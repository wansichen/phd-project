# %%
import math
from typing import Any



from torch import Tensor
from torch.nn.parameter import Parameter, UninitializedParameter

from torch.nn import Module
from scipy.stats import pareto 
from torch.distributions.pareto import Pareto
from torch.nn import init
seed=0
import torch
import torchvision
#torch.cuda.is_available()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import confusion_matrix
#from torch.autograd.functional import jacobian
#import torch.autograd.functional
import time
import copy
import matplotlib.pyplot as plt
import pandas as pd
torch.set_default_dtype(torch.float64)
torch.set_default_dtype(torch.float64)
batch_size=100
input_size=784
output_size=784
hidden_state_size=10
N=28
no_of_layer=2

#torch.cuda.manual_seed_all(seed)
with torch.cuda.device('cuda:0'):
    torch.cuda.empty_cache()

# %%
weight_tuning=2.5
## initial =1
class Linear(Module):
    r"""Applies a linear transformation to the incoming data: :math:`y = xA^T + b`

    This module supports :ref:`TensorFloat32<tf32_on_ampere>`.

    On certain ROCm devices, when using float16 inputs this module will use :ref:`different precision<fp16_on_mi200>` for backward.

    Args:
        in_features: size of each input sample
        out_features: size of each output sample
        bias: If set to ``False``, the layer will not learn an additive bias.
            Default: ``True``

    Shape:
        - Input: :math:`(*, H_{in})` where :math:`*` means any number of
          dimensions including none and :math:`H_{in} = \text{in\_features}`.
        - Output: :math:`(*, H_{out})` where all but the last dimension
          are the same shape as the input and :math:`H_{out} = \text{out\_features}`.

    Attributes:
        weight: the learnable weights of the module of shape
            :math:`(\text{out\_features}, \text{in\_features})`. The values are
            initialized from :math:`\mathcal{U}(-\sqrt{k}, \sqrt{k})`, where
            :math:`k = \frac{1}{\text{in\_features}}`
        bias:   the learnable bias of the module of shape :math:`(\text{out\_features})`.
                If :attr:`bias` is ``True``, the values are initialized from
                :math:`\mathcal{U}(-\sqrt{k}, \sqrt{k})` where
                :math:`k = \frac{1}{\text{in\_features}}`

    Examples::

        >>> m = nn.Linear(20, 30)
        >>> input = torch.randn(128, 20)
        >>> output = m(input)
        >>> print(output.size())
        torch.Size([128, 30])
    """
    __constants__ = ['in_features', 'out_features']
    in_features: int
    out_features: int
    weight: Tensor

    def __init__(self, in_features: int, out_features: int, bias: bool = True,
                 device=None, dtype=None) -> None:
        factory_kwargs = {'device': device, 'dtype': dtype}
        super().__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.weight = Parameter(torch.empty((out_features, in_features), **factory_kwargs))
        if bias:
            self.bias = Parameter(torch.empty(out_features, **factory_kwargs))
        else:
            self.register_parameter('bias', None)
        self.reset_parameters()

    def reset_parameters(self) -> None:
        #if reset=True:
            
        # Setting a=sqrt(5) in kaiming_uniform is the same as initializing with
        # uniform(-1/sqrt(in_features), 1/sqrt(in_features)). For details, see
        # https://github.com/pytorch/pytorch/issues/57109
        #init.kaiming_uniform_(self.weight, a=math.sqrt(5))
        fan_in, _ = init._calculate_fan_in_and_fan_out(self.weight)
        print("fan_in")
        print(fan_in)
        bound =weight_tuning/ math.sqrt(fan_in) 
        init.uniform_(self.weight, -bound,bound)
        if self.bias is not None:
            fan_in, _ = init._calculate_fan_in_and_fan_out(self.bias)
            bound =weight_tuning/ math.sqrt(fan_in) 
            init.uniform_(self.bias, -bound, bound)
            #init.uniform_(self.weight, -bound,bound)
        #fan = _calculate_correct_fan(tensor, mode)
        #gain = calculate_gain(nonlinearity, a)
        #std = gain / math.sqrt(fan)
        #bound = math.sqrt(3.0) * std  # Calculate uniform bounds from standard deviation
        #with torch.no_grad():
            #return tensor.uniform_(-bound, bound)

    def forward(self, input: Tensor) -> Tensor:
        return F.linear(input, self.weight, self.bias)

    def extra_repr(self) -> str:
        return 'in_features={}, out_features={}, bias={}'.format(
            self.in_features, self.out_features, self.bias is not None
        )
    def set_parameter(self,mean, variance):
        
        fan_in, _ = init._calculate_fan_in_and_fan_out(self.weight)
        #print("fan_in")
        #print(fan_in)
        bound=np.sqrt(3*variance)
        print(bound)
        print(variance)
        #bound =weight_tuning/ math.sqrt(fan_in) 
        init.uniform_(self.weight, -bound+mean,bound+mean)
        if self.bias is not None:
            #fan_in, _ = init._calculate_fan_in_and_fan_out(self.bias)
            #bound =weight_tuning/ math.sqrt(fan_in) 
            init.uniform_(self.bias, -bound, bound)

# %%
import torch
import torchvision
#torch.cuda.is_available()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import confusion_matrix
#from torch.autograd.functional import jacobian
#import torch.autograd.functional
import time
import copy
import matplotlib.pyplot as plt
import pandas as pd
torch.set_default_dtype(torch.float64)
torch.set_default_dtype(torch.float64)
batch_size=100
input_size=784
output_size=784
hidden_state_size=10
N=28
no_of_layer=2



font = {
        'size'   : 14}
plt.rc('font', **font)

class AE(nn.Module):
    def __init__(self, input_shape,hidden_layer_shape,encoder_output_shape,n,xinit=torch.eye(batch_size,input_size),xfinal=torch.eye(batch_size,input_size),hidden=torch.eye(10,input_size)):
        super().__init__()
        self.encoder_input_layer = Linear(
            in_features=input_shape, out_features=hidden_layer_shape
        ,bias=False)
        self.hidden_layer=Linear(
            in_features=hidden_layer_shape, out_features=hidden_layer_shape
        ,bias=False)
        self.encoder_output_layer = Linear(
            in_features=hidden_layer_shape, out_features=encoder_output_shape
        ,bias=False)
        self.decoder_input_layer = Linear(
            in_features=encoder_output_shape, out_features=hidden_layer_shape
        ,bias=False)
        self.decoder_output_layer = Linear(
            in_features=hidden_layer_shape, out_features=input_shape
        ,bias=False)
        #self.encoder_input_layer.weight=torch.nn.Parameter(torch.rand(self.encoder_input_layer.weight.size))
        
        self.number_of_layers=n
        self.xinit=xinit
        self.xfinal=xfinal
        self.hidden=hidden

    def forward(self, features):
        reconstructed=self.internals(features)
        return reconstructed
    
    def internals(self,features):
        code=self.encoder(features)
        self.hidden=code
        #print(code)
       # print("hidden state maximum:"+str(torch.max(code)))
        reconstructed=self.decoder(code)
        return reconstructed
    
    def encoder(self,features):
        activation = self.encoder_input_layer(features)
        x = torch.relu(activation)
        self.xinit=x
        for i in range(self.number_of_layers):
            x=torch.relu(self.hidden_layer(x))
        code = self.encoder_output_layer(x)
        result = torch.relu(code)
        return code
    
    def decoder(self,code):
        activation = self.decoder_input_layer(code)
        x = torch.relu(activation)
        for i in range(self.number_of_layers):
             x=torch.relu(self.hidden_layer(x))
        self.xfinal=x
        activation = self.decoder_output_layer(x)
        reconstructed = torch.relu(activation)
        return reconstructed
    
    def xfinals(self):
        return self.xfinal
    
    def xinits(self):
        return self.xinit
    
    def hiddens(self):
        return self.hidden

# %%
import torch
import torchvision
#torch.cuda.is_available()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import confusion_matrix
#from torch.autograd.functional import jacobian
#import torch.autograd.functional
import time
import copy
import matplotlib.pyplot as plt
import pandas as pd
torch.set_default_dtype(torch.float64)
torch.set_default_dtype(torch.float64)
batch_size=100
input_size=784
output_size=784
hidden_state_size=10
N=28
no_of_layer=2



font = {
        'size'   : 14}
plt.rc('font', **font)

class AE_1(nn.Module):
    def __init__(self, input_shape,hidden_layer_shape,encoder_output_shape,n,xinit=torch.eye(batch_size,input_size),xfinal=torch.eye(batch_size,input_size),hidden=torch.eye(10,input_size)):
        super().__init__()

        self.encoder_output_layer = Linear(
            in_features=input_shape, out_features=encoder_output_shape
        ,bias=False)
        self.decoder_input_layer = Linear(
            in_features=encoder_output_shape, out_features=input_shape
        ,bias=False)

        #self.encoder_input_layer.weight=torch.nn.Parameter(torch.rand(self.encoder_input_layer.weight.size))
        
        self.number_of_layers=n
        self.xinit=xinit
        self.xfinal=xfinal
        self.hidden=hidden

    def forward(self, features):
        reconstructed=self.internals(features)
        return reconstructed
    
    def internals(self,features):
        code=self.encoder(features)
        self.hidden=code
        #print("hidden state:"+str(code))
        reconstructed=self.decoder(code)
        return reconstructed
    
    def encoder(self,features):
        activation = self.encoder_output_layer(features)
        code = torch.relu(activation)
     
        return code
    
    def decoder(self,code):
        activation = self.decoder_input_layer(code)
        reconstructed = torch.relu(activation)

        return reconstructed
    
    def xfinals(self):
        return self.xfinal
    
    def xinits(self):
        return self.xinit
    
    def hiddens(self):
        return self.hidden
    def reset_parameter_encoder(self,mean,variance):
        
        self.encoder_output_layer.set_parameter(mean,variance)
    def reset_parameter_decoder(self,mean,variance):
        self.decoder_input_layer.set_parameter(mean,variance)

# %%
def add_gaussian_noise(inputs,strength):
    #print(inputs.size())
    noise = torch.randn_like(inputs)*strength*torch.max(inputs)
    result=inputs + noise
    return result
def add_powerlaw_noise(input_size,batch_size,strength,images):
    ##input size here is the side of the image 28 
    m = Pareto(torch.tensor([1.0]), torch.tensor([1.0]))
    res=m.sample(images.size())

    temp=res/np.sqrt(res.var())/N/batch_size*strength
    noise=temp-temp.mean()
    #if print_bool:
     #   plt.title(powerlaw_noise print)
      #  plt.hist(noise.flatten(),density=True, bins='auto', histtype='stepfilled')
        
      #  plt.show()
    #print(noise[:,:,:,:,0].size())
    return noise[:,:,0]+images

def validation(test_loader):
    
    with torch.no_grad():

     #valid_loss = criterion(outputs, batch_features.view(batch_size,-1).to(device))
        loss=0
        for batch_features, _ in test_loader:
            #input=add_noise(batch_features,).view(100, -1).to(device)
            input_image=add_gaussian_noise(batch_features,noise_strength).view(batch_size, -1).to(device)
            #batch_feature = batch_features.view(batch_size, -1)
            #input_image =add_powerlaw_noise(input_size,batch_size,noise_strength,batch_feature).view(batch_size, -1).to(device)
            batch_feature = batch_features.view(batch_size, -1).to(device)
            outputs = model(input_image)
            valid_loss = criterion(outputs, input_image.to(device)) 
            #accuracy+=kl_div(outputs,batch_features)/batch_size
            loss += valid_loss.item()
    return loss/len(test_loader)
            
def kl_div(output_image,input_image):
    accuracy=0
    kl_loss = nn.KLDivLoss(reduction="batchmean")
    for i in range(len(input_image)):
        input_spectrum=torch.histogram(input_image[i].cpu(), bins=256, density=True)
        output_spectrum=torch.histogram(output_image[i].cpu(), bins=256, density=True)
        accuracy+=kl_loss(input_spectrum[i],output_spectrum[i])
    return accuracy/len(input_image)

def iteration(model,initial_inputs,no_of_repetition,epoch):
    y_pred=initial_inputs.to(device)
    for i in range(no_of_repetition):
        x_train=y_pred
        #if i==0:
           # name="progress asymptotic iteration:"+str(i)+" "
           # visualisation(x_train[0].cpu().detach(),epoch,name,False)
        #if i%5==1:
            #name="progress asymptotic iteration:"+str(i)+" "
            #visualisation(x_train[0].cpu().detach(),epoch,name,False)
        y_pred=model.internals(x_train)
    return x_train,y_pred,model 

def asymptotic_jacobian(model,initial_input,no_of_images,no_of_repetition):
    ave_jac=0
    overall_distribution=np.asarray([])

    jacobian=[]
    sorteds=np.asarray([])
    for j in range(no_of_repetition):
        #print("here")
        x_train=initial_input.to(device)
        y_pred=x_train
        mean_jacobian=0
        for i in range(no_of_images):
            x=x_train[i]
            res=torch.autograd.functional.jacobian(model.internals,x)
            distribution=np.asarray([])
            jacobian.append(res)
            sorted=np.asarray([])
            #if j==no_of_repetition-1:
             #   distribution,sorted=spectral_distribution(res.cpu())
              #  overall_distribution=np.concatenate((overall_distribution,distribution),axis=0)
              #  spectral=spectral_radius(sorted)
              #  sorteds=np.append(sorteds,spectral)

            norm=torch.norm(res).cpu()
            mean_jacobian+=1/np.sqrt(output_size)*norm
        mean_jacobian=mean_jacobian/no_of_images
        ave_jac+=mean_jacobian
    average_jacobian=ave_jac/no_of_repetition
    return average_jacobian,overall_distribution,jacobian,sorteds

def spectral_radius(jacobian,no_of_repetition,no_of_images):
    #result=[]
   
    #output=initial_input.to(device)
   # product=torch.eye(n=input_size,m=output_size).to(device)
    
    spectral=0

    
        
    #res=torch.autograd.functional.jacobian(model.internals,initial_input)
    #product=torch.matmul(product,res)
    #output=model(initial_input)
   # initial_input=output
    
    s,v=torch.linalg.eig(jacobian)
 #   #print(s)
    abs=torch.abs(s)
    
    spectral=torch.max(abs).item()
    return spectral

def poincare_plot(model,initial_input,dimension_vector,no_of_repetition,colour,epoch):
    xt=[]
    xtminus=[]
    
    output=initial_input
    
    for i in range(no_of_repetition):
        
        initial_input=output
        output=model(initial_input)
        
        xt.append(1/output_size*torch.dot(output,dimension_vector).item())
        xtminus.append(1/output_size*torch.dot(initial_input,dimension_vector).item())
    
    return xt,xtminus
  
    


def asymptotic_distance(xinfinity_unperturbed,xinfinity_perturbed,perturbation):
    result=[]
    for i in range(len(xinfinity_unperturbed)):
    
        sum=0
        
        for j in range(len(xinfinity_unperturbed[i])):
            
            temp=np.linalg.norm(xinfinity_unperturbed[i][j]-xinfinity_perturbed[i][j])
            sum+=temp
        
        result.append(1/output_size*1/len(xinfinity_unperturbed[i])*sum) 
    
    return result


def calculation(model,no_of_images,no_of_repetition,ave_jacobian,spectral_radiuses,image,epoch):
    spectral=0
    
    model_clone=AE_1(input_size,input_size,hidden_state_size,no_of_layer).to(device)
    model_clone.load_state_dict(copy.deepcopy(model.state_dict()))
    distributions=np.asarray([])
    x_train,y_pred,model_clone=iteration(model_clone,image,asymptotic_repetition,epoch)   
    #ave_jac,distributions,jacobian,sorteds= asymptotic_jacobian(model_clone,x_train,no_of_images,no_of_repetition)
    
    #np.savetxt("jacobian epoch"+str(epoch)+".txt",sorteds)
    #print("distribution size")
    #print(distributions.size)
    #print("sorted size")
    #print(sorteds.size)
    #average_jacobian.append(ave_jac)
    #x = [ele.real for ele in distributions]
    ## extract imaginary part
    #y = [ele.imag for ele in distributions]
    #plt.title("real and imaginary part of eigenvalue")
    #plt.scatter(x, y)
    #plt.ylabel('Imaginary')
    #plt.xlabel('Real')
    #plt.xscale("log")
    #plt.yscale("log")
    #plt.xlim(-1,1)
    #plt.ylim(-1,1)
    #plt.savefig("epoch:"+str(epoch+1)+"number of iteration:"+str(no_of_repetition)+"eigenvalue scatter plot.jpg",bbox_inches = 'tight')
    #plt.show()
    #plt.title("modulus of eigenvalue in log log plot ")
    #plt.hist(sorteds, density=True, bins='auto', histtype='stepfilled')
    #plt.yscale("log")
    #plt.xscale("log")

    #plt.savefig("epoch:"+str(epoch+1)+"number of iteration:"+str(no_of_repetition)+"eigenvalue distribution.jpg",bbox_inches = 'tight')
    #plt.show()

   # for i in range(no_of_images):
    
        #spectral+=spectral_radius(sorteds,no_of_repetition,no_of_images)
    #spectral=sorteds.mean()
    
    #spectral_radiuses.append(spectral)
    #print(spectral/no_of_images)
    
    return x_train,y_pred,average_jacobian,spectral_radiuses,model_clone


def asymptotic_iteration(model_new,initial_inputs,perturbed_inputs,no_of_repetition,no_of_image,cutoff):
    
    y_pred_unperturbed=initial_inputs.to(device)
    y_pred_perturbed=perturbed_inputs.to(device)
    #cutoff=[]
   
    #for j in range(no_of_image):
     
    #cutoff.append(torch.norm(y_pred_unperturbed[j]-y_pred_perturbed[j]))
        #print(cutoff[j])
    distance=[]
    hidden_layer=[]
    hiddens=[]
    chaos=0
 
    for i in range(no_of_repetition):
        x_train_unperturbed=y_pred_unperturbed
        y_pred_unperturbed=model_new.internals(x_train_unperturbed)
        
       
        x_train_perturbed=y_pred_perturbed
        y_pred_perturbed=model_new.internals(x_train_perturbed)
        
       # print(y_pred_perturbed,y_pred_unperturbed)
        
        hidden = model.hiddens()
        #print(hidden)
        #print(torch.sum(hidden,dim=1).cpu().detach().numpy()/1000)
        hidden_layer.append(torch.sum(hidden,dim=1)[0].cpu().detach().numpy()/10)
        hiddens.append(torch.sum(hidden,dim=1).cpu().detach().numpy()/10)
        
        #visualisation(y_pred.view(batch_size,-1)[0].cpu().detach(),epoch)


        #diff=0
        diff=torch.ones(1,device=device)
        #temp=0
        #print(len(cutoff))
        for j in range(no_of_image):
            result=torch.norm(y_pred_unperturbed[j]-y_pred_perturbed[j])
            #print(np.isnan(result.cpu().detach().numpy()))
            #print(result)
            if np.isinf(result.cpu().detach().numpy()) or np.isnan(result.cpu().detach().numpy())  :
                result=torch.Tensor([1*10**38]).to(device)
                print("infinity")
            if result.cpu().detach().numpy()<2**-52:
                result=torch.Tensor([2**-52]).to(device)
            
            #temp=result
            diff*=result**(1/no_of_image)
                
            continue
            #print(j)
            if result>cutoff[j] and i==no_of_repetition-1:
                chaos+=1
            if np.isinf(diff.cpu().detach().numpy()) or np.isnan(diff.cpu().detach().numpy()):
                diff=torch.Tensor([1*10**38]).to(device)
                print("infinity")
            #print("asymptotic calculation")
            #print(result.cpu())
            #print(diff.cpu())
            
        if diff.cpu().detach().numpy()<2**-52:
            diff=torch.Tensor([2**-52]).to(device)
            distance.append(diff)
            continue
        distance.append(diff.cpu().detach().numpy())

    return distance,hidden_layer,chaos/no_of_image

def visualisation(xfinals,epoch,name,bool):
    plt.imshow(xfinals.reshape(N,N), cmap="gray")
    if bool:
        plt.savefig(str(name)+" epoch:"+str(epoch+1)+".jpg")
    plt.show()
    print(str(name)+" epoch:"+str(epoch+1)+".jpg")
    
def divergence(values):
    result=np.abs(values[-1]-values[-2])
    if result>np.abs(values[2]-values[1]):
        return 1
    return 0

def spectral_radius(sorted):
    if len(sorted)==0:
        return 0
    return sorted[0]

def spectral_distribution(input_matrix):
    result=[]
    count=0
    s,v=torch.linalg.eig(input_matrix)
    #return s
    for i in range(len(s)):
        if np.abs(s[i].cpu())<2**-52:
            count+=1
        
    sorted, indices=torch.sort(torch.abs(s),dim=-1,descending=True)
    #for index in indices.cpu():
     #   if index<=len(s)-count:
     #       result.append(s[index])
    #print(sorted)
    return s,sorted[:-count]

# %%
def stats(tensor):
    # Calculate the mean
    mean = torch.mean(tensor)
    # Calculate the variance
    second = torch.mean(torch.pow(tensor,2))
    third = torch.mean(torch.pow(tensor,3))
    fourth=torch.mean(torch.pow(tensor,4))
    # Calculate the standard deviation
    var=torch.var(tensor)
    std = torch.sqrt(var)
    # Calculate the z-scores
    zscores = (tensor - mean) / std
    # Calculate the skewness
    skew = torch.mean(zscores ** 3)
    # Calculate the kurtosis
    kurt = torch.mean(zscores ** 4) - 3
    print("fourth moment")
    print(fourth)
    #Return the results as a tuple
    return mean, second, skew, kurt

# %%
interval=50
no_of_repetition=100
asymptotic_repetition=50
criterion = nn.MSELoss()
noise_strength=10**-3
perturbation_strength=10**-6
import numpy as np  
import matplotlib.pyplot as plt
import torch
no_of_images=20
means=[]
vars=[]
skews=[]
kurtosises=[]
spectral_radiuses=[]
current_file=6
import os
#print(os.getcwd())
file=["relu-1-adam-no-bias","relu-2.5-adam-no-bias","tanh-1-adam-no-bias","tanh-2.5-adam-no-bias","relu-1-adam-1-layer","tanh-1-adam-1-layer","relu-2.5-adam-1-layer","tanh-2.5-adam-1-layer"]
#list of file to work on 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("running")
path="/raid/home/sichen/phd-project/new runs/"
#current working directory
validation_loss=[]
training_loss=[]
asymptotic_dist=[]
epochs=1000
inits=0
average_jacobian=[]
moment=["mean","variance","skewness","kurtosis"]
layer=["first","second","third","fourth","fifth"]
train_set = torchvision.datasets.FashionMNIST("./data", download=True, transform=
                                                transforms.Compose([
    transforms.ToTensor()
]))
test_set = torchvision.datasets.FashionMNIST("./data", download=True, train=False, transform=
                                               transforms.Compose([
    transforms.ToTensor()
]))  
train_loader = torch.utils.data.DataLoader(train_set, 
                                           batch_size=batch_size,shuffle=False)
test_loader = torch.utils.data.DataLoader(test_set,
                                          batch_size=batch_size,shuffle=False)

for epoch in range(epochs+1):
    model = AE_1(input_size,output_size,hidden_state_size,no_of_layer).to(device)
    PATH=path+file[current_file]+"/epoch:"+str(epoch)+".pt"
    if epoch==0:
        print(PATH)
    model.load_state_dict(torch.load(PATH))
#i=0
    #inits=0
    means=[]
    variance=[]
    if epoch==300:
        for batch_features, _ in train_loader:
        # reshape mini-batch data to [1000, 784] matrix
        # load it to the active device
            input_image =add_gaussian_noise(batch_features,noise_strength).view(batch_size, -1).to(device)
            save_image=input_image
        perturbed_input=add_gaussian_noise(save_image,perturbation_strength)
        cutoffs=[]
        for j in range(no_of_images):
            cutoffs.append(torch.norm(perturbed_input[j]-save_image[j]))
        #perturbed_input=add_gaussian_noise(save_image,perturbation_strength)
        x_train_perturbed,y_pred_perturbed,average_jacobian,spectral_radiuses,model_clone=calculation(model,no_of_images,no_of_repetition,average_jacobian,spectral_radiuses,perturbed_input,epoch)
        x_train_unperturbed,y_pred_unperturbed,average_jacobian,spectral_radiuses,model_clone=calculation(model,no_of_images,no_of_repetition,average_jacobian,spectral_radiuses,save_image,epoch)
        distance,hidden,chaos=asymptotic_iteration(model_clone,y_pred_unperturbed,y_pred_perturbed,no_of_repetition,no_of_images,cutoffs)
        print(distance)
        for value in model.parameters():
            mean, var, skew, kurt = stats(value)
            means.append(mean.item())
            variance.append(var.item())
            print(mean.item(),var.item())
        model.reset_parameter_encoder(means[0],variance[0])
        model.reset_parameter_decoder(means[1],variance[1])
        x_train_perturbed,y_pred_perturbed,average_jacobian,spectral_radiuses,model_clone=calculation(model,no_of_images,no_of_repetition,average_jacobian,spectral_radiuses,perturbed_input,epoch)
        x_train_unperturbed,y_pred_unperturbed,average_jacobian,spectral_radiuses,model_clone=calculation(model,no_of_images,no_of_repetition,average_jacobian,spectral_radiuses,save_image,epoch)
        distance,hidden,chaos=asymptotic_iteration(model_clone,y_pred_unperturbed,y_pred_perturbed,no_of_repetition,no_of_images,cutoffs)
        print(distance)
        for value in model.parameters():
            mean, var, skew, kurt = stats(value)
            means.append(mean.item())
            variance.append(var.item())
            print(mean,var,skew,kurt)
        break
    for value in model.parameters():
        print("epoch:")
        print(epoch)
    # Call the function and print the results
        mean, var, skew, kurt = stats(value)
        means.append(mean.cpu().detach().numpy())
        vars.append(var.cpu().detach().numpy())
        skews.append(skew.cpu().detach().numpy())
        kurtosises.append(kurt.cpu().detach().numpy())
        print(mean, var, skew, kurt)
        #print(f"Mean: {mean}")
        #print(f"Variance: {var}")
        #print(f"Skewness: {skew}")
        #print(f"Kurtosis: {kurt}")
        #print("end")

#means=np.resize(means,(10,1000))
x=np.arange(epochs+1)
print("weights")

fig, (ax1, ax2,ax3,ax4) = plt.subplots (nrows=1, ncols=4,figsize=(40,20))
repeats=2
for i in range(repeats):
    #if i%2==0:
        #print(int(i/2))
        ax1.plot(x,means[i::repeats],label=layer[int(i)]+" layer "+moment[0]+" weights")
        ax1.legend(loc="best")
        ax2.plot(x,vars[i::repeats],label=layer[int(i)]+" layer "+moment[1]+" weights")
        ax2.legend(loc="best")
        ax3.plot(x,skews[i::repeats],label=layer[int(i)]+" layer "+moment[2]+" weights")
        ax3.legend(loc="best")
        ax4.plot(x,kurtosises[i::repeats],label=layer[int(i)]+" layer "+moment[3]+" weights")
        ax4.legend(loc="best")
        #plt.show()
    #else:
     #   ax5.plot(x,means[i::10],label=layer[int(i/2)]+" layer "+moment[0]+" bias")
      #  ax5.legend(loc="best")
      #  ax6.plot(x,vars[i::10],label=layer[int(i/2)]+" layer "+moment[1]+" bias")
      #  ax6.legend(loc="best")
      #  ax7.plot(x,skews[i::10],label=layer[int(i/2)]+" layer "+moment[2]+" bias")
      #  ax7.legend(loc="best")
      #  ax8.plot(x,kurtosises[i::10],label=layer[int(i/2)]+" layer "+moment[3]+" bias")
      #  ax8.legend(loc="best")
fig.tight_layout()

plt.savefig(path+file[current_file]+"/"+"new weights(kurtosis-skew).jpg")
np.savetxt(path+file[current_file]+"mean.txt",means)
np.savetxt(path+file[current_file]+"variance.txt",vars)
np.savetxt(path+file[current_file]+"skewness.txt",skews)
np.savetxt(path+file[current_file]+"kurtosis.txt",kurtosises)

plt.show()
# Out:
# running
# fan_in
# 784
# fan_in
# 10
# /raid/home/sichen/phd-project/new runs/relu-2.5-adam-1-layer/epoch:0.pt
# epoch:
# 0
# fourth moment
# tensor(1.2633e-05, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0027, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0049, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.2046, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 0
# fourth moment
# tensor(0.0773, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0072, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2062, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0248, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.1823, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 1
# fourth moment
# tensor(4.0898e-06, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0004, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0218, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.7114, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 1
# fourth moment
# tensor(0.0520, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0296, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1453, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.0398, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.5566, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 2
# fourth moment
# tensor(2.0243e-06, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0009, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0373, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.2614, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 2
# fourth moment
# tensor(0.0504, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0347, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1327, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.0729, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.1701, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 3
# fourth moment
# tensor(1.0973e-06, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0006, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0581, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.3896, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 3
# fourth moment
# tensor(0.0549, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0404, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1306, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.1389, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1608, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 4
# fourth moment
# tensor(6.7812e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0004, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1168, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.4404, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 4
# fourth moment
# tensor(0.0598, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0450, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1331, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.1868, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2948, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 5
# fourth moment
# tensor(4.6491e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1663, device='cuda:0', grad_fn=<MeanBackward0>) tensor(2.8373, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 5
# fourth moment
# tensor(0.0645, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0483, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1372, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.1998, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.3350, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 6
# fourth moment
# tensor(3.3291e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0721, device='cuda:0', grad_fn=<MeanBackward0>) tensor(4.0114, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 6
# fourth moment
# tensor(0.0687, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0517, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1420, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.1987, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.3144, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 7
# fourth moment
# tensor(2.8875e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0662, device='cuda:0', grad_fn=<MeanBackward0>) tensor(5.8626, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 7
# fourth moment
# tensor(0.0736, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0550, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1472, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.1917, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.3022, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 8
# fourth moment
# tensor(3.1173e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1305, device='cuda:0', grad_fn=<MeanBackward0>) tensor(9.1423, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 8
# fourth moment
# tensor(0.0798, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0583, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1527, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.1782, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.3329, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 9
# fourth moment
# tensor(3.5424e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.3308, device='cuda:0', grad_fn=<MeanBackward0>) tensor(13.4653, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 9
# fourth moment
# tensor(0.0870, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0614, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1581, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.1640, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.4017, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 10
# fourth moment
# tensor(4.1299e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.5380, device='cuda:0', grad_fn=<MeanBackward0>) tensor(18.4226, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 10
# fourth moment
# tensor(0.0943, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0633, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1632, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.1594, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.4642, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 11
# fourth moment
# tensor(4.4586e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6052, device='cuda:0', grad_fn=<MeanBackward0>) tensor(22.0475, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 11
# fourth moment
# tensor(0.1012, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0643, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1681, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.1602, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.5086, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 12
# fourth moment
# tensor(4.6826e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.8886, device='cuda:0', grad_fn=<MeanBackward0>) tensor(25.6426, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 12
# fourth moment
# tensor(0.1077, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0649, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1727, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.1610, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.5407, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 13
# fourth moment
# tensor(4.6634e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.0730, device='cuda:0', grad_fn=<MeanBackward0>) tensor(27.0011, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 13
# fourth moment
# tensor(0.1138, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0654, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1770, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.1615, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.5624, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 14
# fourth moment
# tensor(4.5427e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.0206, device='cuda:0', grad_fn=<MeanBackward0>) tensor(27.7964, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 14
# fourth moment
# tensor(0.1193, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0659, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1809, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.1623, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.5759, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 15
# fourth moment
# tensor(4.6056e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.0584, device='cuda:0', grad_fn=<MeanBackward0>) tensor(28.5862, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 15
# fourth moment
# tensor(0.1243, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0663, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1844, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.1637, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.5839, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 16
# fourth moment
# tensor(4.5523e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.0904, device='cuda:0', grad_fn=<MeanBackward0>) tensor(30.3411, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 16
# fourth moment
# tensor(0.1289, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0667, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1877, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.1654, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.5887, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 17
# fourth moment
# tensor(4.6116e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.0840, device='cuda:0', grad_fn=<MeanBackward0>) tensor(32.2575, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 17
# fourth moment
# tensor(0.1331, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0671, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1906, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.1674, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.5917, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 18
# fourth moment
# tensor(5.2820e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.4019, device='cuda:0', grad_fn=<MeanBackward0>) tensor(37.8442, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 18
# fourth moment
# tensor(0.1370, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0674, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1933, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.1696, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.5939, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 19
# fourth moment
# tensor(5.0902e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.3872, device='cuda:0', grad_fn=<MeanBackward0>) tensor(37.0951, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 19
# fourth moment
# tensor(0.1406, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0678, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1958, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.1717, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.5960, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 20
# fourth moment
# tensor(7.5010e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(2.1265, device='cuda:0', grad_fn=<MeanBackward0>) tensor(54.5727, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 20
# fourth moment
# tensor(0.1441, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0682, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1981, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.1738, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.5981, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 21
# fourth moment
# tensor(7.5908e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(2.0915, device='cuda:0', grad_fn=<MeanBackward0>) tensor(57.0907, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 21
# fourth moment
# tensor(0.1472, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0685, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.1759, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6007, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 22
# fourth moment
# tensor(6.6304e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.9658, device='cuda:0', grad_fn=<MeanBackward0>) tensor(50.1241, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 22
# fourth moment
# tensor(0.1503, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0689, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2021, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.1779, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6035, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 23
# fourth moment
# tensor(6.1929e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.8598, device='cuda:0', grad_fn=<MeanBackward0>) tensor(46.6838, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 23
# fourth moment
# tensor(0.1531, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0693, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2038, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.1798, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6068, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 24
# fourth moment
# tensor(6.1945e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.8518, device='cuda:0', grad_fn=<MeanBackward0>) tensor(46.0100, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 24
# fourth moment
# tensor(0.1557, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0696, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2055, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.1816, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6105, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 25
# fourth moment
# tensor(6.0865e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.7970, device='cuda:0', grad_fn=<MeanBackward0>) tensor(45.0476, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 25
# fourth moment
# tensor(0.1582, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0700, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2070, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.1833, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6145, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 26
# fourth moment
# tensor(5.7822e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.6948, device='cuda:0', grad_fn=<MeanBackward0>) tensor(43.8056, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 26
# fourth moment
# tensor(0.1606, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0703, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2083, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.1849, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6188, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 27
# fourth moment
# tensor(6.6248e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.7200, device='cuda:0', grad_fn=<MeanBackward0>) tensor(48.8486, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 27
# fourth moment
# tensor(0.1628, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0707, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2096, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.1863, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6235, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 28
# fourth moment
# tensor(7.0124e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.6905, device='cuda:0', grad_fn=<MeanBackward0>) tensor(50.8674, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 28
# fourth moment
# tensor(0.1649, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0710, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2108, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.1877, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6284, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 29
# fourth moment
# tensor(6.2887e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.4914, device='cuda:0', grad_fn=<MeanBackward0>) tensor(48.8551, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 29
# fourth moment
# tensor(0.1669, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0713, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2119, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.1890, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6334, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 30
# fourth moment
# tensor(6.0001e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.5416, device='cuda:0', grad_fn=<MeanBackward0>) tensor(47.3485, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 30
# fourth moment
# tensor(0.1688, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0716, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2130, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.1901, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6387, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 31
# fourth moment
# tensor(5.8809e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.3659, device='cuda:0', grad_fn=<MeanBackward0>) tensor(47.1831, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 31
# fourth moment
# tensor(0.1707, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0719, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2140, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.1913, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6442, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 32
# fourth moment
# tensor(6.9594e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.4713, device='cuda:0', grad_fn=<MeanBackward0>) tensor(53.8734, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 32
# fourth moment
# tensor(0.1724, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0722, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2149, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.1924, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6498, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 33
# fourth moment
# tensor(7.0434e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.4582, device='cuda:0', grad_fn=<MeanBackward0>) tensor(55.4403, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 33
# fourth moment
# tensor(0.1741, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0725, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2158, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.1935, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6557, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 34
# fourth moment
# tensor(6.5151e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.1549, device='cuda:0', grad_fn=<MeanBackward0>) tensor(51.9815, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 34
# fourth moment
# tensor(0.1757, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0728, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2166, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.1946, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6617, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 35
# fourth moment
# tensor(5.7915e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.1129, device='cuda:0', grad_fn=<MeanBackward0>) tensor(47.9469, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 35
# fourth moment
# tensor(0.1773, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0731, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2174, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.1957, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6678, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 36
# fourth moment
# tensor(5.6042e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.3029, device='cuda:0', grad_fn=<MeanBackward0>) tensor(46.8674, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 36
# fourth moment
# tensor(0.1789, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0734, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2181, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.1969, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6741, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 37
# fourth moment
# tensor(5.7422e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.0159, device='cuda:0', grad_fn=<MeanBackward0>) tensor(47.5790, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 37
# fourth moment
# tensor(0.1804, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0737, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2188, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.1981, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6804, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 38
# fourth moment
# tensor(5.7118e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.0366, device='cuda:0', grad_fn=<MeanBackward0>) tensor(48.3010, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 38
# fourth moment
# tensor(0.1819, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0739, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2195, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.1993, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6868, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 39
# fourth moment
# tensor(5.1873e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.1164, device='cuda:0', grad_fn=<MeanBackward0>) tensor(45.0965, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 39
# fourth moment
# tensor(0.1833, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0742, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2202, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.2006, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6931, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 40
# fourth moment
# tensor(5.1132e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.1894, device='cuda:0', grad_fn=<MeanBackward0>) tensor(45.7288, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 40
# fourth moment
# tensor(0.1848, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0745, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2209, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.2019, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6996, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 41
# fourth moment
# tensor(5.2598e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.3570, device='cuda:0', grad_fn=<MeanBackward0>) tensor(47.3262, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 41
# fourth moment
# tensor(0.1862, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0748, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2215, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.2031, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.7061, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 42
# fourth moment
# tensor(5.0122e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.3620, device='cuda:0', grad_fn=<MeanBackward0>) tensor(44.0289, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 42
# fourth moment
# tensor(0.1875, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0751, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2221, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.2044, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.7126, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 43
# fourth moment
# tensor(4.6462e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.2677, device='cuda:0', grad_fn=<MeanBackward0>) tensor(43.0320, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 43
# fourth moment
# tensor(0.1888, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0754, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2227, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.2057, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.7191, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 44
# fourth moment
# tensor(4.5114e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.2200, device='cuda:0', grad_fn=<MeanBackward0>) tensor(41.8346, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 44
# fourth moment
# tensor(0.1901, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0756, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2232, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.2070, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.7257, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 45
# fourth moment
# tensor(4.7028e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.1088, device='cuda:0', grad_fn=<MeanBackward0>) tensor(44.0461, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 45
# fourth moment
# tensor(0.1913, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0759, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2237, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.2083, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.7325, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 46
# fourth moment
# tensor(5.8348e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.9584, device='cuda:0', grad_fn=<MeanBackward0>) tensor(51.5525, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 46
# fourth moment
# tensor(0.1925, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0762, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2241, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.2097, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.7393, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 47
# fourth moment
# tensor(5.1045e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.1816, device='cuda:0', grad_fn=<MeanBackward0>) tensor(46.1883, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 47
# fourth moment
# tensor(0.1936, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0764, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2246, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.2110, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.7461, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 48
# fourth moment
# tensor(4.8101e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(9.9341e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.2340, device='cuda:0', grad_fn=<MeanBackward0>) tensor(45.9596, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 48
# fourth moment
# tensor(0.1947, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0767, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2250, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.2124, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.7530, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 49
# fourth moment
# tensor(3.8584e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(9.6732e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.0250, device='cuda:0', grad_fn=<MeanBackward0>) tensor(38.4196, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 49
# fourth moment
# tensor(0.1957, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0769, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2254, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.2138, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.7601, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 50
# fourth moment
# tensor(3.9701e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(9.8320e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.0813, device='cuda:0', grad_fn=<MeanBackward0>) tensor(38.2566, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 50
# fourth moment
# tensor(0.1968, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0771, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2257, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.2152, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.7672, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 51
# fourth moment
# tensor(3.7096e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(9.6857e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.8045, device='cuda:0', grad_fn=<MeanBackward0>) tensor(36.7078, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 51
# fourth moment
# tensor(0.1978, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0774, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2261, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.2167, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.7744, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 52
# fourth moment
# tensor(3.6048e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(9.5744e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6940, device='cuda:0', grad_fn=<MeanBackward0>) tensor(36.4796, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 52
# fourth moment
# tensor(0.1987, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0776, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2264, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.2182, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.7817, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 53
# fourth moment
# tensor(4.0677e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(9.6620e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.0555, device='cuda:0', grad_fn=<MeanBackward0>) tensor(40.7742, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 53
# fourth moment
# tensor(0.1996, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0778, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2267, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.2198, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.7891, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 54
# fourth moment
# tensor(5.2278e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(9.8963e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.4058, device='cuda:0', grad_fn=<MeanBackward0>) tensor(50.6392, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 54
# fourth moment
# tensor(0.2005, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0780, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2269, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.2213, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.7965, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 55
# fourth moment
# tensor(5.7918e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.6682, device='cuda:0', grad_fn=<MeanBackward0>) tensor(54.2265, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 55
# fourth moment
# tensor(0.2013, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0782, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2272, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.2229, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.8040, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 56
# fourth moment
# tensor(7.0289e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(2.1035, device='cuda:0', grad_fn=<MeanBackward0>) tensor(65.1821, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 56
# fourth moment
# tensor(0.2021, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0785, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2274, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.2245, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.8115, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 57
# fourth moment
# tensor(7.3949e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(2.1943, device='cuda:0', grad_fn=<MeanBackward0>) tensor(67.1742, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 57
# fourth moment
# tensor(0.2030, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0787, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2276, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.2262, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.8191, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 58
# fourth moment
# tensor(9.2130e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(2.5380, device='cuda:0', grad_fn=<MeanBackward0>) tensor(82.4452, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 58
# fourth moment
# tensor(0.2037, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0789, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2278, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.2278, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.8266, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 59
# fourth moment
# tensor(7.9586e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(2.1493, device='cuda:0', grad_fn=<MeanBackward0>) tensor(71.3942, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 59
# fourth moment
# tensor(0.2045, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0791, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2280, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.2295, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.8342, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 60
# fourth moment
# tensor(6.8974e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.9955, device='cuda:0', grad_fn=<MeanBackward0>) tensor(64.2848, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 60
# fourth moment
# tensor(0.2053, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0793, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2282, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.2312, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.8419, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 61
# fourth moment
# tensor(8.0839e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(2.3950, device='cuda:0', grad_fn=<MeanBackward0>) tensor(73.6513, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 61
# fourth moment
# tensor(0.2060, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0795, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2283, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.2329, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.8496, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 62
# fourth moment
# tensor(8.5151e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(2.2525, device='cuda:0', grad_fn=<MeanBackward0>) tensor(72.8382, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 62
# fourth moment
# tensor(0.2066, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0797, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2284, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.2347, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.8573, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 63
# fourth moment
# tensor(7.1323e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.9510, device='cuda:0', grad_fn=<MeanBackward0>) tensor(62.4050, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 63
# fourth moment
# tensor(0.2073, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0799, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2286, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.2364, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.8651, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 64
# fourth moment
# tensor(7.9348e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(2.0999, device='cuda:0', grad_fn=<MeanBackward0>) tensor(68.2082, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 64
# fourth moment
# tensor(0.2080, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0801, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2287, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.2381, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.8728, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 65
# fourth moment
# tensor(8.6959e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(2.3724, device='cuda:0', grad_fn=<MeanBackward0>) tensor(76.4527, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 65
# fourth moment
# tensor(0.2086, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0803, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2288, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.2399, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.8807, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 66
# fourth moment
# tensor(8.5666e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(2.2195, device='cuda:0', grad_fn=<MeanBackward0>) tensor(73.8587, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 66
# fourth moment
# tensor(0.2092, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0805, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2288, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.2416, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.8886, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 67
# fourth moment
# tensor(9.5461e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(2.6442, device='cuda:0', grad_fn=<MeanBackward0>) tensor(81.9869, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 67
# fourth moment
# tensor(0.2098, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0807, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2289, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.2434, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.8965, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 68
# fourth moment
# tensor(8.0112e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(2.2280, device='cuda:0', grad_fn=<MeanBackward0>) tensor(72.3538, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 68
# fourth moment
# tensor(0.2104, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0810, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2290, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.2452, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.9043, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 69
# fourth moment
# tensor(7.5555e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(2.2183, device='cuda:0', grad_fn=<MeanBackward0>) tensor(67.8959, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 69
# fourth moment
# tensor(0.2109, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0811, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2290, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.2469, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.9122, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 70
# fourth moment
# tensor(7.5528e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(2.4795, device='cuda:0', grad_fn=<MeanBackward0>) tensor(68.3047, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 70
# fourth moment
# tensor(0.2114, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0813, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2291, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.2487, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.9202, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 71
# fourth moment
# tensor(7.2476e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(2.2850, device='cuda:0', grad_fn=<MeanBackward0>) tensor(65.7050, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 71
# fourth moment
# tensor(0.2120, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0815, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2291, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.2504, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.9282, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 72
# fourth moment
# tensor(6.9999e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(2.1965, device='cuda:0', grad_fn=<MeanBackward0>) tensor(62.9374, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 72
# fourth moment
# tensor(0.2124, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0817, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2291, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.2522, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.9362, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 73
# fourth moment
# tensor(8.7362e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(2.5403, device='cuda:0', grad_fn=<MeanBackward0>) tensor(75.7828, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 73
# fourth moment
# tensor(0.2129, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0819, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2291, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.2539, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.9441, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 74
# fourth moment
# tensor(7.2286e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# ...
# fan_in
# 784
# fan_in
# 10
# epoch:
# 290
# fourth moment
# tensor(1.0214e-06, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(2.0201, device='cuda:0', grad_fn=<MeanBackward0>) tensor(56.2345, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 290
# fourth moment
# tensor(0.2433, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0906, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2197, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.7227, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.6360, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 291
# fourth moment
# tensor(9.4158e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.7146, device='cuda:0', grad_fn=<MeanBackward0>) tensor(51.5264, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 291
# fourth moment
# tensor(0.2436, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0907, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2197, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.7252, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.6383, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 292
# fourth moment
# tensor(1.1074e-06, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(2.0333, device='cuda:0', grad_fn=<MeanBackward0>) tensor(60.5706, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 292
# fourth moment
# tensor(0.2438, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0908, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2197, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.7277, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.6409, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 293
# fourth moment
# tensor(1.1957e-06, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(2.0601, device='cuda:0', grad_fn=<MeanBackward0>) tensor(63.9010, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 293
# fourth moment
# tensor(0.2440, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0908, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2197, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.7302, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.6434, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 294
# fourth moment
# tensor(1.3228e-06, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(2.3120, device='cuda:0', grad_fn=<MeanBackward0>) tensor(70.6614, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 294
# fourth moment
# tensor(0.2442, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0909, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2197, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.7328, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.6460, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 295
# fourth moment
# tensor(1.3286e-06, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(2.1985, device='cuda:0', grad_fn=<MeanBackward0>) tensor(70.9384, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 295
# fourth moment
# tensor(0.2444, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0909, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2197, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.7353, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.6484, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 296
# fourth moment
# tensor(1.3033e-06, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(2.0870, device='cuda:0', grad_fn=<MeanBackward0>) tensor(69.2133, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 296
# fourth moment
# tensor(0.2446, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0910, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2197, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.7378, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.6510, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 297
# fourth moment
# tensor(1.3792e-06, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(2.2129, device='cuda:0', grad_fn=<MeanBackward0>) tensor(71.8499, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 297
# fourth moment
# tensor(0.2449, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0911, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2197, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.7404, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.6536, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 298
# fourth moment
# tensor(1.2654e-06, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.7577, device='cuda:0', grad_fn=<MeanBackward0>) tensor(64.3264, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 298
# fourth moment
# tensor(0.2450, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0911, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2197, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.7430, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.6565, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 299
# fourth moment
# tensor(1.4025e-06, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(2.0404, device='cuda:0', grad_fn=<MeanBackward0>) tensor(69.2511, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 299
# fourth moment
# tensor(0.2453, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0912, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2197, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.7456, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.6592, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# fan_in
# 784
# fan_in
# 10
# fan_in
# 784
# fan_in
# 10
# [array([4.16292742e-06]), array([4.19158589e-06]), array([4.21924715e-06]), array([4.24607313e-06]), array([4.27220282e-06]), array([4.29773702e-06]), array([4.3227599e-06]), array([4.34734487e-06]), array([4.37155704e-06]), array([4.39545343e-06]), array([4.41908249e-06]), array([4.44248602e-06]), array([4.4657013e-06]), array([4.48876319e-06]), array([4.51170336e-06]), array([4.5345484e-06]), array([4.55732181e-06]), array([4.58004528e-06]), array([4.6027372e-06]), array([4.62541385e-06]), array([4.64808961e-06]), array([4.67077721e-06]), array([4.69348794e-06]), array([4.71623181e-06]), array([4.7390176e-06]), array([4.76185304e-06]), array([4.78474498e-06]), array([4.80769955e-06]), array([4.83072224e-06]), array([4.85381797e-06]), array([4.87699115e-06]), array([4.90024576e-06]), array([4.92358537e-06]), array([4.94701323e-06]), array([4.97053225e-06]), array([4.99414509e-06]), array([5.01785416e-06]), array([5.04166165e-06]), array([5.06556958e-06]), array([5.08957979e-06]), array([5.11369397e-06]), array([5.13791369e-06]), array([5.1622404e-06]), array([5.18667545e-06]), array([5.2112201e-06]), array([5.23587553e-06]), array([5.26064285e-06]), array([5.2855231e-06]), array([5.31051729e-06]), array([5.33562636e-06]), array([5.36085122e-06]), array([5.38619272e-06]), array([5.41165171e-06]), array([5.437229e-06]), array([5.46292536e-06]), array([5.48874156e-06]), array([5.51467834e-06]), array([5.54073642e-06]), array([5.56691651e-06]), array([5.59321931e-06]), array([5.61964552e-06]), array([5.6461958e-06]), array([5.67287083e-06]), array([5.69967127e-06]), array([5.72659779e-06]), array([5.75365103e-06]), array([5.78083166e-06]), array([5.8081403e-06]), array([5.83557762e-06]), array([5.86314426e-06]), array([5.89084086e-06]), array([5.91866806e-06]), array([5.9466265e-06]), array([5.97471684e-06]), array([6.0029397e-06]), array([6.03129573e-06]), array([6.05978559e-06]), array([6.0884099e-06]), array([6.11716933e-06]), array([6.14606452e-06]), array([6.17509612e-06]), array([6.20426478e-06]), array([6.23357117e-06]), array([6.26301593e-06]), array([6.29259973e-06]), array([6.32232323e-06]), array([6.35218708e-06]), array([6.38219197e-06]), array([6.41233856e-06]), array([6.44262753e-06]), array([6.47305954e-06]), array([6.50363527e-06]), array([6.53435542e-06]), array([6.56522065e-06]), array([6.59623166e-06]), array([6.62738914e-06]), array([6.65869379e-06]), array([6.69014629e-06]), array([6.72174735e-06]), array([6.75349767e-06])]
# fourth moment
# tensor(1.2323e-06, device='cuda:0', grad_fn=<MeanBackward0>)
# -0.0002641210213893019 0.00013933207295050015
# fourth moment
# tensor(0.2455, device='cuda:0', grad_fn=<MeanBackward0>)
# -0.09126760157530482 0.21970614917562994
# 0.020444955829042537
# 0.00013933207295050015
# 0.8118611011293064
# 0.21970614917562994
# fan_in
# 784
# fan_in
# 10
# fan_in
# 784
# fan_in
# 10
# [tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0'), tensor([2.2204e-16], device='cuda:0')]
# fourth moment
# tensor(3.5295e-08, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0005, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0226, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.2115, device='cuda:0', grad_fn=<SubBackward0>)
# fourth moment
# tensor(0.1009, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0944, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2326, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0164, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.2121, device='cuda:0', grad_fn=<SubBackward0>)
# weights
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 113
#     109 repeats=2
#     110 for i in range(repeats):
#     111     #if i%2==0:
#     112         #print(int(i/2))
# --> 113         ax1.plot(x,means[i::repeats],label=layer[int(i)]+" layer "+moment[0]+" weights")
#     114         ax1.legend(loc="best")
#     115         ax2.plot(x,vars[i::repeats],label=layer[int(i)]+" layer "+moment[1]+" weights")
#
# File /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
#    1685 (``'green'``) or hex strings (``'#008000'``).
#    1686 """
#    1687 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
#    1690     self.add_line(line)
#
# File /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py:504, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     501     self.axes.yaxis.update_units(y)
#     503 if x.shape[0] != y.shape[0]:
# --> 504     raise ValueError(f"x and y must have same first dimension, but "
#     505                      f"have shapes {x.shape} and {y.shape}")
#     506 if x.ndim > 2 or y.ndim > 2:
#     507     raise ValueError(f"x and y can be no greater than 2D, but have "
#     508                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (1001,) and (2,)

# %%
train_set = torchvision.datasets.FashionMNIST("./data", download=True, transform=
                                                transforms.Compose([
    transforms.ToTensor()
]))
test_set = torchvision.datasets.FashionMNIST("./data", download=True, train=False, transform=
                                               transforms.Compose([
    transforms.ToTensor()
]))  
train_loader = torch.utils.data.DataLoader(train_set, 
                                           batch_size=batch_size,shuffle=False)
test_loader = torch.utils.data.DataLoader(test_set,
                                          batch_size=batch_size,shuffle=False)

# %%
interval=50
no_of_repetition=100
asymptotic_repetition=50
criterion = nn.MSELoss()
noise_strength=10**-3
perturbation_strength=10**-6
import numpy as np  
import matplotlib.pyplot as plt
import torch
no_of_images=20
means=[]
vars=[]
skews=[]
kurtosises=[]
current_file=8
import os
#print(os.getcwd())
file=["relu-1-adam-done","relu-2.5-adam-done" ,"relu-1-sgd-done","relu-2.5-sgd-done","tanh-1-adam-done","tanh-2.5-adam-done","tanh-2.5-sgd-done","tanh-1-sgd-done","relu-2.5-sgd-5000","tanh-2.5-sgd-5000","relu-1-sgd-5000","tanh-1-sgd-5000"]
#list of file to work on 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("running")
path="/raid/home/sichen/phd-project/new runs/"
#current working directory
validation_loss=[]
training_loss=[]
asymptotic_dist=[]
average_jacobian=[]
spectral_radiuses=[]
init_compute=True
epochs=5000
for epoch in range(epochs):
    #model = AE(input_size,output_size,hidden_state_size,no_of_layer).to(device)
    PATH=path+file[current_file]+"/epoch:"+str(epoch)+".pt"
    if epoch==0:
        print(PATH)
    #model.load_state_dict(torch.load(PATH))

    #loss = 0
    print(epoch)
    #if init_compute==True:
     #   for batch_features, _ in train_loader:
        # reshape mini-batch data to [N, 784] matrix
        # load it to the active device
        
        #distance,hidden,chaos,divergent=asymptotic_iteration(model_clone,x_train,perturbed_inputs,no_of_repetition,no_of_images,perturbation_strength)
        #if init_compute==True:
      #      input_image =add_gaussian_noise(batch_features,noise_strength).view(batch_size, -1).to(device)
       #     init_compute=False
        #input_image =add_noise(batch_features,noise_strength).view(batch_size, -1).to(device)
        
        
        #input_image=batch_features.view(batch_size,-1).to(device)
      #  batch_feature=batch_features.view(batch_size,-1).to(device)
        # reset the gradients back to zero
        # PyTorch accumulates gradients on subsequent backward passes
 
       # optimizer.zero_grad()
        
        # compute reconstructions
        #outputs = model(batch_features.view(batch_size,-1).to(device))
        #outputs = model(input_image)
        
        # compute training reconstruction loss
        
 
        #train_loss = criterion(outputs,input_image)
        

        #loss += train_loss.item()
    # compute the epoch training loss
   # loss = loss / len(train_loader)
    #print(loss)
    #training_loss.append(loss)
    #with torch.no_grad():
     #   accuracy=validation(test_loader)
     #   validation_loss.append(accuracy)
    if (epoch)%interval==interval-1 or epoch==0:
        for batch_features, _ in train_loader:
        # reshape mini-batch data to [N, 784] matrix
        # load it to the active device
        
        #distance,hidden,chaos,divergent=asymptotic_iteration(model_clone,x_train,perturbed_inputs,no_of_repetition,no_of_images,perturbation_strength)
        #if init_compute==True:
            input_image =add_gaussian_noise(batch_features,noise_strength).view(batch_size, -1).to(device)
        
        model = AE(input_size,output_size,hidden_state_size,no_of_layer).to(device)
        PATH=path+file[current_file]+"/epoch:"+str(epoch)+".pt"
        if epoch==0:
            print(PATH)
        model.load_state_dict(torch.load(PATH))
        perturbed_input=add_gaussian_noise(input_image,perturbation_strength)
        cutoffs=[]
        for j in range(no_of_images):
            cutoffs.append(torch.norm(perturbed_input[j]-input_image[j]))
        print(cutoffs)
        x_train_perturbed,y_pred_perturbed,average_jacobian,spectral_radiuses,model_clone=calculation(model,no_of_images,no_of_repetition,average_jacobian,spectral_radiuses,perturbed_input,epoch)
        x_train_unperturbed,y_pred_unperturbed,average_jacobian,spectral_radiuses,model_clone=calculation(model,no_of_images,no_of_repetition,average_jacobian,spectral_radiuses,input_image,epoch)
        distance,hidden,chaos=asymptotic_iteration(model_clone,y_pred_unperturbed,y_pred_perturbed,no_of_repetition,no_of_images,cutoffs)
        print(distance)   
        asymptotic_dist.append(distance[-1])
       # dimension_vector=torch.ones(input_size).to(device)
        #xt,xtminus=poincare_plot(model_clone,x_train[0],dimension_vector,no_of_repetition,colour,epoch)
       
        print('here')
        #perturbed_inputs=add_gaussian_noise(input_image,perturbation_strength).view(batch_size, -1).to(device)
        #distance,hidden,chaos,divergent=asymptotic_iteration(model_clone,x_train,perturbed_inputs,no_of_repetition,no_of_images,perturbation_strength*input_size)
        #print("percentage of chaos:",chaos)
        #asymptotic_dist.append(distance[-1])
        #print(distance[-1])
        #print("initial distance")
        #print(distance[0])
        #chao.append(chaos)
        #print(torch.norm(perturbed_inputs[0]-input_image[0]))
        #print(perturbation_strength*input_size)


        print("done"+str(epoch))
        
x=np.arange(1,epochs/interval+1)
plt.scatter(x,y=asymptotic_dist,label="asymptotic distance")

#labels="noise:"+str(noise_strength)+", perturbation:"+str(perturbation_strength)
plt.ylabel("asymptotic distance")
plt.xlabel("epoch/"+str(interval))
plt.yscale("log")
#plt.set_label("noise:{:.f},perturbation:{:.f}".format(noise_strength,perturbation_strength))
plt.legend(loc="best")
plt.savefig(path+file[current_file]+"/"+"asymptotic distance test2.jpg")
np.savetxt(path+file[current_file]+"/"+"asymptotic distance test2.txt",asymptotic_dist)
plt.show()
