# %%
import math
from typing import Any

import powerlaw as pl

from torch import Tensor
from torch.nn.parameter import Parameter, UninitializedParameter

from torch.nn import Module
from scipy.stats import levy_stable,pareto
from torch.distributions.pareto import Pareto
from torch.nn import init
from torch.distributions.cauchy import Cauchy
from torch.distributions.laplace import Laplace
from torch.nn import init
seed=0
import torch
import torchvision
#torch.cuda.is_available()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import confusion_matrix
#from torch.autograd.functional import jacobian
#import torch.autograd.functional
import time
import copy
import matplotlib.pyplot as plt
import pandas as pd
torch.set_default_dtype(torch.float64)
torch.set_default_dtype(torch.float64)
batch_size=100
input_size=784
output_size=784
hidden_state_size=10
N=28
no_of_layer=2

#torch.cuda.manual_seed_all(seed)
with torch.cuda.device('cuda:0'):
    torch.cuda.empty_cache()

# %%
weight_tuning=1
## initial =1
class Linear(Module):
    r"""Applies a linear transformation to the incoming data: :math:`y = xA^T + b`

    This module supports :ref:`TensorFloat32<tf32_on_ampere>`.

    On certain ROCm devices, when using float16 inputs this module will use :ref:`different precision<fp16_on_mi200>` for backward.

    Args:
        in_features: size of each input sample
        out_features: size of each output sample
        bias: If set to ``False``, the layer will not learn an additive bias.
            Default: ``True``

    Shape:
        - Input: :math:`(*, H_{in})` where :math:`*` means any number of
          dimensions including none and :math:`H_{in} = \text{in\_features}`.
        - Output: :math:`(*, H_{out})` where all but the last dimension
          are the same shape as the input and :math:`H_{out} = \text{out\_features}`.

    Attributes:
        weight: the learnable weights of the module of shape
            :math:`(\text{out\_features}, \text{in\_features})`. The values are
            initialized from :math:`\mathcal{U}(-\sqrt{k}, \sqrt{k})`, where
            :math:`k = \frac{1}{\text{in\_features}}`
        bias:   the learnable bias of the module of shape :math:`(\text{out\_features})`.
                If :attr:`bias` is ``True``, the values are initialized from
                :math:`\mathcal{U}(-\sqrt{k}, \sqrt{k})` where
                :math:`k = \frac{1}{\text{in\_features}}`

    Examples::

        >>> m = nn.Linear(20, 30)
        >>> input = torch.randn(128, 20)
        >>> output = m(input)
        >>> print(output.size())
        torch.Size([128, 30])
    """
    __constants__ = ['in_features', 'out_features']
    in_features: int
    out_features: int
    weight: Tensor

    def __init__(self, in_features: int, out_features: int, bias: bool = True,
                 device=None, dtype=None) -> None:
        factory_kwargs = {'device': device, 'dtype': dtype}
        super().__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.weight = Parameter(torch.empty((out_features, in_features), **factory_kwargs))
        if bias:
            self.bias = Parameter(torch.empty(out_features, **factory_kwargs))
        else:
            self.register_parameter('bias', None)
        self.reset_parameters()

    def reset_parameters(self) -> None:
        #if reset=True:
            
        # Setting a=sqrt(5) in kaiming_uniform is the same as initializing with
        # uniform(-1/sqrt(in_features), 1/sqrt(in_features)). For details, see
        # https://github.com/pytorch/pytorch/issues/57109
        #init.kaiming_uniform_(self.weight, a=math.sqrt(5))
        #init.uniform_(self.weight, -bound,bound)
        fan_in, _ = init._calculate_fan_in_and_fan_out(self.weight)
        bound =weight_tuning/ math.sqrt(fan_in) if fan_in > 0 else 0
        init.uniform_(self.weight, -bound,bound)
        if self.bias is not None:
            fan_in, _ = init._calculate_fan_in_and_fan_out(self.weight)
            bound =weight_tuning/ math.sqrt(fan_in) if fan_in > 0 else 0
            init.uniform_(self.bias, -bound, bound)
            init.uniform_(self.weight, -bound,bound)
        #fan = _calculate_correct_fan(tensor, mode)
        #gain = calculate_gain(nonlinearity, a)
        #std = gain / math.sqrt(fan)
        #bound = math.sqrt(3.0) * std  # Calculate uniform bounds from standard deviation
        #with torch.no_grad():
            #return tensor.uniform_(-bound, bound)

    def forward(self, input: Tensor) -> Tensor:
        return F.linear(input, self.weight, self.bias)

    def extra_repr(self) -> str:
        return 'in_features={}, out_features={}, bias={}'.format(
            self.in_features, self.out_features, self.bias is not None
        )

# %%
import torch
import torchvision
#torch.cuda.is_available()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import confusion_matrix
#from torch.autograd.functional import jacobian
#import torch.autograd.functional
import time
import copy
import matplotlib.pyplot as plt
import pandas as pd
torch.set_default_dtype(torch.float64)
torch.set_default_dtype(torch.float64)
batch_size=100
input_size=784
output_size=784
hidden_state_size=10
N=28
no_of_layer=2



font = {
        'size'   : 14}
plt.rc('font', **font)

class AE(nn.Module):
    def __init__(self, input_shape,hidden_layer_shape,encoder_output_shape,n,xinit=torch.eye(batch_size,input_size),xfinal=torch.eye(batch_size,input_size),hidden=torch.eye(10,input_size)):
        super().__init__()
        self.encoder_output_layer = Linear(
            in_features=input_shape, out_features=encoder_output_shape
        ,bias=False)
        self.decoder_input_layer = Linear(
            in_features=encoder_output_shape, out_features=input_shape
        ,bias=False)
        #self.encoder_input_layer.weight=torch.nn.Parameter(torch.rand(self.encoder_input_layer.weight.size))
        
        self.number_of_layers=n
        self.xinit=xinit
        self.xfinal=xfinal
        self.hidden=hidden
    def forward(self, features):
        reconstructed=self.internals(features)
        return reconstructed
    
    def internals(self,features):
        code=self.encoder(features)
        self.hidden=code
        #print(code)
       # print("hidden state maximum:"+str(torch.max(code)))
        reconstructed=self.decoder(code)
        return reconstructed
    
    def encoder(self,features):

        code = self.encoder_output_layer(features)
        result = torch.relu(code)
        return code
    
    def decoder(self,code):
        activation = self.decoder_input_layer(code)
        reconstructed = torch.relu(activation)
        
        return reconstructed
    
    def xfinals(self):
        return self.xfinal
    
    def xinits(self):
        return self.xinit
    
    def hiddens(self):
        return self.hidden

# %%
def add_gaussian_noise(inputs,strength):
    #print(inputs.size())
    noise = torch.randn_like(inputs)*strength*torch.max(inputs)
    result=inputs + noise
    return result
def add_powerlaw_noise(input_size,batch_size,strength,images):
    ##input size here is the side of the image 28 
    m = Pareto(torch.tensor([1.0]), torch.tensor([1.0]))
    res=m.sample(images.size())

    temp=res/np.sqrt(res.var())/N/batch_size*strength
    noise=temp-temp.mean()
    #if print_bool:
     #   plt.title(powerlaw_noise print)
      #  plt.hist(noise.flatten(),density=True, bins='auto', histtype='stepfilled')
        
      #  plt.show()
    #print(noise[:,:,:,:,0].size())
    return noise[:,:,0]+images

def validation(test_loader):
    
    with torch.no_grad():

     #valid_loss = criterion(outputs, batch_features.view(batch_size,-1).to(device))
        loss=0
        for batch_features, _ in test_loader:
            #input=add_noise(batch_features,).view(100, -1).to(device)
            input_image=add_gaussian_noise(batch_features,noise_strength).view(batch_size, -1).to(device)
            #batch_feature = batch_features.view(batch_size, -1)
            #input_image =add_powerlaw_noise(input_size,batch_size,noise_strength,batch_feature).view(batch_size, -1).to(device)
            batch_feature = batch_features.view(batch_size, -1).to(device)
            outputs = model(input_image)
            valid_loss = criterion(outputs, input_image.to(device)) 
            #accuracy+=kl_div(outputs,batch_features)/batch_size
            loss += valid_loss.item()
    return loss/len(test_loader)
            
def kl_div(output_image,input_image):
    accuracy=0
    kl_loss = nn.KLDivLoss(reduction="batchmean")
    for i in range(len(input_image)):
        input_spectrum=torch.histogram(input_image[i].cpu(), bins=256, density=True)
        output_spectrum=torch.histogram(output_image[i].cpu(), bins=256, density=True)
        accuracy+=kl_loss(input_spectrum[i],output_spectrum[i])
    return accuracy/len(input_image)

def iteration(model,initial_inputs,no_of_repetition,epoch):
    y_pred=initial_inputs.to(device)
    for i in range(no_of_repetition):
        x_train=y_pred
        #if i==0:
           # name="progress asymptotic iteration:"+str(i)+" "
           # visualisation(x_train[0].cpu().detach(),epoch,name,False)
        #if i%5==1:
            #name="progress asymptotic iteration:"+str(i)+" "
            #visualisation(x_train[0].cpu().detach(),epoch,name,False)
        y_pred=model.internals(x_train)
    return x_train,y_pred,model 

def asymptotic_jacobian(model,initial_input,no_of_images,no_of_repetition):
    ave_jac=0
    overall_distribution=np.asarray([])

    jacobian=[]
    sorteds=np.asarray([])
    for j in range(no_of_repetition):
        #print("here")
        x_train=initial_input.to(device)
        y_pred=x_train
        mean_jacobian=0
        for i in range(no_of_images):
            x=x_train[i]
            res=torch.autograd.functional.jacobian(model.internals,x)
            distribution=np.asarray([])
            jacobian.append(res)
            sorted=np.asarray([])
            #if j==no_of_repetition-1:
             #   distribution,sorted=spectral_distribution(res.cpu())
              #  overall_distribution=np.concatenate((overall_distribution,distribution),axis=0)
              #  spectral=spectral_radius(sorted)
              #  sorteds=np.append(sorteds,spectral)

            norm=torch.norm(res).cpu()
            mean_jacobian+=1/np.sqrt(output_size)*norm
        mean_jacobian=mean_jacobian/no_of_images
        ave_jac+=mean_jacobian
    average_jacobian=ave_jac/no_of_repetition
    return average_jacobian,overall_distribution,jacobian,sorteds

def spectral_radius(jacobian,no_of_repetition,no_of_images):
    #result=[]
   
    #output=initial_input.to(device)
   # product=torch.eye(n=input_size,m=output_size).to(device)
    
    spectral=0

    
        
    #res=torch.autograd.functional.jacobian(model.internals,initial_input)
    #product=torch.matmul(product,res)
    #output=model(initial_input)
   # initial_input=output
    
    s,v=torch.linalg.eig(jacobian)
 #   #print(s)
    abs=torch.abs(s)
    
    spectral=torch.max(abs).item()
    return spectral

def poincare_plot(model,initial_input,dimension_vector,no_of_repetition,colour,epoch):
    xt=[]
    xtminus=[]
    
    output=initial_input
    
    for i in range(no_of_repetition):
        
        initial_input=output
        output=model(initial_input)
        
        xt.append(1/output_size*torch.dot(output,dimension_vector).item())
        xtminus.append(1/output_size*torch.dot(initial_input,dimension_vector).item())
    
    return xt,xtminus
  
    


def asymptotic_distance(xinfinity_unperturbed,xinfinity_perturbed,perturbation):
    result=[]
    for i in range(len(xinfinity_unperturbed)):
    
        sum=0
        
        for j in range(len(xinfinity_unperturbed[i])):
            
            temp=np.linalg.norm(xinfinity_unperturbed[i][j]-xinfinity_perturbed[i][j])
            sum+=temp
        
        result.append(1/output_size*1/len(xinfinity_unperturbed[i])*sum) 
    
    return result


def calculation(model,no_of_images,no_of_repetition,ave_jacobian,spectral_radiuses,image,epoch):
    spectral=0
    
    model_clone=AE(input_size,input_size,hidden_state_size,no_of_layer).to(device)
    model_clone.load_state_dict(copy.deepcopy(model.state_dict()))
    distributions=np.asarray([])
    x_train,y_pred,model_clone=iteration(model_clone,image,asymptotic_repetition,epoch)   
    #ave_jac,distributions,jacobian,sorteds= asymptotic_jacobian(model_clone,x_train,no_of_images,no_of_repetition)
    
    #np.savetxt("jacobian epoch"+str(epoch)+".txt",sorteds)
    #print("distribution size")
    #print(distributions.size)
    #print("sorted size")
    #print(sorteds.size)
    #average_jacobian.append(ave_jac)
    #x = [ele.real for ele in distributions]
    ## extract imaginary part
    #y = [ele.imag for ele in distributions]
    #plt.title("real and imaginary part of eigenvalue")
    #plt.scatter(x, y)
    #plt.ylabel('Imaginary')
    #plt.xlabel('Real')
    #plt.xscale("log")
    #plt.yscale("log")
    #plt.xlim(-1,1)
    #plt.ylim(-1,1)
    #plt.savefig("epoch:"+str(epoch+1)+"number of iteration:"+str(no_of_repetition)+"eigenvalue scatter plot.jpg",bbox_inches = 'tight')
    #plt.show()
    #plt.title("modulus of eigenvalue in log log plot ")
    #plt.hist(sorteds, density=True, bins='auto', histtype='stepfilled')
    #plt.yscale("log")
    #plt.xscale("log")

    #plt.savefig("epoch:"+str(epoch+1)+"number of iteration:"+str(no_of_repetition)+"eigenvalue distribution.jpg",bbox_inches = 'tight')
    #plt.show()

   # for i in range(no_of_images):
    
        #spectral+=spectral_radius(sorteds,no_of_repetition,no_of_images)
    #spectral=sorteds.mean()
    
    #spectral_radiuses.append(spectral)
    #print(spectral/no_of_images)
    
    return x_train,y_pred,average_jacobian,spectral_radiuses,model_clone


def asymptotic_iteration(model_new,initial_inputs,perturbed_inputs,no_of_repetition,no_of_image,cutoff):
    
    y_pred_unperturbed=initial_inputs.to(device)
    y_pred_perturbed=perturbed_inputs.to(device)
    #cutoff=[]
   
    #for j in range(no_of_image):
     
    #cutoff.append(torch.norm(y_pred_unperturbed[j]-y_pred_perturbed[j]))
        #print(cutoff[j])
    distance=[]
    hidden_layer=[]
    hiddens=[]
    chaos=0
 
    for i in range(no_of_repetition):
        x_train_unperturbed=y_pred_unperturbed
        y_pred_unperturbed=model_new.internals(x_train_unperturbed)
        
       
        x_train_perturbed=y_pred_perturbed
        y_pred_perturbed=model_new.internals(x_train_perturbed)
        
       # print(y_pred_perturbed,y_pred_unperturbed)
        
        hidden = model.hiddens()
        #print(hidden)
        #print(torch.sum(hidden,dim=1).cpu().detach().numpy()/1000)
        hidden_layer.append(torch.sum(hidden,dim=1)[0].cpu().detach().numpy()/10)
        hiddens.append(torch.sum(hidden,dim=1).cpu().detach().numpy()/10)
        
        #visualisation(y_pred.view(batch_size,-1)[0].cpu().detach(),epoch)


        #diff=0
        diff=torch.zeros(1,device=device)
        temp=0
        #print(len(cutoff))
        for j in range(no_of_image):
            result=torch.norm(y_pred_unperturbed[j]-y_pred_perturbed[j])
            #print(np.isnan(result.cpu().detach().numpy()))
            #print(result)
            if np.isinf(result.cpu().detach().numpy()) or np.isnan(result.cpu().detach().numpy())  :
                result=torch.Tensor([1*10**38]).to(device)
                print("infinity")
            temp=result
            diff*=result**(1/no_of_image)
            
            #print(j)
            if result>cutoff[j] and i==no_of_repetition-1:
                chaos+=1
            if np.isinf(diff.cpu().detach().numpy()) or np.isnan(diff.cpu().detach().numpy()):
                diff=torch.Tensor([1*10**38]).to(device)
                print("infinity")
            #print("asymptotic calculation")
            #print(result.cpu())
            #print(diff.cpu())
            
        if diff.cpu().detach().numpy()<2**-52:
            diff=2**-52
            distance.append(diff)
            continue
        distance.append(diff.cpu().detach().numpy())

    return distance,hidden_layer,chaos/no_of_image

def visualisation(xfinals,epoch,name,bool):
    plt.imshow(xfinals.reshape(N,N), cmap="gray")
    if bool:
        plt.savefig(str(name)+" epoch:"+str(epoch+1)+".jpg")
    plt.show()
    print(str(name)+" epoch:"+str(epoch+1)+".jpg")
    
def divergence(values):
    result=np.abs(values[-1]-values[-2])
    if result>np.abs(values[2]-values[1]):
        return 1
    return 0

def spectral_radius(sorted):
    if len(sorted)==0:
        return 0
    return sorted[0]

def spectral_distribution(input_matrix):
    result=[]
    count=0
    s,v=torch.linalg.eig(input_matrix)
    #return s
    for i in range(len(s)):
        if np.abs(s[i].cpu())<2**-52:
            count+=1
        
    sorted, indices=torch.sort(torch.abs(s),dim=-1,descending=True)
    #for index in indices.cpu():
     #   if index<=len(s)-count:
     #       result.append(s[index])
    #print(sorted)
    return s,sorted[:-count]

# %%
def stats(tensor):
    # Calculate the mean
    mean = torch.mean(tensor)
    # Calculate the variance
    second = torch.mean(torch.pow(tensor,2))
    third = torch.mean(torch.pow(tensor,3))
    fourth=torch.mean(torch.pow(tensor,4))
    # Calculate the standard deviation
    var=torch.var(tensor)
    std = torch.sqrt(var)
    # Calculate the z-scores
    zscores = (tensor - mean) / std
    # Calculate the skewness
    skew = torch.mean(zscores ** 3)
    # Calculate the kurtosis
    kurt = torch.mean(zscores ** 4) - 3
    #Return the results as a tuple
    return mean, second, skew, kurt

# %%
train_set = torchvision.datasets.FashionMNIST("./data", download=True, transform=
                                                transforms.Compose([
    transforms.ToTensor()
]))
test_set = torchvision.datasets.FashionMNIST("./data", download=True, train=False, transform=
                                               transforms.Compose([
    transforms.ToTensor()
]))  
train_loader = torch.utils.data.DataLoader(train_set, 
                                           batch_size=batch_size,shuffle=False)
test_loader = torch.utils.data.DataLoader(test_set,
                                          batch_size=batch_size,shuffle=False)

# %%
pconv = lambda alpha, beta, mu, sigma: (alpha, beta, mu , sigma)
def test_fitstart(value):
    #draw = levy_stable.rvs(alpha, beta, size=points)
    
    # use scipy's quantile estimator to estimate the parameters and convert to S parameterization
    return pconv(*levy_stable._fitstart(value))

# %%
import scipy.stats as st, levy
spectral_radiuses=[]
average_jacobian=[]
xinfinity=[]
xpinfinity=[]
training_loss=[]
validation_loss=[]
asymptotic_dist=[]
epochs=1000
noise_strength=10**-3
perturbation_strength=10**-6
no_of_images=20
no_of_repetition=200
asymptotic_repetition=100
#diverge=[]
file=["relu-1-adam-1-layer","relu-2.5-adam-1-layer","tanh-1-adam-1-layer","tanh-2.5-adam-1-layer"]
#list of file to work on 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("running")
path="/raid/home/sichen/phd-project/new runs/"
start=time.time()
#print("running")
#strength=0.1
#epochs=10
current_file=3
mu=1
dmu=1/epochs

init_compute=True
chao=[]
noise_print=False
repeats=1
average_chaos=[]
first_moment=[]
second_moment=[]
third_moment=[]
fourth_moment=[]
J0=[]
J1=[]
mu=[]
skewness=[]
for i in range(repeats):
    
    chao=[]
    asy_dist=[]
    print(i)
    for epoch in range(epochs+1):
        loss = 0
        #mu+=dmu
        #print(mu)
        model = AE(input_size,output_size,hidden_state_size,no_of_layer).to(device)
        if epoch==0:
            for batch_features, _ in train_loader:
            # reshape mini-batch data to [1000, 784] matrix
            # load it to the active device
                input_image =add_gaussian_noise(batch_features,noise_strength).view(batch_size, -1).to(device)
        
        #model = AE(input_size,output_size,hidden_state_size,no_of_layer).to(device)           
        PATH=path+file[current_file]+"/epoch:"+str(epoch)+".pt"
        if epoch==0:
            print(PATH)
        model.load_state_dict(torch.load(PATH))
        save_image=input_image
        perturbed_inputs=add_gaussian_noise(input_image,perturbation_strength)
        inits=0
        print(epoch)
        print("\n")
        for value in model.parameters():
            
            first,second,third,fourth=stats(value)
            first_moment.append(first.cpu().detach().numpy())
            second_moment.append(second.cpu().detach().numpy())
            third_moment.append(third.cpu().detach().numpy())
            fourth_moment.append(fourth.cpu().detach().numpy())
            print("here")
            result=pl.Fit(np.abs(value.cpu().detach().numpy()).flatten())
            print(result.alpha,result.xmin)
            #print(test_fitstart(value.cpu().detach().numpy().flatten()))
            #alpha,beta,jzero,jone=test_fitstart(value.cpu().detach().numpy().flatten())
            #if shape<=3:
             #   alpha,beta,jzero,jone=levy_stable.fit(value.cpu().detach().numpy().flatten())
              #  print(alpha,beta,jzero,jone)
                #print(draw)
            #else:
            first,second,third,fourth=stats(value)
            mu.append(result.alpha)
            skewness.append(third)
            J0.append(first)
            J1.append(second)
            inits+=1
        cutoff=[]
        for j in range(no_of_images):
            cutoff.append(torch.norm(perturbed_inputs[j]-input_image[j]))
        model_clone=AE(input_size,input_size,hidden_state_size,no_of_layer,mu).to(device)
        model_clone.load_state_dict(copy.deepcopy(model.state_dict()))

        #spectral_radiuses=[]
        x_train_perturbed,y_pred_perturbed,average_jacobian,spectral_radiuses,model_clone=calculation(model,no_of_images,no_of_repetition,average_jacobian,spectral_radiuses,perturbed_inputs,epoch)
        x_train_unperturbed,y_pred_unperturbed,average_jacobian,spectral_radiuses,model_clone=calculation(model,no_of_images,no_of_repetition,average_jacobian,spectral_radiuses,input_image,epoch)

        distance,hidden,chaos=asymptotic_iteration(model_clone,y_pred_unperturbed,y_pred_perturbed,no_of_repetition,no_of_images,cutoff)
          
        asy_dist.append(distance[-1])
        chao.append(chaos)
        #print(ave_jac)
        #mu+=dmu
    print("here\n") 
    np.savetxt("average_chaos"+str(i)+".txt",chao)
    average_chaos.append(chao)
    #print(average_chaos)
    asymptotic_dist.append(asy_dist)
    np.savetxt("asymptotic distance"+str(i)+".txt",asy_dist)


end=time.time()
print(end-start)

#print(chao)
# Out:
# running
# 0
# /raid/home/sichen/phd-project/new runs/tanh-2.5-adam-1-layer/epoch:0.pt
# 0
#
#
# here
# Calculating best minimal value for power law fit
# 127.59869161950348 0.08785287003412032
# here
# Calculating best minimal value for power law fit
# 628.2093348992465 0.7873216414919012
# 1
#
#
# here
# Calculating best minimal value for power law fit
# 10.002768107981172 0.0724856351790653
# here
# Calculating best minimal value for power law fit
# 17.27575609673003 0.9365094135304811
# 2
#
#
# here
# Calculating best minimal value for power law fit
# 10.266102761509362 0.06991790745176096
# here
# Calculating best minimal value for power law fit
# 10.697273532868618 0.8411475292044941
# 3
#
#
# here
# Calculating best minimal value for power law fit
# 8.098780129920804 0.05835741859249295
# here
# Calculating best minimal value for power law fit
# 8.028829076962094 0.7412082261258023
# 4
#
#
# here
# Calculating best minimal value for power law fit
# 7.967486610713303 0.05972269522308678
# here
# Calculating best minimal value for power law fit
# 6.948785939986272 0.7447163599897418
# 5
#
#
# here
# Calculating best minimal value for power law fit
# 4.257539377613529 0.025384438839925368
# here
# Calculating best minimal value for power law fit
# 19.616043726993432 1.1089078124101166
# 6
#
#
# here
# Calculating best minimal value for power law fit
# 4.612333955533213 0.030719814779013224
# here
# Calculating best minimal value for power law fit
# 8.290223313245995 0.8564666449248057
# 7
#
#
# here
# Calculating best minimal value for power law fit
# 3.9884667385509425 0.021072461751629343
# here
# Calculating best minimal value for power law fit
# 9.76916983021291 0.9094993578043533
# 8
#
#
# here
# Calculating best minimal value for power law fit
# 3.7674537563671175 0.01805962461667804
# here
# Calculating best minimal value for power law fit
# 12.02572243362118 1.0000794259211891
# 9
#
#
# here
# Calculating best minimal value for power law fit
# 3.6741230427703933 0.015157006496734071
# here
# Calculating best minimal value for power law fit
# 12.728064574965329 1.0059726959867166
# 10
#
#
# here
# Calculating best minimal value for power law fit
# 3.5622747113447812 0.01428897212193826
# here
# Calculating best minimal value for power law fit
# 20.92411345197686 1.1675678937166771
# 11
#
#
# here
# Calculating best minimal value for power law fit
# 3.3611894839947762 0.01675426615157128
# here
# Calculating best minimal value for power law fit
# 13.472993512405566 1.0364752549808063
# 12
#
#
# here
# Calculating best minimal value for power law fit
# 3.332233749581536 0.011056297334204393
# here
# Calculating best minimal value for power law fit
# 14.91301563274744 1.0721606393978438
# 13
#
#
# here
# Calculating best minimal value for power law fit
# 3.3282616305740085 0.010731930536174519
# here
# Calculating best minimal value for power law fit
# 14.978758894298128 1.0960762565408715
# 14
#
#
# here
# Calculating best minimal value for power law fit
# 3.2951232804569064 0.010344201397390541
# here
# Calculating best minimal value for power law fit
# 14.531390885404155 1.108780700212392
# 15
#
#
# here
# Calculating best minimal value for power law fit
# 3.2486526477280258 0.00954075262825466
# here
# Calculating best minimal value for power law fit
# 14.25388793454156 1.1262703477626077
# 16
#
#
# here
# Calculating best minimal value for power law fit
# 3.2251484286824246 0.00948713392092834
# here
# Calculating best minimal value for power law fit
# 13.476661736164077 1.111513798299343
# 17
#
#
# here
# Calculating best minimal value for power law fit
# 3.1694879291559186 0.008860951789652245
# here
# Calculating best minimal value for power law fit
# 14.321449336539608 1.1621781779603844
# 18
#
#
# here
# Calculating best minimal value for power law fit
# 3.184567422783049 0.00880605785620181
# here
# Calculating best minimal value for power law fit
# 13.493317048295978 1.1314446522414048
# 19
#
#
# here
# Calculating best minimal value for power law fit
# 3.2028053418160005 0.008774436318425184
# here
# Calculating best minimal value for power law fit
# 13.257428432348474 1.1364101782755442
# 20
#
#
# here
# Calculating best minimal value for power law fit
# 3.158013575685215 0.008550012826958069
# here
# Calculating best minimal value for power law fit
# 12.966640747528434 1.1369912476180486
# 21
#
#
# here
# Calculating best minimal value for power law fit
# 3.161392966143665 0.008365930981168309
# here
# Calculating best minimal value for power law fit
# 13.551727577089165 1.1722054028311142
# 22
#
#
# here
# Calculating best minimal value for power law fit
# 3.150117910080091 0.00824873135004261
# here
# Calculating best minimal value for power law fit
# 13.070590054946058 1.1594966952971337
# 23
#
#
# here
# Calculating best minimal value for power law fit
# 3.1175418927251344 0.007890837184900726
# here
# Calculating best minimal value for power law fit
# 13.279819616773121 1.178337340576054
# 24
#
#
# here
# Calculating best minimal value for power law fit
# 3.0921394392026977 0.007700050346255031
# here
# Calculating best minimal value for power law fit
# 13.58984822532522 1.1961498533365282
# 25
#
#
# here
# Calculating best minimal value for power law fit
# 3.088066688991014 0.007648989634479271
# here
# Calculating best minimal value for power law fit
# 13.87901239864393 1.2016208095358274
# 26
#
#
# here
# Calculating best minimal value for power law fit
# 3.1275279259315294 0.007740666781321817
# here
# Calculating best minimal value for power law fit
# 14.189190463991775 1.2077038678602678
# 27
#
#
# here
# Calculating best minimal value for power law fit
# 3.1373319375673234 0.007726990747162591
# here
# Calculating best minimal value for power law fit
# 14.385151632092494 1.2142284151560683
# 28
#
#
# here
# Calculating best minimal value for power law fit
# 3.098898508291924 0.00759407431736423
# here
# Calculating best minimal value for power law fit
# 13.769639688776227 1.2129763765106463
# 29
#
#
# here
# Calculating best minimal value for power law fit
# 3.111858102318715 0.007598451777716328
# here
# Calculating best minimal value for power law fit
# 13.345429550482722 1.2099713395243874
# 30
#
#
# here
# Calculating best minimal value for power law fit
# 3.075395395680705 0.00742754555323678
# here
# Calculating best minimal value for power law fit
# 13.457190753477514 1.2133473688711982
# 31
#
#
# here
# Calculating best minimal value for power law fit
# 3.111679090249612 0.007649947079737985
# here
# Calculating best minimal value for power law fit
# 13.19222257205413 1.216078534434507
# 32
#
#
# here
# Calculating best minimal value for power law fit
# 3.055450204848397 0.007241076326820085
# here
# Calculating best minimal value for power law fit
# 16.493143699170126 1.324792484437709
# 33
#
#
# here
# Calculating best minimal value for power law fit
# 3.1232242810381714 0.0075991617497740485
# here
# Calculating best minimal value for power law fit
# 16.097997295717093 1.3041731965148375
# 34
#
#
# here
# Calculating best minimal value for power law fit
# 3.1027520988235384 0.007476092543257092
# here
# Calculating best minimal value for power law fit
# 16.31888357578114 1.30973429186286
# 35
#
#
# here
# Calculating best minimal value for power law fit
# 3.0494221923166176 0.007260687857173563
# here
# Calculating best minimal value for power law fit
# 15.810469016250817 1.3012641203562971
# 36
#
#
# here
# Calculating best minimal value for power law fit
# 3.0656615701423275 0.007282344779283663
# here
# Calculating best minimal value for power law fit
# 15.330773781652903 1.2957335808414305
# 37
#
#
# here
# Calculating best minimal value for power law fit
# 3.0606519555575584 0.0072669734011140946
# here
# Calculating best minimal value for power law fit
# 15.737047239166147 1.3009253378316317
# 38
#
#
# here
# Calculating best minimal value for power law fit
# 3.081119461810497 0.007380955145018839
# here
# Calculating best minimal value for power law fit
# 15.793562238528375 1.3024332288707436
# 39
#
#
# here
# Calculating best minimal value for power law fit
# 3.05192198315344 0.007094902345958681
# here
# Calculating best minimal value for power law fit
# 16.102584531016277 1.305455400272456
# 40
#
#
# here
# Calculating best minimal value for power law fit
# 3.0637828296191 0.0072164544361503595
# here
# Calculating best minimal value for power law fit
# 15.595732734035021 1.3046873024965107
# 41
#
#
# here
# Calculating best minimal value for power law fit
# 3.059345788754016 0.007194055484066976
# here
# Calculating best minimal value for power law fit
# 16.19315746588276 1.3156099270640893
# 42
#
#
# here
# Calculating best minimal value for power law fit
# 3.0596694742944868 0.007155861949085758
# here
# Calculating best minimal value for power law fit
# 15.425247338492802 1.3132585028731592
# 43
#
#
# here
# Calculating best minimal value for power law fit
# 3.0575656738642802 0.007083250814255408
# here
# Calculating best minimal value for power law fit
# 10.139271966079402 1.1290408282569555
# 44
#
#
# here
# Calculating best minimal value for power law fit
# 3.0415126699141117 0.006942080109584955
# here
# Calculating best minimal value for power law fit
# 10.256351819752618 1.1350605920546954
# 45
#
#
# here
# Calculating best minimal value for power law fit
# 3.050651854645512 0.006978993009106046
# here
# Calculating best minimal value for power law fit
# 10.284048687312788 1.1355278419662287
# 46
#
#
# here
# Calculating best minimal value for power law fit
# 3.1023920889820635 0.007395700977710225
# here
# Calculating best minimal value for power law fit
# 10.190671112058995 1.1359467766320295
# 47
#
#
# here
# Calculating best minimal value for power law fit
# 3.0359994877851184 0.006943433531063602
# here
# Calculating best minimal value for power law fit
# 10.079778119170706 1.1370831579135205
# 49
#
#
# here
# Calculating best minimal value for power law fit
# 3.0457114094663935 0.006991963592947303
# here
# Calculating best minimal value for power law fit
# 10.177166869680773 1.1487389204028877
# 50
#
#
# here
# Calculating best minimal value for power law fit
# 3.050456096283107 0.006961756439017549
# here
# Calculating best minimal value for power law fit
# 10.59376974351698 1.1620065646320954
# 51
#
#
# here
# Calculating best minimal value for power law fit
# 3.0816466367253983 0.007140416808951016
# here
# Calculating best minimal value for power law fit
# 10.513514719833637 1.1705523279293848
# 52
#
#
# here
# Calculating best minimal value for power law fit
# 3.0555260079469195 0.00693138399434084
# here
# Calculating best minimal value for power law fit
# 10.473587048316228 1.1718752545337934
# 53
#
#
# here
# Calculating best minimal value for power law fit
# 3.0815787360128204 0.0070901169886846485
# here
# Calculating best minimal value for power law fit
# 10.575311766954611 1.1763926692794207
# 54
#
#
# here
# Calculating best minimal value for power law fit
# 3.023211035728017 0.006819948260267043
# here
# Calculating best minimal value for power law fit
# 10.461996964857681 1.174731994950171
# 55
#
#
# here
# Calculating best minimal value for power law fit
# 3.0724841042203472 0.007169531919795966
# here
# Calculating best minimal value for power law fit
# 10.644516478463812 1.181709568199347
# 56
#
#
# here
# Calculating best minimal value for power law fit
# 3.065003339430789 0.007104671342896317
# here
# Calculating best minimal value for power law fit
# 10.517375602997017 1.1804173693613653
# 57
#
#
# here
# Calculating best minimal value for power law fit
# 3.0448879870036936 0.006972362685104646
# here
# Calculating best minimal value for power law fit
# 10.331880540823343 1.1769712656780646
# 58
#
#
# here
# Calculating best minimal value for power law fit
# 3.039592489425002 0.0069715542644873275
# here
# Calculating best minimal value for power law fit
# 17.97782295083056 1.4303749424833263
# 59
#
#
# here
# Calculating best minimal value for power law fit
# 3.052132284585267 0.0070363104222733765
# here
# Calculating best minimal value for power law fit
# 10.263800122885065 1.1781248325668878
# 60
#
#
# here
# Calculating best minimal value for power law fit
# 3.0659229476035814 0.007212361552667172
# here
# Calculating best minimal value for power law fit
# 10.183429440780829 1.1802135853663194
# 61
#
#
# here
# Calculating best minimal value for power law fit
# 3.031974257083046 0.006951283278363927
# here
# Calculating best minimal value for power law fit
# 10.07479204649415 1.1789493230833599
# 62
#
#
# here
# Calculating best minimal value for power law fit
# 3.0448130685856913 0.007008195796286461
# here
# Calculating best minimal value for power law fit
# 10.039175079312558 1.1780642117567912
# 63
#
#
# here
# Calculating best minimal value for power law fit
# 3.049433437735897 0.006992217426956899
# here
# Calculating best minimal value for power law fit
# 9.92440329708627 1.1753062542832273
# 64
#
#
# here
# Calculating best minimal value for power law fit
# 3.0570781689217723 0.007038507754608839
# here
# Calculating best minimal value for power law fit
# 9.79008557799651 1.1693716613907863
# 65
#
#
# here
# Calculating best minimal value for power law fit
# 3.0588463220998765 0.007113344887871731
# here
# Calculating best minimal value for power law fit
# 9.610952852597524 1.167620868990281
# 66
#
#
# here
# Calculating best minimal value for power law fit
# 3.0458174162751654 0.00708177473897797
# here
# Calculating best minimal value for power law fit
# 9.461621198970164 1.1613165490061426
# 67
#
#
# here
# Calculating best minimal value for power law fit
# 3.0390601896081115 0.007064627361560834
# here
# Calculating best minimal value for power law fit
# 9.323526920174405 1.1553093553568585
# 68
#
#
# here
# Calculating best minimal value for power law fit
# 3.0757099781008566 0.0072795003103860645
# here
# Calculating best minimal value for power law fit
# 9.294324539179993 1.153850371842006
# 69
#
#
# here
# Calculating best minimal value for power law fit
# 3.0244801344750774 0.006961991848664279
# here
# Calculating best minimal value for power law fit
# 9.236621613152597 1.1545483633482496
# 70
#
#
# here
# Calculating best minimal value for power law fit
# 3.024801821576597 0.00694609384184011
# here
# Calculating best minimal value for power law fit
# 11.015233438273153 1.2919610530528458
# 71
#
#
# here
# Calculating best minimal value for power law fit
# 3.040672901606382 0.006998906206794095
# here
# Calculating best minimal value for power law fit
# 9.482566684547672 1.1715282411203767
# 72
#
#
# here
# Calculating best minimal value for power law fit
# 3.089877484717138 0.007326253212308363
# here
# Calculating best minimal value for power law fit
# 8.976284074934012 1.1430679062738542
# 73
#
#
# here
# Calculating best minimal value for power law fit
# 3.08937457200329 0.0073175182572157585
# here
# Calculating best minimal value for power law fit
# 8.992926502950143 1.158804111164452
# 74
#
#
# here
# Calculating best minimal value for power law fit
# 3.0395914243965945 0.006982705003242795
# here
# Calculating best minimal value for power law fit
# 8.798181717173284 1.13790113524541
# 75
#
#
# here
# Calculating best minimal value for power law fit
# 3.0798162537749425 0.007257800182487285
# here
# Calculating best minimal value for power law fit
# 8.75512048785969 1.1374446955356536
# 76
#
#
# here
# Calculating best minimal value for power law fit
# 3.082873152552059 0.007220254550020785
# here
# Calculating best minimal value for power law fit
# 8.604494522212192 1.127424244066891
# 77
#
#
# here
# Calculating best minimal value for power law fit
# 3.0866401569321633 0.0072678140490850095
# here
# Calculating best minimal value for power law fit
# 8.542774587663043 1.1242474752600955
# 78
#
#
# here
# Calculating best minimal value for power law fit
# 3.0767240432341048 0.007166576862806587
# here
# Calculating best minimal value for power law fit
# 8.474382741335358 1.1209329307609233
# 79
#
#
# here
# Calculating best minimal value for power law fit
# 3.078321091719376 0.007224452556707376
# here
# Calculating best minimal value for power law fit
# 8.495441129919094 1.1261020357207117
# 80
#
#
# here
# Calculating best minimal value for power law fit
# 3.0494183960695267 0.0070423197563957984
# here
# Calculating best minimal value for power law fit
# 8.53927767454238 1.1305795645177337
# 81
#
#
# here
# Calculating best minimal value for power law fit
# 3.047401010950667 0.007003932618991323
# here
# Calculating best minimal value for power law fit
# 8.451253194009887 1.130014533679123
# 82
#
#
# here
# Calculating best minimal value for power law fit
# 3.045941155198726 0.006990580930915412
# here
# Calculating best minimal value for power law fit
# 8.372360031562597 1.1340633341239006
# 83
#
#
# here
# Calculating best minimal value for power law fit
# 3.037499839471669 0.006980802482089816
# here
# Calculating best minimal value for power law fit
# 8.329102379634758 1.1357106271087611
# 84
#
#
# here
# Calculating best minimal value for power law fit
# 3.048835355873666 0.007092451858519813
# here
# Calculating best minimal value for power law fit
# 8.593228460731037 1.1463679552557646
# 85
#
#
# here
# Calculating best minimal value for power law fit
# 3.08247830510232 0.0073294981269747175
# here
# Calculating best minimal value for power law fit
# 8.517859600355083 1.1475083237931636
# 86
#
#
# here
# Calculating best minimal value for power law fit
# 3.058488659534342 0.0071349907896980464
# here
# Calculating best minimal value for power law fit
# 8.654927236054203 1.1585012579706677
# 87
#
#
# here
# Calculating best minimal value for power law fit
# 3.052603694290209 0.007135518331952824
# here
# Calculating best minimal value for power law fit
# 8.719358608765742 1.1662407412215514
# 88
#
#
# here
# Calculating best minimal value for power law fit
# 3.036083008980968 0.007142614072394654
# here
# Calculating best minimal value for power law fit
# 8.648580917556064 1.1656712804379339
# 89
#
#
# here
# Calculating best minimal value for power law fit
# 3.0568685366523267 0.007195007124251193
# here
# Calculating best minimal value for power law fit
# 8.459301106525073 1.1632500953433502
# 90
#
#
# here
# Calculating best minimal value for power law fit
# 3.065878160960599 0.0073323292416299975
# here
# Calculating best minimal value for power law fit
# 7.952546536316392 1.1268176000140637
# 91
#
#
# here
# Calculating best minimal value for power law fit
# 3.0474139364752895 0.007182465855004113
# here
# Calculating best minimal value for power law fit
# 8.245946281320743 1.1499317866213132
# 92
#
#
# here
# Calculating best minimal value for power law fit
# 3.045875216603677 0.007289505218122469
# here
# Calculating best minimal value for power law fit
# 7.87098352840197 1.1322900226237453
# 93
#
#
# here
# Calculating best minimal value for power law fit
# 3.039572291359531 0.0072414993124919926
# here
# Calculating best minimal value for power law fit
# 7.781529251148826 1.1280987070469386
# 94
#
#
# here
# Calculating best minimal value for power law fit
# 3.0306280504828926 0.0072547124564564126
# here
# Calculating best minimal value for power law fit
# 7.700377070283505 1.1214136790260276
# 95
#
#
# here
# Calculating best minimal value for power law fit
# 3.0360603959805625 0.007253021266341382
# here
# Calculating best minimal value for power law fit
# 7.668342476141261 1.1193829930705406
# 96
#
#
# here
# Calculating best minimal value for power law fit
# 3.0427059622622012 0.007261223855637527
# here
# Calculating best minimal value for power law fit
# 7.655448430179076 1.1245378344328971
# 97
#
#
# here
# Calculating best minimal value for power law fit
# 3.050792496279813 0.007291365699307133
# here
# Calculating best minimal value for power law fit
# 7.660840862797869 1.1288600643668305
# 98
#
#
# here
# Calculating best minimal value for power law fit
# 3.0528357841989195 0.0072870231804342215
# here
# Calculating best minimal value for power law fit
# 7.903757353995622 1.1665289274618733
# 99
#
#
# here
# Calculating best minimal value for power law fit
# 3.041385863159487 0.007259524362149617
# here
# Calculating best minimal value for power law fit
# 7.94687684088533 1.169483499106643
# 100
#
#
# here
# Calculating best minimal value for power law fit
# 3.037272564070141 0.007172438376026195
# here
# Calculating best minimal value for power law fit
# 7.92982771511068 1.1741616814881675
# 101
#
#
# here
# Calculating best minimal value for power law fit
# 3.0353322380906 0.007160834558738995
# here
# Calculating best minimal value for power law fit
# 7.825804217824769 1.165397799561084
# 102
#
#
# here
# Calculating best minimal value for power law fit
# 3.027744238391651 0.007133740278978529
# here
# Calculating best minimal value for power law fit
# 7.7161434961293445 1.1629279942364217
# 103
#
#
# here
# Calculating best minimal value for power law fit
# 3.021641253870552 0.00706918191018167
# here
# Calculating best minimal value for power law fit
# 7.577967281469094 1.1596315980687155
# 104
#
#
# here
# Calculating best minimal value for power law fit
# 3.0126204251343345 0.007050711085221857
# here
# Calculating best minimal value for power law fit
# 7.527553546097116 1.1578050904405113
# 105
#
#
# here
# Calculating best minimal value for power law fit
# 3.0250576277789194 0.007274653095397744
# here
# Calculating best minimal value for power law fit
# 7.666401654150591 1.173568824507942
# 106
#
#
# here
# Calculating best minimal value for power law fit
# 3.0071195464833362 0.007008632807948082
# here
# Calculating best minimal value for power law fit
# 7.516956249917356 1.170713363987714
# 107
#
#
# here
# Calculating best minimal value for power law fit
# 3.025793969395966 0.0071057663146361204
# here
# Calculating best minimal value for power law fit
# 7.395949307527528 1.1643993227442424
# 108
#
#
# here
# Calculating best minimal value for power law fit
# 3.0545985608969923 0.0073353751193705975
# here
# Calculating best minimal value for power law fit
# 7.33752264753201 1.161436217839167
# 109
#
#
# here
# Calculating best minimal value for power law fit
# 3.0682268855058332 0.0073987721263455595
# here
# Calculating best minimal value for power law fit
# 7.318114230349574 1.1629711799907345
# 110
#
#
# here
# Calculating best minimal value for power law fit
# 3.0264651995798753 0.007250809325341937
# here
# Calculating best minimal value for power law fit
# 7.255072829593823 1.162378988594473
# 111
#
#
# here
# Calculating best minimal value for power law fit
# 3.0293680867700044 0.007246155235247903
# here
# Calculating best minimal value for power law fit
# 7.3685211913112205 1.1703671212383955
# 112
#
#
# here
# Calculating best minimal value for power law fit
# 3.0529603505467584 0.007395811998253974
# here
# Calculating best minimal value for power law fit
# 5.517538562524318 0.8880329601428752
# 113
#
#
# here
# Calculating best minimal value for power law fit
# 3.093705370334762 0.007658662481373654
# here
# Calculating best minimal value for power law fit
# 7.011341686957754 1.1470483817824262
# 114
#
#
# here
# Calculating best minimal value for power law fit
# 3.0080789795856138 0.007175482300800249
# here
# Calculating best minimal value for power law fit
# 7.0718562076507245 1.1585058602968878
# 115
#
#
# here
# Calculating best minimal value for power law fit
# 3.014496382525397 0.0071591286655884575
# here
# Calculating best minimal value for power law fit
# 6.991974964335446 1.1597916006032907
# 116
#
#
# here
# Calculating best minimal value for power law fit
# 3.022277629832678 0.00724520402784068
# here
# Calculating best minimal value for power law fit
# 7.046015775015769 1.1645653599308468
# 117
#
#
# here
# Calculating best minimal value for power law fit
# 3.038042512708986 0.007303386381935068
# here
# Calculating best minimal value for power law fit
# 5.4247146744570385 0.8864764166718865
# 118
#
#
# here
# Calculating best minimal value for power law fit
# 3.046658465690101 0.007332905762437371
# here
# Calculating best minimal value for power law fit
# 5.401029227823777 0.8876920276574701
# 119
#
#
# here
# Calculating best minimal value for power law fit
# 3.0153265896945984 0.0071627857106758815
# here
# Calculating best minimal value for power law fit
# 6.870553001926875 1.162946142336503
# 120
#
#
# here
# Calculating best minimal value for power law fit
# 3.0000933544595707 0.006965522639766477
# here
# Calculating best minimal value for power law fit
# 6.8223197493836905 1.1644523374337714
# 121
#
#
# here
# Calculating best minimal value for power law fit
# 3.0529019000546107 0.0073894237157540125
# here
# Calculating best minimal value for power law fit
# 5.350604820463807 0.8903688953283597
# 122
#
#
# here
# Calculating best minimal value for power law fit
# 2.9977042980840993 0.007073491672745924
# here
# Calculating best minimal value for power law fit
# 5.326476051505376 0.8910546753959854
# 123
#
#
# here
# Calculating best minimal value for power law fit
# 3.0121734827291387 0.0071653241426278816
# here
# Calculating best minimal value for power law fit
# 5.293407110043314 0.8899697284559116
# 124
#
#
# here
# Calculating best minimal value for power law fit
# 3.0473049076105183 0.0074059782957010805
# here
# Calculating best minimal value for power law fit
# 5.300329115429123 0.8921253414541133
# 125
#
#
# here
# Calculating best minimal value for power law fit
# 3.0135368848375674 0.00721238882885762
# here
# Calculating best minimal value for power law fit
# 5.241290753582678 0.889462756121069
# 126
#
#
# here
# Calculating best minimal value for power law fit
# 3.0425156750908715 0.0073661035148037835
# here
# Calculating best minimal value for power law fit
# 5.207534048810916 0.8892878213564
# 127
#
#
# here
# Calculating best minimal value for power law fit
# 3.038608923719898 0.007339437282269593
# here
# Calculating best minimal value for power law fit
# 5.167890806192349 0.8881427649210711
# 128
#
#
# here
# Calculating best minimal value for power law fit
# 3.0584197645368856 0.007482390376710689
# here
# Calculating best minimal value for power law fit
# 5.1714674625869 0.8940933014557266
# 129
#
#
# here
# Calculating best minimal value for power law fit
# 3.0691556548636116 0.00752438904867526
# here
# Calculating best minimal value for power law fit
# 5.290957228607837 0.9093755435360945
# 130
#
#
# here
# Calculating best minimal value for power law fit
# 3.0421763150376293 0.007259651811404768
# here
# Calculating best minimal value for power law fit
# 5.071085536137112 0.8806248747494294
# 131
#
#
# here
# Calculating best minimal value for power law fit
# 3.0686947078251268 0.007504722657983111
# here
# Calculating best minimal value for power law fit
# 5.0499168392934095 0.8811165848992831
# 132
#
#
# here
# Calculating best minimal value for power law fit
# 3.02727430993566 0.007228832544606932
# here
# Calculating best minimal value for power law fit
# 5.02543054902434 0.8803855903370804
# 133
#
#
# here
# Calculating best minimal value for power law fit
# 3.033458618621561 0.00713222443476096
# here
# Calculating best minimal value for power law fit
# 4.925879613576641 0.8506002618040125
# 134
#
#
# here
# Calculating best minimal value for power law fit
# 3.033264595424222 0.0071163834445947165
# here
# Calculating best minimal value for power law fit
# 4.962393017000849 0.8746880151666204
# 135
#
#
# here
# Calculating best minimal value for power law fit
# 3.047995076260423 0.007208064790118491
# here
# Calculating best minimal value for power law fit
# 4.923918664349003 0.8713459599038881
# 136
#
#
# here
# Calculating best minimal value for power law fit
# 3.0399847473312374 0.007190333037426876
# here
# Calculating best minimal value for power law fit
# 4.816084054359115 0.8364925137835948
# 137
#
#
# here
# Calculating best minimal value for power law fit
# 3.0454113543654873 0.007357329822213802
# here
# Calculating best minimal value for power law fit
# 4.747666584689142 0.8229822209346653
# 138
#
#
# here
# Calculating best minimal value for power law fit
# 3.0298635165330836 0.007175782297763464
# here
# Calculating best minimal value for power law fit
# 4.735358907604377 0.8269704279138359
# 139
#
#
# here
# Calculating best minimal value for power law fit
# 3.0532793055815213 0.007413859332358148
# here
# Calculating best minimal value for power law fit
# 4.693681904548918 0.8227700824156969
# 140
#
#
# here
# Calculating best minimal value for power law fit
# 3.05567481081547 0.007420565096057815
# here
# Calculating best minimal value for power law fit
# 4.684299918658203 0.8243527367579802
# 141
#
#
# here
# Calculating best minimal value for power law fit
# 3.0619378017710175 0.007513663316668448
# here
# Calculating best minimal value for power law fit
# 4.641292797651577 0.820576131563749
# 142
#
#
# here
# Calculating best minimal value for power law fit
# 3.1200023036064524 0.008035108389527375
# here
# Calculating best minimal value for power law fit
# 4.580666645785069 0.8139048642341343
# 143
#
#
# here
# Calculating best minimal value for power law fit
# 3.0661276478195876 0.007579204328862472
# here
# Calculating best minimal value for power law fit
# 4.518392348555263 0.8064397291834831
# 144
#
#
# here
# Calculating best minimal value for power law fit
# 3.11318269953225 0.00796387195481389
# here
# Calculating best minimal value for power law fit
# 4.475125577529601 0.798719391719357
# 145
#
#
# here
# Calculating best minimal value for power law fit
# 3.0783504910165354 0.007638757711170554
# here
# Calculating best minimal value for power law fit
# 4.468564671089782 0.8020218664969417
# 146
#
#
# here
# Calculating best minimal value for power law fit
# 3.0746696541730913 0.007734019309895107
# here
# Calculating best minimal value for power law fit
# 4.439254676866809 0.7997954506630419
# 147
#
#
# here
# Calculating best minimal value for power law fit
# 3.099270965700397 0.008044431873885373
# here
# Calculating best minimal value for power law fit
# 4.44147237062826 0.8011497861922081
# 148
#
#
# here
# Calculating best minimal value for power law fit
# 3.069064332176659 0.007798542538014438
# here
# Calculating best minimal value for power law fit
# 4.392484554906915 0.7968822597831225
# 149
#
#
# here
# Calculating best minimal value for power law fit
# 3.072072088265692 0.007692390477999216
# here
# Calculating best minimal value for power law fit
# 4.3648781176920215 0.7946890104209547
# 150
#
#
# here
# Calculating best minimal value for power law fit
# 3.0604415700299765 0.007741091726758042
# here
# Calculating best minimal value for power law fit
# 4.35723618388224 0.7953154901606174
# 151
#
#
# here
# Calculating best minimal value for power law fit
# 3.0747389008144266 0.007868217084056807
# here
# Calculating best minimal value for power law fit
# 4.336880710121118 0.7900150912195915
# 152
#
#
# here
# Calculating best minimal value for power law fit
# 3.083889402817419 0.007919466629297186
# here
# Calculating best minimal value for power law fit
# 4.358717620361695 0.806884662655516
# 153
#
#
# here
# Calculating best minimal value for power law fit
# 3.1018237179087063 0.008004013068943399
# here
# Calculating best minimal value for power law fit
# 4.34132231096536 0.8040889495474549
# 154
#
#
# here
# Calculating best minimal value for power law fit
# 3.11029092587243 0.008078295615497619
# here
# Calculating best minimal value for power law fit
# 4.310148148119645 0.7956340281380572
# 155
#
#
# here
# Calculating best minimal value for power law fit
# 3.0711128317693177 0.007888654353654852
# here
# Calculating best minimal value for power law fit
# 4.320422280420093 0.8100286842157246
# 156
#
#
# here
# Calculating best minimal value for power law fit
# 3.110711976637147 0.008028530572433353
# here
# Calculating best minimal value for power law fit
# 4.337223420954929 0.8232391637946055
# 157
#
#
# here
# Calculating best minimal value for power law fit
# 3.1169734471784447 0.00813540017246883
# here
# Calculating best minimal value for power law fit
# 4.320514136848077 0.8256913340268519
# 158
#
#
# here
# Calculating best minimal value for power law fit
# 3.112769805680572 0.008112013033756103
# here
# Calculating best minimal value for power law fit
# 4.2866107822466795 0.8204690881526706
# 159
#
#
# here
# Calculating best minimal value for power law fit
# 3.12640619207422 0.008212905659075953
# here
# Calculating best minimal value for power law fit
# 4.3420930946858896 0.8323311609288544
# 160
#
#
# here
# Calculating best minimal value for power law fit
# 3.148051840071866 0.00837553027494591
# here
# Calculating best minimal value for power law fit
# 4.282243725086319 0.8233286459650659
# 161
#
#
# here
# Calculating best minimal value for power law fit
# 3.118820859663843 0.008097055251839274
# here
# Calculating best minimal value for power law fit
# 4.293051460923835 0.8261411050229408
# 162
#
#
# here
# Calculating best minimal value for power law fit
# 3.0987347683893876 0.007894943445186875
# here
# Calculating best minimal value for power law fit
# 4.252381163447318 0.8220593676769314
# 163
#
#
# here
# Calculating best minimal value for power law fit
# 3.098901457928799 0.007894882816306832
# here
# Calculating best minimal value for power law fit
# 4.216101865551797 0.8165240312512605
# 164
#
#
# here
# Calculating best minimal value for power law fit
# 3.1053886008495524 0.008047081688108155
# here
# Calculating best minimal value for power law fit
# 4.230150505917049 0.820996772147444
# 165
#
#
# here
# Calculating best minimal value for power law fit
# 3.0974906409763947 0.008027930777912452
# here
# Calculating best minimal value for power law fit
# 4.221974103914838 0.8219636532904112
# 166
#
#
# here
# Calculating best minimal value for power law fit
# 3.0960010399341775 0.008066458869626213
# here
# Calculating best minimal value for power law fit
# 4.220186105605807 0.822649873115221
# 167
#
#
# here
# Calculating best minimal value for power law fit
# 3.1506706320462037 0.008766697287835353
# here
# Calculating best minimal value for power law fit
# 4.320170600125167 0.8401710281981589
# 168
#
#
# here
# Calculating best minimal value for power law fit
# 3.1433491019684476 0.008625897222490459
# here
# Calculating best minimal value for power law fit
# 4.238171493787077 0.8268897911751384
# 169
#
#
# here
# Calculating best minimal value for power law fit
# 3.1104430662504328 0.008123777735751724
# here
# Calculating best minimal value for power law fit
# 4.222246751911708 0.8253498529752107
# 170
#
#
# here
# Calculating best minimal value for power law fit
# 3.112995318301455 0.008130326489423727
# here
# Calculating best minimal value for power law fit
# 4.207090403558018 0.8234867044896799
# 171
#
#
# here
# Calculating best minimal value for power law fit
# 3.153706762619307 0.008801690822063609
# here
# Calculating best minimal value for power law fit
# 4.20493743671763 0.8241179875207384
# 172
#
#
# here
# Calculating best minimal value for power law fit
# 3.0999892615514284 0.008174538433375329
# here
# Calculating best minimal value for power law fit
# 4.2965739064096455 0.8407210912305544
# 173
#
#
# here
# Calculating best minimal value for power law fit
# 3.1023119323532775 0.008176681066710696
# here
# Calculating best minimal value for power law fit
# 4.313552091878618 0.8447453002636431
# 174
#
#
# here
# Calculating best minimal value for power law fit
# 3.1190951083225764 0.008244195993612079
# here
# Calculating best minimal value for power law fit
# 4.307571824309883 0.8443481534268409
# 175
#
#
# here
# Calculating best minimal value for power law fit
# 3.1118297859017128 0.008444558099848648
# here
# Calculating best minimal value for power law fit
# 4.216461374301138 0.8278000976687843
# 176
#
#
# here
# Calculating best minimal value for power law fit
# 3.0798865723942908 0.008160831223078582
# here
# Calculating best minimal value for power law fit
# 4.226363476428936 0.8293299718145767
# 177
#
#
# here
# Calculating best minimal value for power law fit
# 3.0705251234176543 0.008095697434728748
# here
# Calculating best minimal value for power law fit
# 4.219167794508538 0.8294816295562031
# 178
#
#
# here
# Calculating best minimal value for power law fit
# 3.084963245727216 0.008109946640719491
# here
# Calculating best minimal value for power law fit
# 4.211919540362021 0.8293073053319453
# 179
#
#
# here
# Calculating best minimal value for power law fit
# 3.0898347979486074 0.008189583814884776
# here
# Calculating best minimal value for power law fit
# 4.217056099222383 0.8311793945652035
# 180
#
#
# here
# Calculating best minimal value for power law fit
# 3.088171995028244 0.008199047381216424
# here
# Calculating best minimal value for power law fit
# 4.20873968603504 0.831262937950989
# 181
#
#
# here
# Calculating best minimal value for power law fit
# 3.091295374019733 0.008257147685084112
# here
# Calculating best minimal value for power law fit
# 4.095579135150688 0.7970659261714627
# 182
#
#
# here
# Calculating best minimal value for power law fit
# 3.092730598320605 0.00819137248093663
# here
# Calculating best minimal value for power law fit
# 4.094460675283671 0.7979392060922849
# 183
#
#
# here
# Calculating best minimal value for power law fit
# 3.0842675692381634 0.008217253790245503
# here
# Calculating best minimal value for power law fit
# 4.095514418693767 0.7990082495133525
# 184
#
#
# here
# Calculating best minimal value for power law fit
# 3.117949448360277 0.008484406590099731
# here
# Calculating best minimal value for power law fit
# 4.084857251904298 0.7980599486781913
# 185
#
#
# here
# Calculating best minimal value for power law fit
# 3.100275338443801 0.008228773621848482
# here
# Calculating best minimal value for power law fit
# 4.087340065495043 0.8002601286903319
# 186
#
#
# here
# Calculating best minimal value for power law fit
# 3.0860323263095832 0.008144703224929798
# here
# Calculating best minimal value for power law fit
# 4.075887792960253 0.7941655814325319
# 187
#
#
# here
# Calculating best minimal value for power law fit
# 3.0936688805481207 0.008266631433915723
# here
# Calculating best minimal value for power law fit
# 4.071090861979423 0.7943680769336128
# 188
#
#
# here
# Calculating best minimal value for power law fit
# 3.0949938097878484 0.008205723127324573
# here
# Calculating best minimal value for power law fit
# 4.060471761317304 0.7937071732098281
# 189
#
#
# here
# Calculating best minimal value for power law fit
# 3.1035818001619453 0.008390257606273797
# here
# Calculating best minimal value for power law fit
# 4.072061742322214 0.7983277736602545
# 190
#
#
# here
# Calculating best minimal value for power law fit
# 3.0923504457777473 0.008189503064772103
# here
# Calculating best minimal value for power law fit
# 4.08807188040886 0.8027159624381728
# 191
#
#
# here
# Calculating best minimal value for power law fit
# 3.087969242749389 0.008244308271449513
# here
# Calculating best minimal value for power law fit
# 4.079015835530861 0.7998143580873284
# 192
#
#
# here
# Calculating best minimal value for power law fit
# 3.0899932075992815 0.008269954973654403
# here
# Calculating best minimal value for power law fit
# 4.051680819234233 0.7960510852787438
# 193
#
#
# here
# Calculating best minimal value for power law fit
# 3.055163554674702 0.007885441952225979
# here
# Calculating best minimal value for power law fit
# 4.040454831074156 0.7932376496249863
# 194
#
#
# here
# Calculating best minimal value for power law fit
# 3.091451244300955 0.00822155048220267
# here
# Calculating best minimal value for power law fit
# 4.0465979153536535 0.7940109660801606
# 195
#
#
# here
# Calculating best minimal value for power law fit
# 3.1026496554523093 0.008389980240579038
# here
# Calculating best minimal value for power law fit
# 4.043677462947338 0.7936741973566327
# 196
#
#
# here
# Calculating best minimal value for power law fit
# 3.0792576911097114 0.008170420021050045
# here
# Calculating best minimal value for power law fit
# 4.029826760803248 0.7920347683822005
# 197
#
#
# here
# Calculating best minimal value for power law fit
# 3.1194575441853725 0.008417896542981425
# here
# Calculating best minimal value for power law fit
# 4.019580659394268 0.7903660616311046
# 198
#
#
# here
# Calculating best minimal value for power law fit
# 3.113690993463534 0.00841409920245674
# here
# Calculating best minimal value for power law fit
# 4.026514986197396 0.7911769736226056
# 199
#
#
# here
# Calculating best minimal value for power law fit
# 3.1110817994223527 0.0084283414815361
# here
# Calculating best minimal value for power law fit
# 4.030102277961213 0.7920579303439523
# 200
#
#
# here
# Calculating best minimal value for power law fit
# 3.031140293814538 0.00772060708466169
# here
# Calculating best minimal value for power law fit
# 4.056833778223426 0.7969190158920149
# 201
#
#
# here
# Calculating best minimal value for power law fit
# 3.073719251929168 0.008126912271823708
# here
# Calculating best minimal value for power law fit
# 4.058841978868925 0.7966466522531189
# 202
#
#
# here
# Calculating best minimal value for power law fit
# 3.0521767669700806 0.00787932036361218
# here
# Calculating best minimal value for power law fit
# 4.0624044454666475 0.7971634539869774
# 203
#
#
# here
# Calculating best minimal value for power law fit
# 3.0495638926833326 0.00788304875081305
# here
# Calculating best minimal value for power law fit
# 4.068479690219375 0.7992392861666585
# 204
#
#
# here
# Calculating best minimal value for power law fit
# 3.075588243490834 0.008313858505441099
# here
# Calculating best minimal value for power law fit
# 4.0720902625678495 0.799773857175253
# 205
#
#
# here
# Calculating best minimal value for power law fit
# 3.0375739746522563 0.007893825515378722
# here
# Calculating best minimal value for power law fit
# 4.0576989215415775 0.7991010051525298
# 206
#
#
# here
# Calculating best minimal value for power law fit
# 3.082697380531503 0.008361283452539477
# here
# Calculating best minimal value for power law fit
# 4.038907723393443 0.7959660827658589
# 207
#
#
# here
# Calculating best minimal value for power law fit
# 3.0435560082515125 0.007893175774462836
# here
# Calculating best minimal value for power law fit
# 4.035873663592678 0.7959325639645104
# 208
#
#
# here
# Calculating best minimal value for power law fit
# 3.0645496594654724 0.008138621736566024
# here
# Calculating best minimal value for power law fit
# 4.015733698388707 0.7936832106295543
# 209
#
#
# here
# Calculating best minimal value for power law fit
# 3.0423176585610014 0.007871406137566773
# here
# Calculating best minimal value for power law fit
# 4.010684015356665 0.7914203516194078
# 210
#
#
# here
# Calculating best minimal value for power law fit
# 3.0309723688022574 0.007842275139806133
# here
# Calculating best minimal value for power law fit
# 4.003162153146789 0.7892786496516293
# 211
#
#
# here
# Calculating best minimal value for power law fit
# 3.0478838912743957 0.007940772317646578
# here
# Calculating best minimal value for power law fit
# 4.025524156017532 0.7961768236423624
# 212
#
#
# here
# Calculating best minimal value for power law fit
# 3.0412673212981067 0.00792880631343718
# here
# Calculating best minimal value for power law fit
# 4.038873255656636 0.7992390323628621
# 213
#
#
# here
# Calculating best minimal value for power law fit
# 3.04259247249786 0.007848965224700424
# here
# Calculating best minimal value for power law fit
# 4.035084934403454 0.7969993907884404
# 214
#
#
# here
# Calculating best minimal value for power law fit
# 3.0290734446095735 0.007835081388076655
# here
# Calculating best minimal value for power law fit
# 4.048142154791803 0.8011018120028621
# 215
#
#
# here
# Calculating best minimal value for power law fit
# 3.026515464926144 0.007805683662278971
# here
# Calculating best minimal value for power law fit
# 4.048190185937663 0.8008913034622086
# 216
#
#
# here
# Calculating best minimal value for power law fit
# 3.0195895946399496 0.007836626102364566
# here
# Calculating best minimal value for power law fit
# 4.04122592913299 0.7987448835785701
# 217
#
#
# here
# Calculating best minimal value for power law fit
# 3.0783351123395746 0.008410677343346634
# here
# Calculating best minimal value for power law fit
# 4.040157161517195 0.7985198281565381
# 218
#
#
# here
# Calculating best minimal value for power law fit
# 3.038777497229835 0.008027167807271751
# here
# Calculating best minimal value for power law fit
# 4.046719021675278 0.8002645665282357
# 219
#
#
# here
# Calculating best minimal value for power law fit
# 3.0641028818605007 0.008327939095306306
# here
# Calculating best minimal value for power law fit
# 4.034472569311083 0.7969487198927647
# 220
#
#
# here
# Calculating best minimal value for power law fit
# 3.025407058005672 0.007987231090493761
# here
# Calculating best minimal value for power law fit
# 4.033122101521302 0.797039951362434
# 221
#
#
# here
# Calculating best minimal value for power law fit
# 3.059094932087585 0.008252635858435916
# here
# Calculating best minimal value for power law fit
# 4.0242805889117985 0.7967505469213556
# 222
#
#
# here
# Calculating best minimal value for power law fit
# 3.029255111995327 0.007928824444439302
# here
# Calculating best minimal value for power law fit
# 4.0299411198078285 0.8026040171410179
# 223
#
#
# here
# Calculating best minimal value for power law fit
# 3.0664806425019147 0.00823175857634037
# here
# Calculating best minimal value for power law fit
# 4.029158650023742 0.8034315640451493
# 224
#
#
# here
# Calculating best minimal value for power law fit
# 3.0856343512499014 0.008306760946692545
# here
# Calculating best minimal value for power law fit
# 4.025287938238629 0.8021921034054954
# 225
#
#
# here
# Calculating best minimal value for power law fit
# 3.0696611814715355 0.008257997555249152
# here
# Calculating best minimal value for power law fit
# 4.033640419581396 0.8087833240395114
# 226
#
#
# here
# Calculating best minimal value for power law fit
# 3.072844622567551 0.008297787413264663
# here
# Calculating best minimal value for power law fit
# 4.02038113775868 0.8059744558094633
# 227
#
#
# here
# Calculating best minimal value for power law fit
# 3.0614598747755157 0.008224627576300011
# here
# Calculating best minimal value for power law fit
# 4.0369076117574485 0.8108490953106312
# 228
#
#
# here
# Calculating best minimal value for power law fit
# 3.065600923493549 0.0081904308563356
# here
# Calculating best minimal value for power law fit
# 4.025188842326331 0.8092517599544657
# 229
#
#
# here
# Calculating best minimal value for power law fit
# 3.0264912649211015 0.00798900935321075
# here
# Calculating best minimal value for power law fit
# 4.030145467244731 0.8113178727513796
# 230
#
#
# here
# Calculating best minimal value for power law fit
# 3.015589253317122 0.008002188682373769
# here
# Calculating best minimal value for power law fit
# 4.028496447082231 0.8109495736950446
# 231
#
#
# here
# Calculating best minimal value for power law fit
# 3.01503437593363 0.00793037978166232
# here
# Calculating best minimal value for power law fit
# 3.9569301951204774 0.7860753632050562
# 232
#
#
# here
# Calculating best minimal value for power law fit
# 3.0423668095070258 0.008145113141397216
# here
# Calculating best minimal value for power law fit
# 3.958072234718205 0.7863421759918424
# 233
#
#
# here
# Calculating best minimal value for power law fit
# 3.031686496235995 0.008071402277826895
# here
# Calculating best minimal value for power law fit
# 3.957408956658842 0.7874005068659036
# 234
#
#
# here
# Calculating best minimal value for power law fit
# 3.0307300150569065 0.00810074092016131
# here
# Calculating best minimal value for power law fit
# 3.9460856762638152 0.7865125092108243
# 235
#
#
# here
# Calculating best minimal value for power law fit
# 3.032320225544051 0.008092452377531272
# here
# Calculating best minimal value for power law fit
# 3.9411351310185765 0.7869141066395199
# 236
#
#
# here
# Calculating best minimal value for power law fit
# 3.0369648672543548 0.008143529359655767
# here
# Calculating best minimal value for power law fit
# 3.9122407107146406 0.7813154840972331
# 237
#
#
# here
# Calculating best minimal value for power law fit
# 3.033600424465503 0.00813757433478711
# here
# Calculating best minimal value for power law fit
# 4.012290928830861 0.8109584501721578
# 238
#
#
# here
# Calculating best minimal value for power law fit
# 3.0368028477526616 0.008155050373320547
# here
# Calculating best minimal value for power law fit
# 3.944277567085836 0.790680820632333
# 239
#
#
# here
# Calculating best minimal value for power law fit
# 3.0492638206923792 0.008214919444500108
# here
# Calculating best minimal value for power law fit
# 3.9572281044721196 0.7937182301879565
# 240
#
#
# here
# Calculating best minimal value for power law fit
# 3.0651496432305008 0.008410054299373844
# here
# Calculating best minimal value for power law fit
# 3.95766293434211 0.7935579360574943
# 241
#
#
# here
# Calculating best minimal value for power law fit
# 3.0475404665023653 0.008214268937939122
# here
# Calculating best minimal value for power law fit
# 3.9539266088365954 0.7922995806708463
# 242
#
#
# here
# Calculating best minimal value for power law fit
# 3.0393618779188247 0.008069473142428734
# here
# Calculating best minimal value for power law fit
# 3.9555429918200953 0.7928994038998392
# 243
#
#
# here
# Calculating best minimal value for power law fit
# 3.0413971078297677 0.008127609437467067
# here
# Calculating best minimal value for power law fit
# 3.9545788422781913 0.7932926115467438
# 244
#
#
# here
# Calculating best minimal value for power law fit
# 3.046360942199349 0.00823818650716687
# here
# Calculating best minimal value for power law fit
# 3.946857569411199 0.7944849153712772
# 245
#
#
# here
# Calculating best minimal value for power law fit
# 3.0431590800002457 0.008191756565756332
# here
# Calculating best minimal value for power law fit
# 3.986760094324437 0.8100926372829476
# 246
#
#
# here
# Calculating best minimal value for power law fit
# 3.056210525402441 0.00824415882557878
# here
# Calculating best minimal value for power law fit
# 3.984086610301086 0.8099954550326469
# 247
#
#
# here
# Calculating best minimal value for power law fit
# 3.0758169250905567 0.008525159804333934
# here
# Calculating best minimal value for power law fit
# 3.9780006756184405 0.8091961919602586
# 248
#
#
# here
# Calculating best minimal value for power law fit
# 3.048085909157195 0.008222983061825999
# here
# Calculating best minimal value for power law fit
# 3.999656453510227 0.8169046818353887
# 249
#
#
# here
# Calculating best minimal value for power law fit
# 3.0500830947864404 0.00825707976928963
# here
# Calculating best minimal value for power law fit
# 4.001043279572263 0.8171787729970379
# 250
#
#
# here
# Calculating best minimal value for power law fit
# 3.0769424183781355 0.008650182914887974
# here
# Calculating best minimal value for power law fit
# 4.005624885525897 0.8184261482639394
# 251
#
#
# here
# Calculating best minimal value for power law fit
# 3.0452402533521434 0.00826088705856637
# here
# Calculating best minimal value for power law fit
# 4.000539223136482 0.8181214173529153
# 252
#
#
# here
# Calculating best minimal value for power law fit
# 3.0579579399653594 0.008455806889440497
# here
# Calculating best minimal value for power law fit
# 4.00157488711136 0.8182943925245463
# 253
#
#
# here
# ...
# here
# Calculating best minimal value for power law fit
# 3.753716024550888 0.7871289311049743
# 621
#
#
# here
# Calculating best minimal value for power law fit
# 3.0958725749958225 0.010419403394845594
# here
# Calculating best minimal value for power law fit
# 3.755047261512907 0.7876027213767594
# 622
#
#
# here
# Calculating best minimal value for power law fit
# 3.1025407292401392 0.01042882630000936
# here
# Calculating best minimal value for power law fit
# 3.7525582978170364 0.7858944935384196
# 623
#
#
# here
# Calculating best minimal value for power law fit
# 3.0858076017568763 0.010394630534550014
# here
# Calculating best minimal value for power law fit
# 3.7549957606160658 0.7861236796224409
# 624
#
#
# here
# Calculating best minimal value for power law fit
# 3.085152646107544 0.010440399341041734
# here
# Calculating best minimal value for power law fit
# 3.756851040424055 0.7862922224053599
# 625
#
#
# here
# Calculating best minimal value for power law fit
# 3.0856593804393606 0.01041220740819256
# here
# Calculating best minimal value for power law fit
# 3.759112269162833 0.7865158904302645
# 626
#
#
# here
# Calculating best minimal value for power law fit
# 2.9503458346365843 0.01670875193708344
# here
# Calculating best minimal value for power law fit
# 3.756213689415894 0.7865925388653305
# 627
#
#
# here
# Calculating best minimal value for power law fit
# 3.0746168384504786 0.010105531323185984
# here
# Calculating best minimal value for power law fit
# 3.756502306865892 0.786597880043802
# 628
#
#
# here
# Calculating best minimal value for power law fit
# 3.0836625530499147 0.010365017263776819
# here
# Calculating best minimal value for power law fit
# 3.756377056104589 0.7865751751186453
# 629
#
#
# here
# Calculating best minimal value for power law fit
# 3.0883551025797122 0.01038197030199342
# here
# Calculating best minimal value for power law fit
# 3.75688088162851 0.7865917320198833
# 630
#
#
# here
# Calculating best minimal value for power law fit
# 3.0868239732330767 0.010510927006144085
# here
# Calculating best minimal value for power law fit
# 3.732525321157502 0.779016525568193
# 631
#
#
# here
# Calculating best minimal value for power law fit
# 3.075686379339029 0.010415433889941386
# here
# Calculating best minimal value for power law fit
# 3.7355297229306825 0.7793043040313248
# 632
#
#
# here
# Calculating best minimal value for power law fit
# 3.0941580915124747 0.010490645682420897
# here
# Calculating best minimal value for power law fit
# 3.7373304923598836 0.779462225810936
# 633
#
#
# here
# Calculating best minimal value for power law fit
# 3.09988419102087 0.010457628717586168
# here
# Calculating best minimal value for power law fit
# 3.7354504065311684 0.7792735125900038
# 634
#
#
# here
# Calculating best minimal value for power law fit
# 3.0929049580927317 0.010462526063162687
# here
# Calculating best minimal value for power law fit
# 3.749930973389974 0.7847499544190889
# 635
#
#
# here
# Calculating best minimal value for power law fit
# 3.1075074165412615 0.010560953789137805
# here
# Calculating best minimal value for power law fit
# 3.7510457583746484 0.7848527557171779
# 636
#
#
# here
# Calculating best minimal value for power law fit
# 3.0726139729049224 0.010128197853250415
# here
# Calculating best minimal value for power law fit
# 3.728651810083278 0.7770832567559351
# 637
#
#
# here
# Calculating best minimal value for power law fit
# 3.0808077156526252 0.010422458466043108
# here
# Calculating best minimal value for power law fit
# 3.720083606907891 0.7744179330617903
# 638
#
#
# here
# Calculating best minimal value for power law fit
# 3.087839541648039 0.01035621748783622
# here
# Calculating best minimal value for power law fit
# 3.722967343595185 0.7754113327915948
# 639
#
#
# here
# Calculating best minimal value for power law fit
# 3.085660286399251 0.010188462382800814
# here
# Calculating best minimal value for power law fit
# 3.7198289172413785 0.775074308172752
# 640
#
#
# here
# Calculating best minimal value for power law fit
# 2.914112405624306 0.01689858901562814
# here
# Calculating best minimal value for power law fit
# 3.7232575645793515 0.7757679038359113
# 641
#
#
# here
# Calculating best minimal value for power law fit
# 3.0796317385355008 0.01048231389076431
# here
# Calculating best minimal value for power law fit
# 3.4141448868141704 0.6440019749863783
# 642
#
#
# here
# Calculating best minimal value for power law fit
# 3.0944551749364355 0.010479578902193377
# here
# Calculating best minimal value for power law fit
# 3.414056695311487 0.6439874298579652
# 643
#
#
# here
# Calculating best minimal value for power law fit
# 3.120733120345838 0.01053493949435099
# here
# Calculating best minimal value for power law fit
# 3.413845593551351 0.6439644338226401
# 644
#
#
# here
# Calculating best minimal value for power law fit
# 3.097398977405821 0.010382646236774604
# here
# Calculating best minimal value for power law fit
# 3.413922904974577 0.6439657271307583
# 645
#
#
# here
# Calculating best minimal value for power law fit
# 3.094903303819026 0.0104632467162412
# here
# Calculating best minimal value for power law fit
# 3.413618656548323 0.6439246289083416
# 646
#
#
# here
# Calculating best minimal value for power law fit
# 3.109987069728979 0.010533298466158105
# here
# Calculating best minimal value for power law fit
# 3.7307804708348162 0.7761465523136645
# 647
#
#
# here
# Calculating best minimal value for power law fit
# 3.0964398739470553 0.010428428464977714
# here
# Calculating best minimal value for power law fit
# 12.948920657528845 1.9823310645572532
# 648
#
#
# here
# Calculating best minimal value for power law fit
# 3.0993889633315104 0.01045953510236873
# here
# Calculating best minimal value for power law fit
# 12.947446727283099 1.9822736717386291
# 649
#
#
# here
# Calculating best minimal value for power law fit
# 3.105967828441677 0.010501871480144217
# here
# Calculating best minimal value for power law fit
# 12.946832048636269 1.9822418825652648
# 650
#
#
# here
# Calculating best minimal value for power law fit
# 3.105749917236908 0.010499644045235223
# here
# Calculating best minimal value for power law fit
# 3.4109533094553264 0.6438363211428917
# 651
#
#
# here
# Calculating best minimal value for power law fit
# 3.0970397963865643 0.010503302162590988
# here
# Calculating best minimal value for power law fit
# 3.411342766666704 0.6436571290323463
# 652
#
#
# here
# Calculating best minimal value for power law fit
# 2.9923505510886232 0.01566832763689986
# here
# Calculating best minimal value for power law fit
# 3.4106805153207502 0.6437826431402848
# 653
#
#
# here
# Calculating best minimal value for power law fit
# 3.1022669105782077 0.01046513274162754
# here
# Calculating best minimal value for power law fit
# 3.4575867559955413 0.6679633306084543
# 654
#
#
# here
# Calculating best minimal value for power law fit
# 3.10757239058027 0.01052521391407222
# here
# Calculating best minimal value for power law fit
# 3.4584062569905965 0.6683305650207588
# 655
#
#
# here
# Calculating best minimal value for power law fit
# 3.0830478877618765 0.010307607539403432
# here
# Calculating best minimal value for power law fit
# 3.460962294870472 0.6686034387678792
# 656
#
#
# here
# Calculating best minimal value for power law fit
# 3.09347893988486 0.010526556564378568
# here
# Calculating best minimal value for power law fit
# 3.4612142978446387 0.6686130422719277
# 657
#
#
# here
# Calculating best minimal value for power law fit
# 3.1011204317055685 0.010504796067756854
# here
# Calculating best minimal value for power law fit
# 3.4617353573996694 0.6686811086025614
# 658
#
#
# here
# Calculating best minimal value for power law fit
# 3.1041555425247362 0.010540440004661788
# here
# Calculating best minimal value for power law fit
# 3.4621694639006195 0.6687124809865731
# 659
#
#
# here
# Calculating best minimal value for power law fit
# 3.1172785296767502 0.010552022164809364
# here
# Calculating best minimal value for power law fit
# 3.4613179257119358 0.6683574500548944
# 660
#
#
# here
# Calculating best minimal value for power law fit
# 3.112712976467407 0.010501660760446752
# here
# Calculating best minimal value for power law fit
# 3.4621411947011995 0.6684309544748641
# 661
#
#
# here
# Calculating best minimal value for power law fit
# 2.946084336536951 0.01748918280733011
# here
# Calculating best minimal value for power law fit
# 3.460769038505138 0.6682965457222594
# 662
#
#
# here
# Calculating best minimal value for power law fit
# 3.094363422915256 0.010338906810396413
# here
# Calculating best minimal value for power law fit
# 3.4602748502251033 0.6679591891411469
# 663
#
#
# here
# Calculating best minimal value for power law fit
# 3.1006724890854955 0.010486051160595302
# here
# Calculating best minimal value for power law fit
# 3.4614933844140094 0.6678323215059541
# 664
#
#
# here
# Calculating best minimal value for power law fit
# 3.0955087323686055 0.010472895052611675
# here
# Calculating best minimal value for power law fit
# 3.46223516589853 0.6684189076744838
# 665
#
#
# here
# Calculating best minimal value for power law fit
# 3.1017781209131075 0.010511700888684698
# here
# Calculating best minimal value for power law fit
# 3.460942698295116 0.6674889174003623
# 666
#
#
# here
# Calculating best minimal value for power law fit
# 3.082453376231152 0.01048288801305692
# here
# Calculating best minimal value for power law fit
# 3.464524606796069 0.6694053908844451
# 667
#
#
# here
# Calculating best minimal value for power law fit
# 3.0946466454035106 0.010462631315273667
# here
# Calculating best minimal value for power law fit
# 3.464794767476985 0.6684008081899536
# 668
#
#
# here
# Calculating best minimal value for power law fit
# 3.104008970787876 0.01052329811661415
# here
# Calculating best minimal value for power law fit
# 3.4644345267441867 0.6683609672851458
# 669
#
#
# here
# Calculating best minimal value for power law fit
# 3.1123094193468024 0.010435721473418402
# here
# Calculating best minimal value for power law fit
# 3.464323819336394 0.6683266412883527
# 670
#
#
# here
# Calculating best minimal value for power law fit
# 3.091299939805714 0.010314502644986446
# here
# Calculating best minimal value for power law fit
# 3.467597879913681 0.6704938641486679
# 671
#
#
# here
# Calculating best minimal value for power law fit
# 3.1007365632369583 0.010415015654977043
# here
# Calculating best minimal value for power law fit
# 3.4681154144393838 0.6705403401999072
# 672
#
#
# here
# Calculating best minimal value for power law fit
# 3.08990153358121 0.010473012914327211
# here
# Calculating best minimal value for power law fit
# 3.4689528381282795 0.6711626886376971
# 673
#
#
# here
# Calculating best minimal value for power law fit
# 2.928192056866514 0.017576334678261866
# here
# Calculating best minimal value for power law fit
# 5.925094692672286 1.346340010093135
# 674
#
#
# here
# Calculating best minimal value for power law fit
# 3.071839372711571 0.01014952114786064
# here
# Calculating best minimal value for power law fit
# 5.928219091902529 1.3464926683218361
# 675
#
#
# here
# Calculating best minimal value for power law fit
# 2.905904748256713 0.017531593575136357
# here
# Calculating best minimal value for power law fit
# 3.476522774002106 0.6735147713447158
# 676
#
#
# here
# Calculating best minimal value for power law fit
# 3.08233402628413 0.010168684532014518
# here
# Calculating best minimal value for power law fit
# 3.4705497211528193 0.6715445075432069
# 677
#
#
# here
# Calculating best minimal value for power law fit
# 3.0787927634620007 0.010257230896827318
# here
# Calculating best minimal value for power law fit
# 3.4764389336166936 0.6732003527141401
# 678
#
#
# here
# Calculating best minimal value for power law fit
# 3.100180084380902 0.010451452747196336
# here
# Calculating best minimal value for power law fit
# 3.47818267278819 0.6736420481403186
# 679
#
#
# here
# Calculating best minimal value for power law fit
# 3.102994162498722 0.010354081520230195
# here
# Calculating best minimal value for power law fit
# 3.47894186298983 0.6737256198827634
# 680
#
#
# here
# Calculating best minimal value for power law fit
# 3.1009891260983573 0.010406793742474364
# here
# Calculating best minimal value for power law fit
# 3.463794858404176 0.6692274484673123
# 681
#
#
# here
# Calculating best minimal value for power law fit
# 3.087766393306053 0.010338407599201313
# here
# Calculating best minimal value for power law fit
# 5.999610599685168 1.3515444954208893
# 682
#
#
# here
# Calculating best minimal value for power law fit
# 3.0808127666684806 0.010210723023751351
# here
# Calculating best minimal value for power law fit
# 5.975702797354887 1.3502113070390016
# 683
#
#
# here
# Calculating best minimal value for power law fit
# 3.088661777486521 0.010353662283201424
# here
# Calculating best minimal value for power law fit
# 5.951974654811732 1.348910234233995
# 684
#
#
# here
# Calculating best minimal value for power law fit
# 3.121171963798378 0.010532904423113642
# here
# Calculating best minimal value for power law fit
# 5.928608240075985 1.3475686661200192
# 685
#
#
# here
# Calculating best minimal value for power law fit
# 3.1201295985912028 0.010562470439289104
# here
# Calculating best minimal value for power law fit
# 5.904755507262139 1.3462539072195105
# 686
#
#
# here
# Calculating best minimal value for power law fit
# 3.102351387356334 0.010236434535739962
# here
# Calculating best minimal value for power law fit
# 3.4671884621261717 0.6680090095729377
# 687
#
#
# here
# Calculating best minimal value for power law fit
# 3.0944370224442177 0.010366625362189595
# here
# Calculating best minimal value for power law fit
# 3.4674437133342333 0.6677510343498316
# 688
#
#
# here
# Calculating best minimal value for power law fit
# 3.093849970958118 0.01041146148033787
# here
# Calculating best minimal value for power law fit
# 3.4673114230718443 0.667723614076259
# 689
#
#
# here
# Calculating best minimal value for power law fit
# 3.091129085382328 0.010390685231240229
# here
# Calculating best minimal value for power law fit
# 3.4633630173411474 0.6667812964032682
# 690
#
#
# here
# Calculating best minimal value for power law fit
# 3.1104006850658292 0.010520696691774316
# here
# Calculating best minimal value for power law fit
# 3.464398907588725 0.666878512288767
# 691
#
#
# here
# Calculating best minimal value for power law fit
# 3.0900542565272184 0.01036442545104415
# here
# Calculating best minimal value for power law fit
# 3.4645945321013887 0.6666353068452759
# 692
#
#
# here
# Calculating best minimal value for power law fit
# 2.998692212834781 0.01532365799196739
# here
# Calculating best minimal value for power law fit
# 3.4505676350082144 0.6613270535271799
# 693
#
#
# here
# Calculating best minimal value for power law fit
# 3.0893114362433565 0.01026454261096324
# here
# Calculating best minimal value for power law fit
# 3.4447798867161383 0.6594315988456304
# 694
#
#
# here
# Calculating best minimal value for power law fit
# 3.0787381970333723 0.010319466468540848
# here
# Calculating best minimal value for power law fit
# 3.447075516899729 0.6599452801931502
# 695
#
#
# here
# Calculating best minimal value for power law fit
# 3.083270133034006 0.010253196990980503
# here
# Calculating best minimal value for power law fit
# 3.44901726468055 0.660118228807941
# 696
#
#
# here
# Calculating best minimal value for power law fit
# 3.087648393793624 0.010154799741645798
# here
# Calculating best minimal value for power law fit
# 3.4508187414157354 0.6603201981888686
# 697
#
#
# here
# Calculating best minimal value for power law fit
# 3.092968702721078 0.010199880657699284
# here
# Calculating best minimal value for power law fit
# 3.452951555447176 0.6605353495120917
# 698
#
#
# here
# Calculating best minimal value for power law fit
# 3.1083382550298353 0.010368822878627487
# here
# Calculating best minimal value for power law fit
# 3.4530189827802733 0.6607884863367016
# 699
#
#
# here
# Calculating best minimal value for power law fit
# 3.115061290600216 0.010313502651685921
# here
# Calculating best minimal value for power law fit
# 3.45963223895082 0.6627545907749617
# 700
#
#
# here
# Calculating best minimal value for power law fit
# 3.092690067637305 0.010410830877464267
# here
# Calculating best minimal value for power law fit
# 3.459798588223121 0.6625034846196022
# 701
#
#
# here
# Calculating best minimal value for power law fit
# 3.0999567626244846 0.010384190979591404
# here
# Calculating best minimal value for power law fit
# 3.4645274507817065 0.6642723594194001
# 702
#
#
# here
# Calculating best minimal value for power law fit
# 3.075704465315085 0.01026145706233691
# here
# Calculating best minimal value for power law fit
# 3.465271228437768 0.6643650110406987
# 703
#
#
# here
# Calculating best minimal value for power law fit
# 3.0868354820977806 0.010090577599012288
# here
# Calculating best minimal value for power law fit
# 3.464262795582564 0.6639828297916651
# 704
#
#
# here
# Calculating best minimal value for power law fit
# xmin progress: 46%

# %%
color=np.arange(1001)
def processing(moment):
    moment=np.asarray(moment)
    moment=moment.reshape(repeats,epochs+1,2)
    #moment=np.mean(moment,axis=0)
    moment=np.abs(moment)
    moment=geometric_mean(moment)
    return moment
def moment_treatment(mu,moment,indicator):
    
    moment=np.asarray(moment)
    moment=moment.reshape(repeats,epochs+1,2)
    #moment=np.mean(moment,axis=0)
    moment=np.abs(moment)
    moment=geometric_mean(moment)
    #if indicator=="first"
        
    plt.scatter(mu.T[0],moment.T[0],c=color)
    plt.ylabel(indicator+" moment")
    plt.xlabel("exponent")
   
    plt.title(indicator+" moment vs exponent graph for t distribution first layer")
    np.savetxt(indicator+" moment vs exponent graph for t distribution layer 1.txt",moment.T[0])
    plt.savefig(path+file[current_file]+indicator+" moment vs exponent graph for t distribution layer 1 test.jpg")
    plt.xscale("log")
    plt.yscale("log")
    plt.show()
    plt.scatter(mu.T[1],moment.T[1],c=color)
    plt.ylabel(indicator+" moment")
    plt.xlabel("exponent")
    plt.yscale("log")
    plt.title(indicator+" moment vs exponent graph for t distribution second layer ")
    np.savetxt(indicator+" moment vs exponent graph for t distribution layer 2test.txt",moment.T[1])
    plt.savefig(path+file[current_file]+indicator+" moment vs exponent graph for t distribution layer 2 test.jpg")
    plt.show()
    
def chaos_treatment(mu,chaos,indicator):
    chaos=np.asarray(chaos)
    if indicator=="asymptotic distance":
        chaos=geometric_mean(chaos)
        print(chaos.size)
    else:
        chaos=np.mean(chaos,axis=0)
    
    
    plt.scatter(mu,chaos,c=color)
    plt.ylabel(indicator)
    plt.xlabel("exponent")
    if indicator=="asymptotic distance":
        print("here")
        plt.yscale("log")
    plt.title(indicator+" vs exponent graph for t distribution ")
    np.savetxt(indicator+" vs exponent graph for t distribution test.txt",chaos)
    plt.savefig(path+file[current_file]+indicator+" vs exponent graph for t distribution test.jpg")
    plt.show()

def geometric_mean(mean):
    result=1
    for i in range(len(mean)):
        result*=mean[i]**(1/len(mean))
    return result

# %%
y=np.arange(1001)
color=np.arange(1001)
mu_1=np.asarray(mu)
mu_2=mu_1.reshape(repeats,epochs+1,2)
mu_value=geometric_mean(mu_2)
skewness_1=np.asarray(skewness)
skewness_2=skewness_1.reshape(repeats,epochs+1,2)
skewness_value=geometric_mean(skewness_2)
moment_treatment(mu_value,first_moment,"first")
moment_treatment(mu_value,second_moment,"second")
moment_treatment(mu_value,third_moment,"third")
moment_treatment(mu_value,fourth_moment,"fourth")

first_moment_1=processing(first_moment)
second_moment_1=processing(second_moment)
result=[]
vertical=[]
for i in range(len(J0)):
    #print(first_moment_1[i]/second_moment_1[i])
    result.append(J0[i]/J1[i])
    vertical.append(1/J1[i])
plt.scatter(mu_value.T[0][mu_value.T[0]<20],y[mu_value.T[0]<20],c=color[mu_value.T[0]<20])
plt.show()
plt.scatter(mu_value.T[1][mu_value.T[1]<20],y[mu_value.T[1]<20],c=color[mu_value.T[1]<20])
plt.xlabel("exponent")
plt.ylabel("skewness")
#plt.xlim([0,10])
plt.xscale('log')
plt.savefig(path+file[current_file]+"exponent vs skewness test.jpg")
plt.show()
result_1=np.asarray(result)
result_2=result_1.reshape(repeats,epochs+1,2)
result_value=geometric_mean(result_2)

vertical_1=np.asarray(vertical)
vertical_2=vertical_1.reshape(repeats,epochs+1,2)
vertical_value=geometric_mean(vertical_2)
plt.scatter(result_value.T[0],vertical_value.T[0],c=color)
plt.xlabel("J0/J1")
plt.ylabel("1/J1")
plt.savefig(path+file[current_file]+"phase diagram first layer test.jpg")
plt.show()
plt.scatter(result_value.T[1],vertical_value.T[1],c=color)
plt.xlabel("J0/J1")
plt.ylabel("1/J1")
plt.savefig(path+file[current_file]+"phase diagram second layer test.jpg")
#print(result)
plt.show()
chaos_treatment(mu_value.T[0],average_chaos,"percentage chaos")
print(np.asarray(asymptotic_dist).size)
chaos_treatment(mu_value.T[0],asymptotic_dist,"asymptotic distance")
# Out:
# 1001
# 1001
# here
