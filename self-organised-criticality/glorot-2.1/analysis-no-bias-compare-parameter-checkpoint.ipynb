# %%
import math
from typing import Any



from torch import Tensor
from torch.nn.parameter import Parameter, UninitializedParameter

from torch.nn import Module
from scipy.stats import pareto 
from torch.distributions.pareto import Pareto
from torch.nn import init
seed=0
import torch
import torchvision
#torch.cuda.is_available()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import confusion_matrix
#from torch.autograd.functional import jacobian
#import torch.autograd.functional
import time
import copy
import matplotlib.pyplot as plt
import pandas as pd
torch.set_default_dtype(torch.float64)
torch.set_default_dtype(torch.float64)
batch_size=100
input_size=784
output_size=784
hidden_state_size=10
N=28
no_of_layer=2

#torch.cuda.manual_seed_all(seed)
with torch.cuda.device('cuda:0'):
    torch.cuda.empty_cache()

# %%
weight_tuning=1
## initial =1
class Linear(Module):
    r"""Applies a linear transformation to the incoming data: :math:`y = xA^T + b`

    This module supports :ref:`TensorFloat32<tf32_on_ampere>`.

    On certain ROCm devices, when using float16 inputs this module will use :ref:`different precision<fp16_on_mi200>` for backward.

    Args:
        in_features: size of each input sample
        out_features: size of each output sample
        bias: If set to ``False``, the layer will not learn an additive bias.
            Default: ``True``

    Shape:
        - Input: :math:`(*, H_{in})` where :math:`*` means any number of
          dimensions including none and :math:`H_{in} = \text{in\_features}`.
        - Output: :math:`(*, H_{out})` where all but the last dimension
          are the same shape as the input and :math:`H_{out} = \text{out\_features}`.

    Attributes:
        weight: the learnable weights of the module of shape
            :math:`(\text{out\_features}, \text{in\_features})`. The values are
            initialized from :math:`\mathcal{U}(-\sqrt{k}, \sqrt{k})`, where
            :math:`k = \frac{1}{\text{in\_features}}`
        bias:   the learnable bias of the module of shape :math:`(\text{out\_features})`.
                If :attr:`bias` is ``True``, the values are initialized from
                :math:`\mathcal{U}(-\sqrt{k}, \sqrt{k})` where
                :math:`k = \frac{1}{\text{in\_features}}`

    Examples::

        >>> m = nn.Linear(20, 30)
        >>> input = torch.randn(128, 20)
        >>> output = m(input)
        >>> print(output.size())
        torch.Size([128, 30])
    """
    __constants__ = ['in_features', 'out_features']
    in_features: int
    out_features: int
    weight: Tensor

    def __init__(self, in_features: int, out_features: int, bias: bool = True,
                 device=None, dtype=None) -> None:
        factory_kwargs = {'device': device, 'dtype': dtype}
        super().__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.weight = Parameter(torch.empty((out_features, in_features), **factory_kwargs))
        if bias:
            self.bias = Parameter(torch.empty(out_features, **factory_kwargs))
        else:
            self.register_parameter('bias', None)
        self.reset_parameters()

    def reset_parameters(self) -> None:
        #if reset=True:
            
        # Setting a=sqrt(5) in kaiming_uniform is the same as initializing with
        # uniform(-1/sqrt(in_features), 1/sqrt(in_features)). For details, see
        # https://github.com/pytorch/pytorch/issues/57109
        #init.kaiming_uniform_(self.weight, a=math.sqrt(5))
        fan_in, _ = init._calculate_fan_in_and_fan_out(self.weight)
        print("fan_in")
        print(fan_in)
        bound =weight_tuning/ math.sqrt(fan_in) 
        init.uniform_(self.weight, -bound,bound)
        if self.bias is not None:
            fan_in, _ = init._calculate_fan_in_and_fan_out(self.bias)
            bound =weight_tuning/ math.sqrt(fan_in) 
            init.uniform_(self.bias, -bound, bound)
            #init.uniform_(self.weight, -bound,bound)
        #fan = _calculate_correct_fan(tensor, mode)
        #gain = calculate_gain(nonlinearity, a)
        #std = gain / math.sqrt(fan)
        #bound = math.sqrt(3.0) * std  # Calculate uniform bounds from standard deviation
        #with torch.no_grad():
            #return tensor.uniform_(-bound, bound)

    def forward(self, input: Tensor) -> Tensor:
        return F.linear(input, self.weight, self.bias)

    def extra_repr(self) -> str:
        return 'in_features={}, out_features={}, bias={}'.format(
            self.in_features, self.out_features, self.bias is not None
        )
    def set_parameter(self,mean, variance):
        
        fan_in, _ = init._calculate_fan_in_and_fan_out(self.weight)
        print("fan_in")
        print(fan_in)
        bound=np.sqrt(3*variance)
        #bound =weight_tuning/ math.sqrt(fan_in) 
        init.uniform_(self.weight, -bound+mean,bound+mean)
        if self.bias is not None:
            #fan_in, _ = init._calculate_fan_in_and_fan_out(self.bias)
            #bound =weight_tuning/ math.sqrt(fan_in) 
            init.uniform_(self.bias, -bound, bound)

# %%
import torch
import torchvision
#torch.cuda.is_available()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import confusion_matrix
#from torch.autograd.functional import jacobian
#import torch.autograd.functional
import time
import copy
import matplotlib.pyplot as plt
import pandas as pd
torch.set_default_dtype(torch.float64)
torch.set_default_dtype(torch.float64)
batch_size=100
input_size=784
output_size=784
hidden_state_size=10
N=28
no_of_layer=2



font = {
        'size'   : 14}
plt.rc('font', **font)

class AE(nn.Module):
    def __init__(self, input_shape,hidden_layer_shape,encoder_output_shape,n,xinit=torch.eye(batch_size,input_size),xfinal=torch.eye(batch_size,input_size),hidden=torch.eye(10,input_size)):
        super().__init__()
        self.encoder_input_layer = Linear(
            in_features=input_shape, out_features=hidden_layer_shape
        ,bias=False)
        self.hidden_layer=Linear(
            in_features=hidden_layer_shape, out_features=hidden_layer_shape
        ,bias=False)
        self.encoder_output_layer = Linear(
            in_features=hidden_layer_shape, out_features=encoder_output_shape
        ,bias=False)
        self.decoder_input_layer = Linear(
            in_features=encoder_output_shape, out_features=hidden_layer_shape
        ,bias=False)
        self.decoder_output_layer = Linear(
            in_features=hidden_layer_shape, out_features=input_shape
        ,bias=False)
        #self.encoder_input_layer.weight=torch.nn.Parameter(torch.rand(self.encoder_input_layer.weight.size))
        
        self.number_of_layers=n
        self.xinit=xinit
        self.xfinal=xfinal
        self.hidden=hidden

    def forward(self, features):
        reconstructed=self.internals(features)
        return reconstructed
    
    def internals(self,features):
        code=self.encoder(features)
        self.hidden=code
        #print(code)
       # print("hidden state maximum:"+str(torch.max(code)))
        reconstructed=self.decoder(code)
        return reconstructed
    
    def encoder(self,features):
        activation = self.encoder_input_layer(features)
        x = torch.relu(activation)
        self.xinit=x
        for i in range(self.number_of_layers):
            x=torch.relu(self.hidden_layer(x))
        code = self.encoder_output_layer(x)
        result = torch.relu(code)
        return code
    
    def decoder(self,code):
        activation = self.decoder_input_layer(code)
        x = torch.relu(activation)
        for i in range(self.number_of_layers):
             x=torch.relu(self.hidden_layer(x))
        self.xfinal=x
        activation = self.decoder_output_layer(x)
        reconstructed = torch.relu(activation)
        return reconstructed
    
    def xfinals(self):
        return self.xfinal
    
    def xinits(self):
        return self.xinit
    
    def hiddens(self):
        return self.hidden

# %%
import torch
import torchvision
#torch.cuda.is_available()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import confusion_matrix
#from torch.autograd.functional import jacobian
#import torch.autograd.functional
import time
import copy
import matplotlib.pyplot as plt
import pandas as pd
torch.set_default_dtype(torch.float64)
torch.set_default_dtype(torch.float64)
batch_size=100
input_size=784
output_size=784
hidden_state_size=10
N=28
no_of_layer=2



font = {
        'size'   : 14}
plt.rc('font', **font)

class AE_1(nn.Module):
    def __init__(self, input_shape,hidden_layer_shape,encoder_output_shape,n,xinit=torch.eye(batch_size,input_size),xfinal=torch.eye(batch_size,input_size),hidden=torch.eye(10,input_size)):
        super().__init__()

        self.encoder_output_layer = Linear(
            in_features=input_shape, out_features=encoder_output_shape
        ,bias=False)
        self.decoder_input_layer = Linear(
            in_features=encoder_output_shape, out_features=input_shape
        ,bias=False)

        #self.encoder_input_layer.weight=torch.nn.Parameter(torch.rand(self.encoder_input_layer.weight.size))
        
        self.number_of_layers=n
        self.xinit=xinit
        self.xfinal=xfinal
        self.hidden=hidden

    def forward(self, features):
        reconstructed=self.internals(features)
        return reconstructed
    
    def internals(self,features):
        code=self.encoder(features)
        self.hidden=code
        #print("hidden state:"+str(code))
        reconstructed=self.decoder(code)
        return reconstructed
    
    def encoder(self,features):
        activation = self.encoder_output_layer(features)
        code = torch.tanh(activation)
     
        return code
    
    def decoder(self,code):
        activation = self.decoder_input_layer(code)
        reconstructed = torch.tanh(activation)

        return reconstructed
    
    def xfinals(self):
        return self.xfinal
    
    def xinits(self):
        return self.xinit
    
    def hiddens(self):
        return self.hidden
    def reset_parameter(self):
        
         self.encoder_output_layer.reset_parameter()
        self.decoder_input_layer .reset_parameter()
# Out:
#   Cell In[1], line 85
#     def reset_parameter（self):
#                        ^
# SyntaxError: invalid character '（' (U+FF08)

# %%
def add_gaussian_noise(inputs,strength):
    #print(inputs.size())
    noise = torch.randn_like(inputs)*strength*torch.max(inputs)
    result=inputs + noise
    return result
def add_powerlaw_noise(input_size,batch_size,strength,images):
    ##input size here is the side of the image 28 
    m = Pareto(torch.tensor([1.0]), torch.tensor([1.0]))
    res=m.sample(images.size())

    temp=res/np.sqrt(res.var())/N/batch_size*strength
    noise=temp-temp.mean()
    #if print_bool:
     #   plt.title(powerlaw_noise print)
      #  plt.hist(noise.flatten(),density=True, bins='auto', histtype='stepfilled')
        
      #  plt.show()
    #print(noise[:,:,:,:,0].size())
    return noise[:,:,0]+images

def validation(test_loader):
    
    with torch.no_grad():

     #valid_loss = criterion(outputs, batch_features.view(batch_size,-1).to(device))
        loss=0
        for batch_features, _ in test_loader:
            #input=add_noise(batch_features,).view(100, -1).to(device)
            input_image=add_gaussian_noise(batch_features,noise_strength).view(batch_size, -1).to(device)
            #batch_feature = batch_features.view(batch_size, -1)
            #input_image =add_powerlaw_noise(input_size,batch_size,noise_strength,batch_feature).view(batch_size, -1).to(device)
            batch_feature = batch_features.view(batch_size, -1).to(device)
            outputs = model(input_image)
            valid_loss = criterion(outputs, input_image.to(device)) 
            #accuracy+=kl_div(outputs,batch_features)/batch_size
            loss += valid_loss.item()
    return loss/len(test_loader)
            
def kl_div(output_image,input_image):
    accuracy=0
    kl_loss = nn.KLDivLoss(reduction="batchmean")
    for i in range(len(input_image)):
        input_spectrum=torch.histogram(input_image[i].cpu(), bins=256, density=True)
        output_spectrum=torch.histogram(output_image[i].cpu(), bins=256, density=True)
        accuracy+=kl_loss(input_spectrum[i],output_spectrum[i])
    return accuracy/len(input_image)

def iteration(model,initial_inputs,no_of_repetition,epoch):
    y_pred=initial_inputs.to(device)
    for i in range(no_of_repetition):
        x_train=y_pred
        #if i==0:
           # name="progress asymptotic iteration:"+str(i)+" "
           # visualisation(x_train[0].cpu().detach(),epoch,name,False)
        #if i%5==1:
            #name="progress asymptotic iteration:"+str(i)+" "
            #visualisation(x_train[0].cpu().detach(),epoch,name,False)
        y_pred=model.internals(x_train)
    return x_train,y_pred,model 

def asymptotic_jacobian(model,initial_input,no_of_images,no_of_repetition):
    ave_jac=0
    overall_distribution=np.asarray([])

    jacobian=[]
    sorteds=np.asarray([])
    for j in range(no_of_repetition):
        #print("here")
        x_train=initial_input.to(device)
        y_pred=x_train
        mean_jacobian=0
        for i in range(no_of_images):
            x=x_train[i]
            res=torch.autograd.functional.jacobian(model.internals,x)
            distribution=np.asarray([])
            jacobian.append(res)
            sorted=np.asarray([])
            #if j==no_of_repetition-1:
             #   distribution,sorted=spectral_distribution(res.cpu())
              #  overall_distribution=np.concatenate((overall_distribution,distribution),axis=0)
              #  spectral=spectral_radius(sorted)
              #  sorteds=np.append(sorteds,spectral)

            norm=torch.norm(res).cpu()
            mean_jacobian+=1/np.sqrt(output_size)*norm
        mean_jacobian=mean_jacobian/no_of_images
        ave_jac+=mean_jacobian
    average_jacobian=ave_jac/no_of_repetition
    return average_jacobian,overall_distribution,jacobian,sorteds

def spectral_radius(jacobian,no_of_repetition,no_of_images):
    #result=[]
   
    #output=initial_input.to(device)
   # product=torch.eye(n=input_size,m=output_size).to(device)
    
    spectral=0

    
        
    #res=torch.autograd.functional.jacobian(model.internals,initial_input)
    #product=torch.matmul(product,res)
    #output=model(initial_input)
   # initial_input=output
    
    s,v=torch.linalg.eig(jacobian)
 #   #print(s)
    abs=torch.abs(s)
    
    spectral=torch.max(abs).item()
    return spectral

def poincare_plot(model,initial_input,dimension_vector,no_of_repetition,colour,epoch):
    xt=[]
    xtminus=[]
    
    output=initial_input
    
    for i in range(no_of_repetition):
        
        initial_input=output
        output=model(initial_input)
        
        xt.append(1/output_size*torch.dot(output,dimension_vector).item())
        xtminus.append(1/output_size*torch.dot(initial_input,dimension_vector).item())
    
    return xt,xtminus
  
    


def asymptotic_distance(xinfinity_unperturbed,xinfinity_perturbed,perturbation):
    result=[]
    for i in range(len(xinfinity_unperturbed)):
    
        sum=0
        
        for j in range(len(xinfinity_unperturbed[i])):
            
            temp=np.linalg.norm(xinfinity_unperturbed[i][j]-xinfinity_perturbed[i][j])
            sum+=temp
        
        result.append(1/output_size*1/len(xinfinity_unperturbed[i])*sum) 
    
    return result


def calculation(model,no_of_images,no_of_repetition,ave_jacobian,spectral_radiuses,image,epoch):
    spectral=0
    
    model_clone=AE(input_size,input_size,hidden_state_size,no_of_layer).to(device)
    model_clone.load_state_dict(copy.deepcopy(model.state_dict()))
    distributions=np.asarray([])
    x_train,y_pred,model_clone=iteration(model_clone,image,asymptotic_repetition,epoch)   
    #ave_jac,distributions,jacobian,sorteds= asymptotic_jacobian(model_clone,x_train,no_of_images,no_of_repetition)
    
    #np.savetxt("jacobian epoch"+str(epoch)+".txt",sorteds)
    #print("distribution size")
    #print(distributions.size)
    #print("sorted size")
    #print(sorteds.size)
    #average_jacobian.append(ave_jac)
    #x = [ele.real for ele in distributions]
    ## extract imaginary part
    #y = [ele.imag for ele in distributions]
    #plt.title("real and imaginary part of eigenvalue")
    #plt.scatter(x, y)
    #plt.ylabel('Imaginary')
    #plt.xlabel('Real')
    #plt.xscale("log")
    #plt.yscale("log")
    #plt.xlim(-1,1)
    #plt.ylim(-1,1)
    #plt.savefig("epoch:"+str(epoch+1)+"number of iteration:"+str(no_of_repetition)+"eigenvalue scatter plot.jpg",bbox_inches = 'tight')
    #plt.show()
    #plt.title("modulus of eigenvalue in log log plot ")
    #plt.hist(sorteds, density=True, bins='auto', histtype='stepfilled')
    #plt.yscale("log")
    #plt.xscale("log")

    #plt.savefig("epoch:"+str(epoch+1)+"number of iteration:"+str(no_of_repetition)+"eigenvalue distribution.jpg",bbox_inches = 'tight')
    #plt.show()

   # for i in range(no_of_images):
    
        #spectral+=spectral_radius(sorteds,no_of_repetition,no_of_images)
    #spectral=sorteds.mean()
    
    #spectral_radiuses.append(spectral)
    #print(spectral/no_of_images)
    
    return x_train,y_pred,average_jacobian,spectral_radiuses,model_clone


def asymptotic_iteration(model_new,initial_inputs,perturbed_inputs,no_of_repetition,no_of_image,cutoff):
    
    y_pred_unperturbed=initial_inputs.to(device)
    y_pred_perturbed=perturbed_inputs.to(device)
    #cutoff=[]
   
    #for j in range(no_of_image):
     
    #cutoff.append(torch.norm(y_pred_unperturbed[j]-y_pred_perturbed[j]))
        #print(cutoff[j])
    distance=[]
    hidden_layer=[]
    hiddens=[]
    chaos=0
 
    for i in range(no_of_repetition):
        x_train_unperturbed=y_pred_unperturbed
        y_pred_unperturbed=model_new.internals(x_train_unperturbed)
        
       
        x_train_perturbed=y_pred_perturbed
        y_pred_perturbed=model_new.internals(x_train_perturbed)
        
       # print(y_pred_perturbed,y_pred_unperturbed)
        
        hidden = model.hiddens()
        #print(hidden)
        #print(torch.sum(hidden,dim=1).cpu().detach().numpy()/1000)
        hidden_layer.append(torch.sum(hidden,dim=1)[0].cpu().detach().numpy()/10)
        hiddens.append(torch.sum(hidden,dim=1).cpu().detach().numpy()/10)
        
        #visualisation(y_pred.view(batch_size,-1)[0].cpu().detach(),epoch)


        #diff=0
        diff=torch.zeros(1,device=device)
        temp=0
        #print(len(cutoff))
        for j in range(no_of_image):
            result=torch.norm(y_pred_unperturbed[j]-y_pred_perturbed[j])
            #print(np.isnan(result.cpu().detach().numpy()))
            #print(result)
            if np.isinf(result.cpu().detach().numpy()) or np.isnan(result.cpu().detach().numpy())  :
                result=torch.Tensor([1*10**38]).to(device)
                print("infinity")
            temp=result
            diff*=result**(1/no_of_image)
            
            #print(j)
            if result>cutoff[j] and i==no_of_repetition-1:
                chaos+=1
            if np.isinf(diff.cpu().detach().numpy()) or np.isnan(diff.cpu().detach().numpy()):
                diff=torch.Tensor([1*10**38]).to(device)
                print("infinity")
            #print("asymptotic calculation")
            #print(result.cpu())
            #print(diff.cpu())
            
        if diff.cpu().detach().numpy()<2**-52:
            diff=2**-52
            distance.append(diff)
            continue
        distance.append(diff.cpu().detach().numpy())

    return distance,hidden_layer,chaos/no_of_image

def visualisation(xfinals,epoch,name,bool):
    plt.imshow(xfinals.reshape(N,N), cmap="gray")
    if bool:
        plt.savefig(str(name)+" epoch:"+str(epoch+1)+".jpg")
    plt.show()
    print(str(name)+" epoch:"+str(epoch+1)+".jpg")
    
def divergence(values):
    result=np.abs(values[-1]-values[-2])
    if result>np.abs(values[2]-values[1]):
        return 1
    return 0

def spectral_radius(sorted):
    if len(sorted)==0:
        return 0
    return sorted[0]

def spectral_distribution(input_matrix):
    result=[]
    count=0
    s,v=torch.linalg.eig(input_matrix)
    #return s
    for i in range(len(s)):
        if np.abs(s[i].cpu())<2**-52:
            count+=1
        
    sorted, indices=torch.sort(torch.abs(s),dim=-1,descending=True)
    #for index in indices.cpu():
     #   if index<=len(s)-count:
     #       result.append(s[index])
    #print(sorted)
    return s,sorted[:-count]

# %%
def stats(tensor):
    # Calculate the mean
    mean = torch.mean(tensor)
    # Calculate the variance
    second = torch.mean(torch.pow(tensor,2))
    third = torch.mean(torch.pow(tensor,3))
    fourth=torch.mean(torch.pow(tensor,4))
    # Calculate the standard deviation
    var=torch.var(tensor)
    std = torch.sqrt(var)
    # Calculate the z-scores
    zscores = (tensor - mean) / std
    # Calculate the skewness
    skew = torch.mean(zscores ** 3)
    # Calculate the kurtosis
    kurt = torch.mean(zscores ** 4) - 3
    print(fourth)
    #Return the results as a tuple
    return mean, second, skew, kurt

# %%
interval=50
no_of_repetition=100
asymptotic_repetition=50
criterion = nn.MSELoss()
noise_strength=10**-3
perturbation_strength=10**-6
import numpy as np  
import matplotlib.pyplot as plt
import torch
no_of_images=20
means=[]
vars=[]
skews=[]
kurtosises=[]
current_file=7
import os
#print(os.getcwd())
file=["relu-1-adam-no-bias","relu-2.5-adam-no-bias","tanh-1-adam-no-bias","tanh-2.5-adam-no-bias","relu-1-adam-1-layer","tanh-1-adam-1-layer","relu-2.5-adam-1-layer","tanh-2.5-adam-1-layer"]
#list of file to work on 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("running")
path="/raid/home/sichen/phd-project/new runs/"
#current working directory
validation_loss=[]
training_loss=[]
asymptotic_dist=[]
epochs=1000
inits=0
moment=["mean","variance","skewness","kurtosis"]
layer=["first","second","third","fourth","fifth"]

for epoch in range(epochs+1):
    model = AE_1(input_size,output_size,hidden_state_size,no_of_layer).to(device)
    PATH=path+file[current_file]+"/epoch:"+str(epoch)+".pt"
    if epoch==0:
        print(PATH)
    model.load_state_dict(torch.load(PATH))
#i=0
    #inits=0
    if epoch=100:
        
    for value in model.parameters():
        print("epoch:")
        print(epoch)
    # Call the function and print the results
        mean, var, skew, kurt = stats(value)
        means.append(mean.cpu().detach().numpy())
        vars.append(var.cpu().detach().numpy())
        skews.append(skew.cpu().detach().numpy())
        kurtosises.append(kurt.cpu().detach().numpy())
        print(mean, var, skew, kurt)
        #print(f"Mean: {mean}")
        #print(f"Variance: {var}")
        #print(f"Skewness: {skew}")
        #print(f"Kurtosis: {kurt}")
        #print("end")

#means=np.resize(means,(10,1000))
x=np.arange(epochs+1)
print("weights")

fig, (ax1, ax2,ax3,ax4) = plt.subplots (nrows=1, ncols=4,figsize=(40,20))
repeats=2
for i in range(repeats):
    #if i%2==0:
        #print(int(i/2))
        ax1.plot(x,means[i::repeats],label=layer[int(i)]+" layer "+moment[0]+" weights")
        ax1.legend(loc="best")
        ax2.plot(x,vars[i::repeats],label=layer[int(i)]+" layer "+moment[1]+" weights")
        ax2.legend(loc="best")
        ax3.plot(x,skews[i::repeats],label=layer[int(i)]+" layer "+moment[2]+" weights")
        ax3.legend(loc="best")
        ax4.plot(x,kurtosises[i::repeats],label=layer[int(i)]+" layer "+moment[3]+" weights")
        ax4.legend(loc="best")
        #plt.show()
    #else:
     #   ax5.plot(x,means[i::10],label=layer[int(i/2)]+" layer "+moment[0]+" bias")
      #  ax5.legend(loc="best")
      #  ax6.plot(x,vars[i::10],label=layer[int(i/2)]+" layer "+moment[1]+" bias")
      #  ax6.legend(loc="best")
      #  ax7.plot(x,skews[i::10],label=layer[int(i/2)]+" layer "+moment[2]+" bias")
      #  ax7.legend(loc="best")
      #  ax8.plot(x,kurtosises[i::10],label=layer[int(i/2)]+" layer "+moment[3]+" bias")
      #  ax8.legend(loc="best")
fig.tight_layout()

plt.savefig(path+file[current_file]+"/"+"new weights(kurtosis-skew).jpg")
np.savetxt(path+file[current_file]+"mean.txt",means)
np.savetxt(path+file[current_file]+"variance.txt",vars)
np.savetxt(path+file[current_file]+"skewness.txt",skews)
np.savetxt(path+file[current_file]+"kurtosis.txt",kurtosises)

plt.show()
# Out:
# running
# fan_in
# 784
# fan_in
# 10
# /raid/home/sichen/phd-project/new runs/tanh-2.5-adam-1-layer/epoch:0.pt
# epoch:
# 0
# tensor(1.2919e-05, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0005, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0027, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.0149, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.2166, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 0
# tensor(0.0779, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0015, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2082, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0071, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.2020, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 1
# tensor(4.4301e-06, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0014, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0351, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.6599, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 1
# tensor(0.0506, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0025, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1462, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.0260, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.6337, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 2
# tensor(2.2588e-06, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0009, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0462, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.2331, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 2
# tensor(0.0484, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0025, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1329, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.0430, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.2612, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 3
# tensor(1.1758e-06, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0006, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0681, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2909, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 3
# tensor(0.0528, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0020, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1303, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.0406, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1083, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 4
# tensor(6.7978e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(5.0380e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0004, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0760, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.1207, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 4
# tensor(0.0590, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0028, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1320, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.0354, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.3831, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 5
# tensor(3.9681e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(3.0957e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1063, device='cuda:0', grad_fn=<MeanBackward0>) tensor(1.8554, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 5
# tensor(0.0648, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0039, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1358, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.0338, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.5104, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 6
# tensor(2.7961e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(6.0623e-06, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0939, device='cuda:0', grad_fn=<MeanBackward0>) tensor(2.9594, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 6
# tensor(0.0703, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0047, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1403, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.0213, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.5685, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 7
# tensor(2.5372e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-4.1893e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0859, device='cuda:0', grad_fn=<MeanBackward0>) tensor(4.7254, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 7
# tensor(0.0754, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0037, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1453, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.0108, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.5733, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 8
# tensor(2.5081e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-1.6226e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1169, device='cuda:0', grad_fn=<MeanBackward0>) tensor(6.7433, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 8
# tensor(0.0798, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0015, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1502, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.0139, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.5362, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 9
# tensor(2.4533e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(2.8451e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0471, device='cuda:0', grad_fn=<MeanBackward0>) tensor(8.7228, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 9
# tensor(0.0842, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0015, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1551, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.0313, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.4989, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 10
# tensor(2.6742e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(7.7611e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0912, device='cuda:0', grad_fn=<MeanBackward0>) tensor(11.3787, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 10
# tensor(0.0897, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0039, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1602, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.0499, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.4950, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 11
# tensor(2.7823e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(8.8095e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0122, device='cuda:0', grad_fn=<MeanBackward0>) tensor(13.2425, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 11
# tensor(0.0960, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0053, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1654, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.0602, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.5123, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 12
# tensor(2.9168e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(9.7971e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.0766, device='cuda:0', grad_fn=<MeanBackward0>) tensor(15.1345, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 12
# tensor(0.1023, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0060, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1702, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.0642, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.5326, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 13
# tensor(2.8798e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(9.3232e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.2459, device='cuda:0', grad_fn=<MeanBackward0>) tensor(17.1404, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 13
# tensor(0.1083, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0064, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1747, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.0653, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.5502, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 14
# tensor(3.2075e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(7.8792e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.4038, device='cuda:0', grad_fn=<MeanBackward0>) tensor(20.0479, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 14
# tensor(0.1139, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0065, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1789, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.0650, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.5644, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 15
# tensor(3.7599e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(6.8251e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.6701, device='cuda:0', grad_fn=<MeanBackward0>) tensor(24.4613, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 15
# tensor(0.1191, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0065, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1826, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.0638, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.5756, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 16
# tensor(3.6130e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(6.3941e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.6723, device='cuda:0', grad_fn=<MeanBackward0>) tensor(24.2551, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 16
# tensor(0.1240, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0065, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1860, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.0622, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.5843, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 17
# tensor(3.7989e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(5.7733e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.7889, device='cuda:0', grad_fn=<MeanBackward0>) tensor(26.1444, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 17
# tensor(0.1284, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0064, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1891, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.0603, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.5911, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 18
# tensor(3.5370e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(6.6398e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.7685, device='cuda:0', grad_fn=<MeanBackward0>) tensor(25.9595, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 18
# tensor(0.1325, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1920, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.0583, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.5961, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 19
# tensor(3.4611e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(6.0296e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.8542, device='cuda:0', grad_fn=<MeanBackward0>) tensor(26.7907, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 19
# tensor(0.1363, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0060, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1946, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.0561, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.5999, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 20
# tensor(3.7936e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(7.1232e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.8798, device='cuda:0', grad_fn=<MeanBackward0>) tensor(29.3640, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 20
# tensor(0.1399, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0058, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1971, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.0539, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6026, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 21
# tensor(3.5208e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(6.5713e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.7493, device='cuda:0', grad_fn=<MeanBackward0>) tensor(28.9985, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 21
# tensor(0.1432, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0056, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1994, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.0515, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6045, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 22
# tensor(3.7394e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(6.5631e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.9527, device='cuda:0', grad_fn=<MeanBackward0>) tensor(31.8254, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 22
# tensor(0.1463, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0054, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2015, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.0491, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6058, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 23
# tensor(4.6057e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(6.0174e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.0593, device='cuda:0', grad_fn=<MeanBackward0>) tensor(37.1755, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 23
# tensor(0.1492, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0052, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2034, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.0466, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6066, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 24
# tensor(4.8600e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(5.7709e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.0231, device='cuda:0', grad_fn=<MeanBackward0>) tensor(39.1155, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 24
# tensor(0.1520, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0049, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2053, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.0442, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6071, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 25
# tensor(4.8415e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(5.9154e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.2239, device='cuda:0', grad_fn=<MeanBackward0>) tensor(39.8378, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 25
# tensor(0.1545, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0047, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2070, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.0416, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6072, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 26
# tensor(4.9470e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(4.4127e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.5144, device='cuda:0', grad_fn=<MeanBackward0>) tensor(42.5195, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 26
# tensor(0.1570, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0045, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2086, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.0390, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6071, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 27
# tensor(4.6606e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(4.7923e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.3792, device='cuda:0', grad_fn=<MeanBackward0>) tensor(41.6527, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 27
# tensor(0.1592, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0042, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2101, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.0364, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6067, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 28
# tensor(4.7655e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(4.9823e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.3587, device='cuda:0', grad_fn=<MeanBackward0>) tensor(41.8286, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 28
# tensor(0.1613, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0040, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2115, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.0337, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6063, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 29
# tensor(4.5218e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(5.5113e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.1164, device='cuda:0', grad_fn=<MeanBackward0>) tensor(40.0942, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 29
# tensor(0.1633, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0038, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2128, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.0309, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6057, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 30
# tensor(4.3083e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(4.6553e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.2446, device='cuda:0', grad_fn=<MeanBackward0>) tensor(39.1048, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 30
# tensor(0.1651, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0035, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2140, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.0281, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6051, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 31
# tensor(4.1237e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(5.0222e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.1660, device='cuda:0', grad_fn=<MeanBackward0>) tensor(37.6806, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 31
# tensor(0.1668, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0033, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2151, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.0254, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6045, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 32
# tensor(3.7747e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(4.3622e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(9.9629e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.2049, device='cuda:0', grad_fn=<MeanBackward0>) tensor(35.0411, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 32
# tensor(0.1684, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0030, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2161, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.0226, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6039, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 33
# tensor(4.2306e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(4.4218e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(9.9622e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.0746, device='cuda:0', grad_fn=<MeanBackward0>) tensor(39.6374, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 33
# tensor(0.1699, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0028, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2171, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.0199, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6032, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 34
# tensor(3.9888e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(5.1466e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(9.9024e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.7496, device='cuda:0', grad_fn=<MeanBackward0>) tensor(37.6858, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 34
# tensor(0.1713, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0026, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2180, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.0171, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6026, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 35
# tensor(3.9645e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(5.3025e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(9.9496e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.8575, device='cuda:0', grad_fn=<MeanBackward0>) tensor(37.0580, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 35
# tensor(0.1726, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0023, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2189, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.0145, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6020, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 36
# tensor(3.8333e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(4.7232e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(9.8270e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.9636, device='cuda:0', grad_fn=<MeanBackward0>) tensor(36.7044, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 36
# tensor(0.1738, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0021, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2196, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.0118, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6015, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 37
# tensor(4.1744e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(4.8914e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.2030, device='cuda:0', grad_fn=<MeanBackward0>) tensor(38.3661, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 37
# tensor(0.1749, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0019, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2204, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.0093, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6010, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 38
# tensor(4.0731e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(4.9429e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(9.9538e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.1278, device='cuda:0', grad_fn=<MeanBackward0>) tensor(38.1238, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 38
# tensor(0.1760, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0016, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2210, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.0068, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6006, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 39
# tensor(4.1703e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(3.9713e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(9.8512e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.3603, device='cuda:0', grad_fn=<MeanBackward0>) tensor(39.9837, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 39
# tensor(0.1770, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0014, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2217, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.0044, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6003, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 40
# tensor(4.2987e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(3.9827e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(9.9989e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.1494, device='cuda:0', grad_fn=<MeanBackward0>) tensor(40.0052, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 40
# tensor(0.1779, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0012, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2223, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.0021, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6001, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 41
# tensor(4.1391e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(4.4381e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(9.9010e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.0047, device='cuda:0', grad_fn=<MeanBackward0>) tensor(39.2316, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 41
# tensor(0.1788, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0010, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2228, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.5999, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 42
# tensor(4.5992e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(4.8742e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(9.8809e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.6402, device='cuda:0', grad_fn=<MeanBackward0>) tensor(44.1101, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 42
# tensor(0.1797, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0008, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2234, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0023, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.5998, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 43
# tensor(4.3196e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(3.3207e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(9.8055e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.1307, device='cuda:0', grad_fn=<MeanBackward0>) tensor(41.9314, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 43
# tensor(0.1805, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0007, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2239, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0043, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.5998, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 44
# tensor(3.7935e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(4.8414e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(9.5743e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.0698, device='cuda:0', grad_fn=<MeanBackward0>) tensor(38.3963, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 44
# tensor(0.1812, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0005, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2243, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0063, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6000, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 45
# tensor(3.6972e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(4.3640e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(9.5178e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.2677, device='cuda:0', grad_fn=<MeanBackward0>) tensor(37.8269, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 45
# tensor(0.1820, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2248, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0082, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6004, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 46
# tensor(4.0894e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(3.3479e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(9.7823e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.4540, device='cuda:0', grad_fn=<MeanBackward0>) tensor(39.7434, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 46
# tensor(0.1827, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2252, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0101, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6008, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 47
# tensor(4.3002e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(3.2336e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(9.9117e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.4228, device='cuda:0', grad_fn=<MeanBackward0>) tensor(40.7790, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 47
# tensor(0.1834, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-4.4406e-06, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2256, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0118, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6014, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 48
# tensor(4.1065e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(4.0521e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(9.8765e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.2990, device='cuda:0', grad_fn=<MeanBackward0>) tensor(39.1103, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 48
# tensor(0.1840, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2260, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0135, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6021, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# tensor(4.4334e-07)
# (tensor(2.3802e-05), tensor(0.0001), tensor(-1.5300), tensor(41.3270))
# 7840
# tensor(0.1846)
# (tensor(-0.0003), tensor(0.2263), tensor(0.0151), tensor(0.6030))
# 7840
# separation
# epoch:
# 49
# tensor(4.4334e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(2.3802e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.5300, device='cuda:0', grad_fn=<MeanBackward0>) tensor(41.3270, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 49
# tensor(0.1846, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2263, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0151, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6030, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 50
# tensor(4.4810e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(2.5437e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(9.9176e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.5796, device='cuda:0', grad_fn=<MeanBackward0>) tensor(42.5624, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 50
# tensor(0.1852, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0004, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2267, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0167, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6040, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 51
# tensor(3.9410e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(2.0176e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(9.6442e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.4525, device='cuda:0', grad_fn=<MeanBackward0>) tensor(39.3733, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 51
# tensor(0.1858, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0006, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2270, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0181, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6052, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 52
# tensor(3.8481e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(2.2495e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(9.6281e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.3185, device='cuda:0', grad_fn=<MeanBackward0>) tensor(38.5129, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 52
# tensor(0.1863, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0007, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2273, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0196, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6066, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 53
# tensor(4.0956e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(3.1784e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(9.7134e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.3748, device='cuda:0', grad_fn=<MeanBackward0>) tensor(40.4159, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 53
# tensor(0.1869, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0008, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2276, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0209, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6082, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 54
# tensor(3.9978e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(3.0502e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(9.7703e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.2428, device='cuda:0', grad_fn=<MeanBackward0>) tensor(38.8843, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 54
# tensor(0.1874, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0009, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2278, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0222, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6100, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 55
# tensor(4.2190e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(4.1384e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(9.8700e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.1990, device='cuda:0', grad_fn=<MeanBackward0>) tensor(40.3198, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 55
# tensor(0.1879, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0010, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2281, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0233, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6119, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 56
# tensor(4.3187e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(3.7252e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(9.9041e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.2681, device='cuda:0', grad_fn=<MeanBackward0>) tensor(41.0364, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 56
# tensor(0.1884, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0011, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2283, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0245, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6139, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 57
# tensor(4.5738e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(3.5191e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(9.9852e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.6381, device='cuda:0', grad_fn=<MeanBackward0>) tensor(42.8857, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 57
# tensor(0.1889, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0012, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2285, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0256, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6162, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 58
# tensor(4.7574e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(3.2706e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.6674, device='cuda:0', grad_fn=<MeanBackward0>) tensor(44.3351, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 58
# tensor(0.1894, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0013, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2288, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0265, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6186, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 59
# tensor(5.0383e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(4.1434e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.7045, device='cuda:0', grad_fn=<MeanBackward0>) tensor(46.0980, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 59
# tensor(0.1899, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0014, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2290, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0275, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6212, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 60
# tensor(4.7321e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(4.5840e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.6550, device='cuda:0', grad_fn=<MeanBackward0>) tensor(43.7829, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 60
# tensor(0.1904, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0015, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2292, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0284, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6240, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 61
# tensor(4.6245e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(4.5298e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.4947, device='cuda:0', grad_fn=<MeanBackward0>) tensor(42.9573, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 61
# tensor(0.1908, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0016, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2293, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0292, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6270, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 62
# tensor(4.5008e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(3.7007e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.4017, device='cuda:0', grad_fn=<MeanBackward0>) tensor(41.8230, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 62
# tensor(0.1913, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0016, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2295, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0299, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6302, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 63
# tensor(4.9137e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(3.8601e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.3494, device='cuda:0', grad_fn=<MeanBackward0>) tensor(45.0505, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 63
# tensor(0.1918, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0017, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2297, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0306, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6336, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 64
# tensor(4.5845e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(3.3052e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(9.9343e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.4841, device='cuda:0', grad_fn=<MeanBackward0>) tensor(43.4629, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 64
# tensor(0.1922, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0017, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2299, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0312, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6371, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 65
# tensor(4.4571e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(3.5854e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(9.9182e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.3294, device='cuda:0', grad_fn=<MeanBackward0>) tensor(42.3172, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 65
# tensor(0.1926, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0018, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2300, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0318, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6410, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 66
# tensor(4.7302e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(2.5328e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(9.8904e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.6373, device='cuda:0', grad_fn=<MeanBackward0>) tensor(45.3615, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 66
# tensor(0.1930, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0018, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2301, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0323, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6450, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 67
# tensor(4.9627e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(4.3700e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.5724, device='cuda:0', grad_fn=<MeanBackward0>) tensor(46.4225, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 67
# tensor(0.1935, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0019, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2303, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0327, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6492, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 68
# tensor(4.3481e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(4.4834e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.0382, device='cuda:0', grad_fn=<MeanBackward0>) tensor(39.6488, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 68
# tensor(0.1940, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0019, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2304, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0331, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6536, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 69
# tensor(4.2258e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(4.8359e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.1278, device='cuda:0', grad_fn=<MeanBackward0>) tensor(38.5813, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 69
# tensor(0.1944, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0019, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2305, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0334, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6582, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 70
# tensor(4.1061e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(5.0141e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(9.9235e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.0771, device='cuda:0', grad_fn=<MeanBackward0>) tensor(38.7094, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 70
# tensor(0.1948, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0019, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2306, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0337, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6630, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 71
# tensor(4.1756e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(5.6808e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(9.8149e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.0735, device='cuda:0', grad_fn=<MeanBackward0>) tensor(40.3618, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 71
# tensor(0.1953, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0020, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2307, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0339, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6681, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 72
# tensor(4.2632e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(5.7935e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(9.8712e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.0942, device='cuda:0', grad_fn=<MeanBackward0>) tensor(40.7683, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 72
# tensor(0.1957, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0020, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2308, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0340, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6734, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 73
# tensor(4.0351e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(5.0442e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(9.6771e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.0748, device='cuda:0', grad_fn=<MeanBackward0>) tensor(40.1011, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 73
# tensor(0.1961, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0020, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2309, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0342, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6789, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 74
# tensor(4.0953e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(3.7374e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(9.7252e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.1898, device='cuda:0', grad_fn=<MeanBackward0>) tensor(40.3089, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 74
# tensor(0.1966, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0020, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2310, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0342, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6845, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 75
# tensor(4.4161e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(5.5346e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(9.9555e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.0731, device='cuda:0', grad_fn=<MeanBackward0>) tensor(41.5719, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 75
# tensor(0.1970, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(-0.0020, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2310, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0342, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6904, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 76
# tensor(4.1537e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(3.6912e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(9.7312e-05, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-1.2481, device='cuda:0', grad_fn=<MeanBackward0>) tensor(40.8718, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 76
# tensor(0.1975, device='cuda:0', grad_fn=<MeanBackward0>)
# ...
# epoch:
# 975
# tensor(0.3662, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0300, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2335, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.5617, device='cuda:0', grad_fn=<MeanBackward0>) tensor(3.6055, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 976
# tensor(9.3837e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.3074, device='cuda:0', grad_fn=<MeanBackward0>) tensor(46.9133, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 976
# tensor(0.3664, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0300, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2335, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.5642, device='cuda:0', grad_fn=<MeanBackward0>) tensor(3.6086, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 977
# tensor(9.2796e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.8446, device='cuda:0', grad_fn=<MeanBackward0>) tensor(47.0529, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 977
# tensor(0.3667, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0300, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2335, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.5667, device='cuda:0', grad_fn=<MeanBackward0>) tensor(3.6119, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 978
# tensor(1.0776e-06, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.5115, device='cuda:0', grad_fn=<MeanBackward0>) tensor(52.6260, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 978
# tensor(0.3669, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0301, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2335, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.5692, device='cuda:0', grad_fn=<MeanBackward0>) tensor(3.6151, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 979
# tensor(9.5396e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.8623, device='cuda:0', grad_fn=<MeanBackward0>) tensor(48.0263, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 979
# tensor(0.3671, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0301, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2335, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.5717, device='cuda:0', grad_fn=<MeanBackward0>) tensor(3.6186, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 980
# tensor(9.9951e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.8134, device='cuda:0', grad_fn=<MeanBackward0>) tensor(48.7945, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 980
# tensor(0.3673, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0302, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2335, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.5743, device='cuda:0', grad_fn=<MeanBackward0>) tensor(3.6220, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 981
# tensor(9.5906e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.9346, device='cuda:0', grad_fn=<MeanBackward0>) tensor(46.7084, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 981
# tensor(0.3676, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0302, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2335, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.5768, device='cuda:0', grad_fn=<MeanBackward0>) tensor(3.6254, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 982
# tensor(9.9464e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.6384, device='cuda:0', grad_fn=<MeanBackward0>) tensor(48.5291, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 982
# tensor(0.3678, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0302, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2335, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.5794, device='cuda:0', grad_fn=<MeanBackward0>) tensor(3.6289, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 983
# tensor(9.5158e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.7146, device='cuda:0', grad_fn=<MeanBackward0>) tensor(46.9017, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 983
# tensor(0.3681, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0303, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2335, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.5820, device='cuda:0', grad_fn=<MeanBackward0>) tensor(3.6324, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 984
# tensor(9.0567e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.7873, device='cuda:0', grad_fn=<MeanBackward0>) tensor(45.5489, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 984
# tensor(0.3683, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0303, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2335, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.5845, device='cuda:0', grad_fn=<MeanBackward0>) tensor(3.6359, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 985
# tensor(9.6920e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.7306, device='cuda:0', grad_fn=<MeanBackward0>) tensor(47.6712, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 985
# tensor(0.3685, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0304, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2335, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.5871, device='cuda:0', grad_fn=<MeanBackward0>) tensor(3.6394, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 986
# tensor(1.0281e-06, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.7445, device='cuda:0', grad_fn=<MeanBackward0>) tensor(49.0310, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 986
# tensor(0.3688, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0304, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2335, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.5896, device='cuda:0', grad_fn=<MeanBackward0>) tensor(3.6430, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 987
# tensor(1.1055e-06, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.6776, device='cuda:0', grad_fn=<MeanBackward0>) tensor(52.4853, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 987
# tensor(0.3690, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0305, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2335, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.5922, device='cuda:0', grad_fn=<MeanBackward0>) tensor(3.6468, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 988
# tensor(1.1021e-06, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.5280, device='cuda:0', grad_fn=<MeanBackward0>) tensor(52.5047, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 988
# tensor(0.3693, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0305, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2335, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.5949, device='cuda:0', grad_fn=<MeanBackward0>) tensor(3.6504, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 989
# tensor(1.0994e-06, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.0238, device='cuda:0', grad_fn=<MeanBackward0>) tensor(51.9482, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 989
# tensor(0.3695, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0305, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2335, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.5975, device='cuda:0', grad_fn=<MeanBackward0>) tensor(3.6542, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 990
# tensor(9.7472e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.2714, device='cuda:0', grad_fn=<MeanBackward0>) tensor(46.9488, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 990
# tensor(0.3698, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0306, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2335, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6000, device='cuda:0', grad_fn=<MeanBackward0>) tensor(3.6579, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 991
# tensor(9.1257e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.5976, device='cuda:0', grad_fn=<MeanBackward0>) tensor(44.2637, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 991
# tensor(0.3700, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0306, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2335, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6027, device='cuda:0', grad_fn=<MeanBackward0>) tensor(3.6615, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 992
# tensor(9.2617e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.8395, device='cuda:0', grad_fn=<MeanBackward0>) tensor(45.7110, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 992
# tensor(0.3703, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0307, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2335, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6053, device='cuda:0', grad_fn=<MeanBackward0>) tensor(3.6654, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 993
# tensor(9.3728e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.6272, device='cuda:0', grad_fn=<MeanBackward0>) tensor(46.6701, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 993
# tensor(0.3706, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0307, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2335, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6080, device='cuda:0', grad_fn=<MeanBackward0>) tensor(3.6691, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 994
# tensor(9.5405e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.5263, device='cuda:0', grad_fn=<MeanBackward0>) tensor(46.1465, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 994
# tensor(0.3709, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0308, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2335, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6105, device='cuda:0', grad_fn=<MeanBackward0>) tensor(3.6730, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 995
# tensor(9.9259e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.2408, device='cuda:0', grad_fn=<MeanBackward0>) tensor(47.1632, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 995
# tensor(0.3711, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0308, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2335, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6132, device='cuda:0', grad_fn=<MeanBackward0>) tensor(3.6770, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 996
# tensor(1.0786e-06, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.1135, device='cuda:0', grad_fn=<MeanBackward0>) tensor(52.1813, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 996
# tensor(0.3714, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0309, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2335, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6159, device='cuda:0', grad_fn=<MeanBackward0>) tensor(3.6810, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 997
# tensor(8.5186e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.4435, device='cuda:0', grad_fn=<MeanBackward0>) tensor(42.8116, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 997
# tensor(0.3717, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0309, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2335, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6185, device='cuda:0', grad_fn=<MeanBackward0>) tensor(3.6851, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 998
# tensor(8.6565e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.5429, device='cuda:0', grad_fn=<MeanBackward0>) tensor(42.3523, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 998
# tensor(0.3719, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0309, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2335, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6212, device='cuda:0', grad_fn=<MeanBackward0>) tensor(3.6891, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# tensor(8.5644e-07)
# (tensor(0.0002), tensor(0.0001), tensor(-0.6406), tensor(42.4748))
# 7840
# tensor(0.3722)
# (tensor(0.0310), tensor(0.2335), tensor(0.6239), tensor(3.6932))
# 7840
# separation
# epoch:
# 999
# tensor(8.5644e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.6406, device='cuda:0', grad_fn=<MeanBackward0>) tensor(42.4748, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 999
# tensor(0.3722, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0310, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2335, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6239, device='cuda:0', grad_fn=<MeanBackward0>) tensor(3.6932, device='cuda:0', grad_fn=<SubBackward0>)
# fan_in
# 784
# fan_in
# 10
# epoch:
# 1000
# tensor(9.0081e-07, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>) tensor(-0.4529, device='cuda:0', grad_fn=<MeanBackward0>) tensor(44.5738, device='cuda:0', grad_fn=<SubBackward0>)
# epoch:
# 1000
# tensor(0.3725, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0310, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.2336, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.6266, device='cuda:0', grad_fn=<MeanBackward0>) tensor(3.6972, device='cuda:0', grad_fn=<SubBackward0>)
# weights

# %%
train_set = torchvision.datasets.FashionMNIST("./data", download=True, transform=
                                                transforms.Compose([
    transforms.ToTensor()
]))
test_set = torchvision.datasets.FashionMNIST("./data", download=True, train=False, transform=
                                               transforms.Compose([
    transforms.ToTensor()
]))  
train_loader = torch.utils.data.DataLoader(train_set, 
                                           batch_size=batch_size,shuffle=False)
test_loader = torch.utils.data.DataLoader(test_set,
                                          batch_size=batch_size,shuffle=False)

# %%
interval=50
no_of_repetition=100
asymptotic_repetition=50
criterion = nn.MSELoss()
noise_strength=10**-3
perturbation_strength=10**-6
import numpy as np  
import matplotlib.pyplot as plt
import torch
no_of_images=20
means=[]
vars=[]
skews=[]
kurtosises=[]
current_file=8
import os
#print(os.getcwd())
file=["relu-1-adam-done","relu-2.5-adam-done" ,"relu-1-sgd-done","relu-2.5-sgd-done","tanh-1-adam-done","tanh-2.5-adam-done","tanh-2.5-sgd-done","tanh-1-sgd-done","relu-2.5-sgd-5000","tanh-2.5-sgd-5000","relu-1-sgd-5000","tanh-1-sgd-5000"]
#list of file to work on 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("running")
path="/raid/home/sichen/phd-project/new runs/"
#current working directory
validation_loss=[]
training_loss=[]
asymptotic_dist=[]
average_jacobian=[]
spectral_radiuses=[]
init_compute=True
epochs=5000
for epoch in range(epochs):
    #model = AE(input_size,output_size,hidden_state_size,no_of_layer).to(device)
    PATH=path+file[current_file]+"/epoch:"+str(epoch)+".pt"
    if epoch==0:
        print(PATH)
    #model.load_state_dict(torch.load(PATH))

    #loss = 0
    print(epoch)
    #if init_compute==True:
     #   for batch_features, _ in train_loader:
        # reshape mini-batch data to [N, 784] matrix
        # load it to the active device
        
        #distance,hidden,chaos,divergent=asymptotic_iteration(model_clone,x_train,perturbed_inputs,no_of_repetition,no_of_images,perturbation_strength)
        #if init_compute==True:
      #      input_image =add_gaussian_noise(batch_features,noise_strength).view(batch_size, -1).to(device)
       #     init_compute=False
        #input_image =add_noise(batch_features,noise_strength).view(batch_size, -1).to(device)
        
        
        #input_image=batch_features.view(batch_size,-1).to(device)
      #  batch_feature=batch_features.view(batch_size,-1).to(device)
        # reset the gradients back to zero
        # PyTorch accumulates gradients on subsequent backward passes
 
       # optimizer.zero_grad()
        
        # compute reconstructions
        #outputs = model(batch_features.view(batch_size,-1).to(device))
        #outputs = model(input_image)
        
        # compute training reconstruction loss
        
 
        #train_loss = criterion(outputs,input_image)
        

        #loss += train_loss.item()
    # compute the epoch training loss
   # loss = loss / len(train_loader)
    #print(loss)
    #training_loss.append(loss)
    #with torch.no_grad():
     #   accuracy=validation(test_loader)
     #   validation_loss.append(accuracy)
    if (epoch)%interval==interval-1 or epoch==0:
        for batch_features, _ in train_loader:
        # reshape mini-batch data to [N, 784] matrix
        # load it to the active device
        
        #distance,hidden,chaos,divergent=asymptotic_iteration(model_clone,x_train,perturbed_inputs,no_of_repetition,no_of_images,perturbation_strength)
        #if init_compute==True:
            input_image =add_gaussian_noise(batch_features,noise_strength).view(batch_size, -1).to(device)
        
        model = AE(input_size,output_size,hidden_state_size,no_of_layer).to(device)
        PATH=path+file[current_file]+"/epoch:"+str(epoch)+".pt"
        if epoch==0:
            print(PATH)
        model.load_state_dict(torch.load(PATH))
        perturbed_input=add_gaussian_noise(input_image,perturbation_strength)
        cutoffs=[]
        for j in range(no_of_images):
            cutoffs.append(torch.norm(perturbed_input[j]-input_image[j]))
        print(cutoffs)
        x_train_perturbed,y_pred_perturbed,average_jacobian,spectral_radiuses,model_clone=calculation(model,no_of_images,no_of_repetition,average_jacobian,spectral_radiuses,perturbed_input,epoch)
        x_train_unperturbed,y_pred_unperturbed,average_jacobian,spectral_radiuses,model_clone=calculation(model,no_of_images,no_of_repetition,average_jacobian,spectral_radiuses,input_image,epoch)
        distance,hidden,chaos=asymptotic_iteration(model_clone,y_pred_unperturbed,y_pred_perturbed,no_of_repetition,no_of_images,cutoffs)
        print(distance)   
        asymptotic_dist.append(distance[-1])
       # dimension_vector=torch.ones(input_size).to(device)
        #xt,xtminus=poincare_plot(model_clone,x_train[0],dimension_vector,no_of_repetition,colour,epoch)
       
        print('here')
        #perturbed_inputs=add_gaussian_noise(input_image,perturbation_strength).view(batch_size, -1).to(device)
        #distance,hidden,chaos,divergent=asymptotic_iteration(model_clone,x_train,perturbed_inputs,no_of_repetition,no_of_images,perturbation_strength*input_size)
        #print("percentage of chaos:",chaos)
        #asymptotic_dist.append(distance[-1])
        #print(distance[-1])
        #print("initial distance")
        #print(distance[0])
        #chao.append(chaos)
        #print(torch.norm(perturbed_inputs[0]-input_image[0]))
        #print(perturbation_strength*input_size)


        print("done"+str(epoch))
        
x=np.arange(1,epochs/interval+1)
plt.scatter(x,y=asymptotic_dist,label="asymptotic distance")

#labels="noise:"+str(noise_strength)+", perturbation:"+str(perturbation_strength)
plt.ylabel("asymptotic distance")
plt.xlabel("epoch/"+str(interval))
plt.yscale("log")
#plt.set_label("noise:{:.f},perturbation:{:.f}".format(noise_strength,perturbation_strength))
plt.legend(loc="best")
plt.savefig(path+file[current_file]+"/"+"asymptotic distance test2.jpg")
np.savetxt(path+file[current_file]+"/"+"asymptotic distance test2.txt",asymptotic_dist)
plt.show()
# Out:
# running
# /raid/home/sichen/phd-project/new runs/relu-2.5-sgd-5000/epoch:0.pt
# 0
# fan_in
# 784
# fan_in
# 784
# fan_in
# 784
# fan_in
# 10
# fan_in
# 784
# /raid/home/sichen/phd-project/new runs/relu-2.5-sgd-5000/epoch:0.pt
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 90
#      88 if epoch==0:
#      89     print(PATH)
# ---> 90 model.load_state_dict(torch.load(PATH))
#      91 perturbed_input=add_gaussian_noise(input_image,perturbation_strength)
#      92 cutoffs=[]
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:2040, in Module.load_state_dict(self, state_dict, strict)
#    2035         error_msgs.insert(
#    2036             0, 'Missing key(s) in state_dict: {}. '.format(
#    2037                 ', '.join('"{}"'.format(k) for k in missing_keys)))
#    2039 if len(error_msgs) > 0:
# -> 2040     raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
#    2041                        self.__class__.__name__, "\n\t".join(error_msgs)))
#    2042 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for AE:
# 	Unexpected key(s) in state_dict: "encoder_input_layer.bias", "hidden_layer.bias", "encoder_output_layer.bias", "decoder_input_layer.bias", "decoder_output_layer.bias".
