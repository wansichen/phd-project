# %%
# %run importingtrial.ipynb
# Out:
# training imageimage:1
# noised_imageimage:1
# training imageimage:2
# noised_imageimage:2
# training imageimage:3
# noised_imageimage:3
# training imageimage:4
# noised_imageimage:4
# training imageimage:5
# noised_imageimage:5
# training imageimage:6
# noised_imageimage:6
# training imageimage:7
# noised_imageimage:7
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /tmp/ipykernel_1301/1489194473.py:3
#       1 i=0
#       2 for b,(x_train,y_train) in enumerate(train_loader):
# ----> 3     visualisation(x_train[0],i,"training image",True)
#       4     noised_image=add_noise(x_train[0],noise_strength)
#       5     visualisation(noised_image[0],i,"noised_image",True)
#
# File /tmp/ipykernel_1301/537403764.py:164, in visualisation(xfinals, epoch, name, bool)
#     161 plt.imshow(xfinals.reshape(28,28), cmap="gray")
# ...
